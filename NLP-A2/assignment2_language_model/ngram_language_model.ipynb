# %% [markdown]
# ## Neural and N-Gram Language Model for CPSC 503 Assignment 2
# #### The neural model notebook is modified from Yunjey Choi's Github repository - pytorch-tutorial.
# #### Familiarize yourself with pytorch, start with: https://pytorch.org/tutorials/beginner/basics/intro.html
#
# #### The N-gram model notebook is from Josh Loehr's Github repository - ngram-language-model.
# #### https://github.com/joshualoehr/ngram-language-model
#
# #### ========================================================================================

# %% [markdown]
# ### Let's load a number of dependencies:

# %%
import torch
import torch.nn as nn
from torch.nn.utils import clip_grad_norm_
import torch.nn.functional as F
import numpy as np
import os
import math
from collections import defaultdict
from tqdm import tqdm

# check if GPU is available to pytorch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Here are two classes needed for the data loading and formating:

# %%
class Dictionary(object):
    # use to generate and return the word-to-index (index-to-word) vocabulary dictionary
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0
    
    def add_word(self, word):
        if not word in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def return_dict(self):
        return self.idx2word
        
    def __len__(self):
        return len(self.word2idx)


class Corpus(object):
    # load and prepare the corpus  the language models input format
    def __init__(self):
        self.dictionary = Dictionary()

    def get_data(self, path, n_gram=2):
        with open(path, 'r') as f:
            tokens = 0;
            sample_list = []
            for line in f:
                # add <start> tokens based on the number of n-grams.
                words = ['<start>'] * (n_gram - 1) + line.split() + ['<end>']
                tokens += len(words)
                sample_list.append(words)
                for word in words: 
                    self.dictionary.add_word(word)  

        # # Read corpus and store the each line (word sequence) into its corresponding index sequence.
        ids_list = [[0]*len(s) for s in sample_list if len(s) > n_gram] 
        with open(path, 'r') as f:
            sample_num = 0
            for line in f:
                token = 0
                words = ['<start>'] * (n_gram - 1) + line.split() + ['<end>']
                if len(words) >= n_gram:
                    for word in words:
                        ids_list[sample_num][token] = self.dictionary.word2idx[word]
                        token += 1
                    sample_num += 1

        # FOR THE NEURAL MODEL Convert the flat index sequences into the n-gram tensors which are ready for neural model.
        for n in range(len(ids_list)):
            flat_ids = ids_list[n]
            ids_list[n] = torch.LongTensor([flat_ids[i:i+n_gram] for i in range(len(flat_ids)-(n_gram - 1))])
        return ids_list

# %% [markdown]
# ### Hyper-parameters for both Language Models:

# %%
# Bigram model
n_gram = 2

# m_gram is the number of preceding/conditioning words 
m_gram = n_gram - 1

# %%
corpus = Corpus()
ids = corpus.get_data('data/train_mini.txt', n_gram)
# ids = corpus.get_data('data/train.txt', n_gram)


# Use 70% for training, 15% for development, and 15% for testing 
n_train = round(len(ids) * .75)
n_dev = round(len(ids) * .15)

train_ids = ids[:n_train]
dev_ids = ids[n_train:n_train + n_dev]
test_ids = ids[n_train + n_dev:]

print(f"Number of sentences: {len(train_ids)} train, {len(dev_ids)} dev, {len(test_ids)} test")
vocab_size = len(corpus.dictionary)
print(f"Vocab size: {vocab_size}")
# Out:
# Number of sentences: 786 train, 157 dev, 105 test
# Vocab size: 3580

# %% [markdown]
# ### Load the "Penn Treebank" dataset and split it into train/dev/test

# %% [markdown]
# ### The class of count-based language model:

# %%
class CountLM(object):
    def __init__(self, vocab_size, x_n, x_m, laplace=1):
        self.vocab_size = vocab_size
        self.laplace = laplace
        
        # Dictionaries for tracking the count of n-grams
        self.n_gram_count = self.count_ngrams(x_n)
        self.m_gram_count = self.count_ngrams(x_m)
    
    def count_ngrams(self, x):
        """
        Populate the dictionary with the number of occurrences of each n-gram
        """
        count_list = defaultdict(int)
        for example in x:
            for n_gram in example.tolist():
                count_list[tuple(n_gram)] += 1 
                
        return count_list
    
    def compute_mle(self, n_gram):
        """
        Compute the MLE of P(w_n|w_{n−1}, ...) with add-one Laplacian smoothing
        
        Please see chapter 3.5.1 of J&M 3rd Ed. for more information
        """
        n_count = self.n_gram_count[n_gram]
        
        m_gram = n_gram[:-1]
        m_count = self.m_gram_count[m_gram]
        prob = (n_count + self.laplace) / (m_count + self.laplace * self.vocab_size) 
        return prob

# %% [markdown]
# ### Train the n-gram model based on MLE

# %%
m_gram_train_ids = corpus.get_data('data/train_mini.txt', m_gram)[:-200]
# m_gram_train_ids = corpus.get_data('data/train.txt', m_gram)[:n_train]
n_gram_train_ids = train_ids

# Populate the dictionaries with counts from training corpus
count_model = CountLM(vocab_size, n_gram_train_ids, m_gram_train_ids)

# Compute average perplexity on training set
train_ppl = 0
for i in range(0, len(train_ids)):
    
    probabilities = list(map(lambda x: count_model.compute_mle(tuple(x)), train_ids[i].tolist()))
    perplexity = np.exp(sum(-np.log(probabilities)) / len(train_ids[i]))
    train_ppl += perplexity
#     print(probabilities)
print('The average training perplexity for count-based LM: '+str(train_ppl/len(train_ids)))
# Out:
# The average training perplexity for count-based LM: 1026.5023506565244

# %%
we = corpus.dictionary.word2idx["we"]
want = corpus.dictionary.word2idx["want"]
count_model.compute_mle((we, want))
# count_model.n_gram_count
# Out:
# 0.000278473962684489

# %% [markdown]
# conditional prob of the word given the previous context
# get all the words in the vocab...
# given train IDs how do I map it to a word?
# How do I loop through all the words and get all the probabilities?
# normalize the sum of the count to 1

# %%
the = corpus.dictionary.word2idx["the"]
zero = corpus.dictionary.idx2word[0]
count_model.compute_mle((0, the))
x = count_model.n_gram_count

# %%
the = corpus.dictionary.word2idx["the"]
zero = corpus.dictionary.idx2word[0]
count_model.compute_mle((0, the))
x = count_model.n_gram_count
while True:
    value = 0
    key
    for pair in x:
    #     print(pair)
        try:
            prob = count_model.compute_mle(pair)
            if prob > value:
                value = prob
                key = pair

        except TypeError:
            # hit end of dict
            
            break
    prob = count_model.compute_mle(key)
    x = count_model.n_gram_count
    print(prob)
    
    
# print(key, value)
# print(corpus.dictionary.idx2word[key[1]])
# prob = count_model.compute_mle(key)
# print(prob)
# Out:
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# 0.03910614525139665
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-b16123c59512> in <module>
#      18     prob = count_model.compute_mle(key)
#      19     x = count_model.n_gram_count
# ---> 20     print(prob)
#      21
#      22
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Compute average perplexity on testing set
test_ppl = 0
for i in range(0, len(test_ids)):

    probabilities = list(map(lambda x: count_model.compute_mle(tuple(x)), test_ids[i].tolist()))
    perplexity = np.exp(sum(-np.log(probabilities)) / len(test_ids[i]))
    print('Perplexity for test sample '+str(i)+' :', perplexity)
    test_ppl += perplexity
    
print('The average testing perplexity for count-based LM: '+str(test_ppl/len(test_ids)))
# Out:
# Perplexity for test sample 0 : 481.93397924150236
# Perplexity for test sample 1 : 1791.0646372289625
# Perplexity for test sample 2 : 295.4281859753384
# Perplexity for test sample 3 : 336.8972086530059
# Perplexity for test sample 4 : 188.3063912073697
# Perplexity for test sample 5 : 1580.4694541715269
# Perplexity for test sample 6 : 908.3518812063347
# Perplexity for test sample 7 : 587.567516576945
# Perplexity for test sample 8 : 466.1199712311848
# Perplexity for test sample 9 : 710.2569626653177
# Perplexity for test sample 10 : 3201.2726581592956
# Perplexity for test sample 11 : 731.7403780164503
# Perplexity for test sample 12 : 902.777634164664
# Perplexity for test sample 13 : 2107.650302714663
# Perplexity for test sample 14 : 867.2708592238805
# Perplexity for test sample 15 : 1282.4375182196761
# Perplexity for test sample 16 : 516.5791519391194
# Perplexity for test sample 17 : 1637.3482160822728
# Perplexity for test sample 18 : 891.4693914511101
# Perplexity for test sample 19 : 1841.6775228827773
# Perplexity for test sample 20 : 1411.6364645250546
# Perplexity for test sample 21 : 925.721200326531
# Perplexity for test sample 22 : 812.7457742328704
# Perplexity for test sample 23 : 941.5028962212622
# Perplexity for test sample 24 : 1120.1733908456056
# Perplexity for test sample 25 : 1300.686968344618
# Perplexity for test sample 26 : 1043.2409835503154
# Perplexity for test sample 27 : 1154.6694641376612
# Perplexity for test sample 28 : 1904.927705371301
# Perplexity for test sample 29 : 1564.8239058313404
# Perplexity for test sample 30 : 676.7400513026464
# Perplexity for test sample 31 : 132.8558212349922
# Perplexity for test sample 32 : 538.5771460958322
# Perplexity for test sample 33 : 81.76321022295139
# Perplexity for test sample 34 : 571.480273977931
# Perplexity for test sample 35 : 165.45585748663606
# Perplexity for test sample 36 : 289.9800469108205
# Perplexity for test sample 37 : 562.3828278316614
# Perplexity for test sample 38 : 129.5098683541854
# Perplexity for test sample 39 : 251.04721015184742
# Perplexity for test sample 40 : 49.96273834996938
# Perplexity for test sample 41 : 411.3631839797082
# Perplexity for test sample 42 : 58.09396842662475
# Perplexity for test sample 43 : 132.8965152703088
# Perplexity for test sample 44 : 160.82306992958496
# Perplexity for test sample 45 : 417.54489178352094
# Perplexity for test sample 46 : 89.45980080244514
# Perplexity for test sample 47 : 187.74322355559934
# Perplexity for test sample 48 : 42.580282658623396
# Perplexity for test sample 49 : 1080.9448564581933
# Perplexity for test sample 50 : 41.742086102867084
# Perplexity for test sample 51 : 105.92756077666773
# Perplexity for test sample 52 : 433.6738110778931
# Perplexity for test sample 53 : 269.89232041470666
# Perplexity for test sample 54 : 717.6379023645706
# Perplexity for test sample 55 : 208.2174372366463
# Perplexity for test sample 56 : 776.3925582715576
# Perplexity for test sample 57 : 548.494486550106
# Perplexity for test sample 58 : 216.32622468219282
# Perplexity for test sample 59 : 325.29422598756565
# Perplexity for test sample 60 : 679.0089766494968
# Perplexity for test sample 61 : 393.99553477705075
# Perplexity for test sample 62 : 325.29422598756565
# Perplexity for test sample 63 : 229.82903738786212
# Perplexity for test sample 64 : 532.6811239695834
# Perplexity for test sample 65 : 2149.0048685562347
# Perplexity for test sample 66 : 2717.393855732771
# Perplexity for test sample 67 : 2900.054892453815
# Perplexity for test sample 68 : 2650.285188774986
# Perplexity for test sample 69 : 208.6572365923395
# Perplexity for test sample 70 : 310.28720655254773
# Perplexity for test sample 71 : 2201.991559458374
# Perplexity for test sample 72 : 827.8769907521668
# Perplexity for test sample 73 : 2447.7760513552685
# Perplexity for test sample 74 : 1812.5585122084933
# Perplexity for test sample 75 : 1703.1835158682684
# Perplexity for test sample 76 : 815.728771098482
# Perplexity for test sample 77 : 1590.4006670499434
# Perplexity for test sample 78 : 1279.7535868433238
# Perplexity for test sample 79 : 1340.2529630738416
# Perplexity for test sample 80 : 1808.847468997499
# Perplexity for test sample 81 : 2091.5025074535565
# Perplexity for test sample 82 : 574.9743300831767
# Perplexity for test sample 83 : 1410.610624968925
# Perplexity for test sample 84 : 922.0769796223215
# Perplexity for test sample 85 : 482.12706134344273
# Perplexity for test sample 86 : 522.0152652604133
# Perplexity for test sample 87 : 1126.1920568787814
# Perplexity for test sample 88 : 2314.9316792912873
# Perplexity for test sample 89 : 796.8027385306444
# Perplexity for test sample 90 : 1302.660304482246
# Perplexity for test sample 91 : 937.4383551934911
# Perplexity for test sample 92 : 946.0231806331294
# Perplexity for test sample 93 : 593.6277246777432
# Perplexity for test sample 94 : 1167.113805590988
# Perplexity for test sample 95 : 72.92303497762008
# Perplexity for test sample 96 : 637.3965523004482
# Perplexity for test sample 97 : 890.0684625241698
# Perplexity for test sample 98 : 344.183478146407
# Perplexity for test sample 99 : 1166.5691316796197
# Perplexity for test sample 100 : 584.5172584599296
# Perplexity for test sample 101 : 1593.3553333789537
# Perplexity for test sample 102 : 69.04335071735089
# Perplexity for test sample 103 : 573.0293813716038
# Perplexity for test sample 104 : 187.52340321188927
# Perplexity for test sample 105 : 240.9020527339753
# Perplexity for test sample 106 : 644.1191442531299
# Perplexity for test sample 107 : 285.5368795424497
# Perplexity for test sample 108 : 462.4482900924821
# Perplexity for test sample 109 : 340.2137657345182
# Perplexity for test sample 110 : 383.91317434343654
# Perplexity for test sample 111 : 212.025718531229
# Perplexity for test sample 112 : 1151.9519074972484
# Perplexity for test sample 113 : 2216.6637439883825
# Perplexity for test sample 114 : 718.5425378237985
# Perplexity for test sample 115 : 1537.1241142398208
# Perplexity for test sample 116 : 561.0310397902816
# Perplexity for test sample 117 : 2402.809953626731
# Perplexity for test sample 118 : 124.77232892143405
# Perplexity for test sample 119 : 122.063854322889
# Perplexity for test sample 120 : 880.9513469442462
# Perplexity for test sample 121 : 828.5834804843624
# Perplexity for test sample 122 : 1735.0536036592168
# Perplexity for test sample 123 : 1389.8502159253487
# Perplexity for test sample 124 : 549.62862330631
# Perplexity for test sample 125 : 1962.7735657632538
# Perplexity for test sample 126 : 3407.751505672027
# Perplexity for test sample 127 : 1637.6460500509975
# Perplexity for test sample 128 : 892.1009001180562
# Perplexity for test sample 129 : 623.7997004478515
# Perplexity for test sample 130 : 1654.4519510023747
# Perplexity for test sample 131 : 921.3499953414732
# Perplexity for test sample 132 : 1728.753001807538
# Perplexity for test sample 133 : 1065.1476567654593
# Perplexity for test sample 134 : 1167.3112799091816
# Perplexity for test sample 135 : 1538.544249168221
# Perplexity for test sample 136 : 2319.0883003213685
# Perplexity for test sample 137 : 795.9255576859662
# Perplexity for test sample 138 : 1218.6085486640316
# Perplexity for test sample 139 : 1150.111603163303
# Perplexity for test sample 140 : 3757.3916240800177
# Perplexity for test sample 141 : 1543.016620681778
# Perplexity for test sample 142 : 2377.6407902103747
# Perplexity for test sample 143 : 852.4670185004002
# Perplexity for test sample 144 : 1183.1022441662797
# Perplexity for test sample 145 : 1184.6531594138253
# Perplexity for test sample 146 : 1095.177943047591
# Perplexity for test sample 147 : 1059.363198358075
# Perplexity for test sample 148 : 2359.3493458286302
# Perplexity for test sample 149 : 2665.1627188357497
# Perplexity for test sample 150 : 689.1334590779602
# Perplexity for test sample 151 : 1012.3342320850847
# Perplexity for test sample 152 : 1458.3549605897933
# Perplexity for test sample 153 : 528.4073433716661
# Perplexity for test sample 154 : 2105.645590221529
# Perplexity for test sample 155 : 1211.867883843374
# Perplexity for test sample 156 : 1154.5806506260953
# Perplexity for test sample 157 : 687.465483362681
# Perplexity for test sample 158 : 1830.1219597298436
# Perplexity for test sample 159 : 2212.895097637416
# Perplexity for test sample 160 : 536.8299521704005
# Perplexity for test sample 161 : 430.6924496696502
# Perplexity for test sample 162 : 1790.9797025048024
# Perplexity for test sample 163 : 1828.260852159602
# Perplexity for test sample 164 : 1365.6553031718809
# Perplexity for test sample 165 : 1295.6540337293798
# Perplexity for test sample 166 : 575.1026878262901
# Perplexity for test sample 167 : 1168.1818170824204
# Perplexity for test sample 168 : 568.8338678988555
# Perplexity for test sample 169 : 1039.7651714120648
# Perplexity for test sample 170 : 1034.1962721849995
# Perplexity for test sample 171 : 1313.5233179676427
# Perplexity for test sample 172 : 293.9979208886636
# Perplexity for test sample 173 : 431.993811532335
# Perplexity for test sample 174 : 470.1589795188589
# Perplexity for test sample 175 : 722.3085986950761
# Perplexity for test sample 176 : 671.9209523011697
# Perplexity for test sample 177 : 1824.06710883368
# Perplexity for test sample 178 : 768.4396809592182
# Perplexity for test sample 179 : 1356.1565343508082
# Perplexity for test sample 180 : 883.0983683139631
# Perplexity for test sample 181 : 366.0316331196213
# Perplexity for test sample 182 : 408.0788780291165
# Perplexity for test sample 183 : 605.9052716904299
# Perplexity for test sample 184 : 2550.764077330927
# Perplexity for test sample 185 : 1662.6739345157207
# Perplexity for test sample 186 : 1121.9763152207486
# Perplexity for test sample 187 : 1019.7621566857607
# Perplexity for test sample 188 : 1495.1114199671185
# Perplexity for test sample 189 : 1111.4673850253657
# Perplexity for test sample 190 : 2485.5241710479486
# Perplexity for test sample 191 : 826.257585469103
# Perplexity for test sample 192 : 1008.649835479471
# Perplexity for test sample 193 : 756.1962912032374
# Perplexity for test sample 194 : 2118.4721585723687
# Perplexity for test sample 195 : 367.1294729707249
# Perplexity for test sample 196 : 4345.048290475975
# Perplexity for test sample 197 : 126.17942940796823
# Perplexity for test sample 198 : 792.7132974441065
# Perplexity for test sample 199 : 1197.1588012356203
# Perplexity for test sample 200 : 336.61321112316523
# Perplexity for test sample 201 : 338.0750633931618
# Perplexity for test sample 202 : 1840.3177203836428
# Perplexity for test sample 203 : 1104.4173072663175
# Perplexity for test sample 204 : 1929.2928617899279
# Perplexity for test sample 205 : 1224.2887203952719
# Perplexity for test sample 206 : 573.0976434771746
# Perplexity for test sample 207 : 2089.8000421366105
# Perplexity for test sample 208 : 1225.387112232634
# Perplexity for test sample 209 : 509.1824829598239
# Perplexity for test sample 210 : 654.7881138097173
# Perplexity for test sample 211 : 1282.1266289249197
# Perplexity for test sample 212 : 2651.1338159172847
# Perplexity for test sample 213 : 288.7155880389371
# Perplexity for test sample 214 : 186.30042481710035
# Perplexity for test sample 215 : 69.67996126558957
# Perplexity for test sample 216 : 1344.1353858252974
# Perplexity for test sample 217 : 271.54666551236545
# Perplexity for test sample 218 : 245.96151196306934
# Perplexity for test sample 219 : 309.83097112783247
# Perplexity for test sample 220 : 79.20393044891293
# Perplexity for test sample 221 : 503.82108055128526
# Perplexity for test sample 222 : 185.39421633307623
# Perplexity for test sample 223 : 743.4153928721299
# Perplexity for test sample 224 : 325.4161391200666
# Perplexity for test sample 225 : 906.9222720718021
# Perplexity for test sample 226 : 616.9794814170156
# Perplexity for test sample 227 : 360.33086550034494
# Perplexity for test sample 228 : 403.111511455393
# Perplexity for test sample 229 : 495.2434525486773
# Perplexity for test sample 230 : 2825.7407548282904
# Perplexity for test sample 231 : 581.2971382586132
# Perplexity for test sample 232 : 672.0025263065963
# Perplexity for test sample 233 : 673.2034217663294
# Perplexity for test sample 234 : 85.50278366400184
# Perplexity for test sample 235 : 393.8123158135173
# Perplexity for test sample 236 : 288.47302152739917
# Perplexity for test sample 237 : 214.01840813502668
# Perplexity for test sample 238 : 1049.7590536840248
# Perplexity for test sample 239 : 537.1283592734683
# Perplexity for test sample 240 : 678.8742992635207
# Perplexity for test sample 241 : 273.46329332869396
# Perplexity for test sample 242 : 186.40106034583727
# Perplexity for test sample 243 : 383.55145773588333
# Perplexity for test sample 244 : 610.8408618765214
# Perplexity for test sample 245 : 47.82929953760972
# Perplexity for test sample 246 : 523.75390157577
# Perplexity for test sample 247 : 211.60716164771037
# Perplexity for test sample 248 : 99.26081125402789
# Perplexity for test sample 249 : 2854.3604016587515
# Perplexity for test sample 250 : 127.74782277343489
# Perplexity for test sample 251 : 1054.3825661111
# Perplexity for test sample 252 : 774.5884918710809
# Perplexity for test sample 253 : 756.4116943639248
# Perplexity for test sample 254 : 394.32651749609914
# Perplexity for test sample 255 : 1425.6001193778402
# Perplexity for test sample 256 : 1882.7076662310026
# Perplexity for test sample 257 : 977.9429776977498
# Perplexity for test sample 258 : 1212.4534001526054
# Perplexity for test sample 259 : 271.24104513002425
# Perplexity for test sample 260 : 1598.1734298202998
# Perplexity for test sample 261 : 2532.5849390374306
# Perplexity for test sample 262 : 409.8384644797687
# Perplexity for test sample 263 : 148.64362766468204
# Perplexity for test sample 264 : 2145.5953160599665
# Perplexity for test sample 265 : 462.57555344218696
# Perplexity for test sample 266 : 192.48330869555107
# Perplexity for test sample 267 : 652.9895794076865
# Perplexity for test sample 268 : 991.765915119332
# Perplexity for test sample 269 : 492.7139289466672
# Perplexity for test sample 270 : 1322.287163531744
# Perplexity for test sample 271 : 1435.3340696791918
# Perplexity for test sample 272 : 491.0621787405643
# Perplexity for test sample 273 : 1816.12656277639
# Perplexity for test sample 274 : 348.8448861761549
# Perplexity for test sample 275 : 2673.042249359975
# Perplexity for test sample 276 : 68.82558636190802
# Perplexity for test sample 277 : 409.07154895716417
# Perplexity for test sample 278 : 360.84536631365137
# Perplexity for test sample 279 : 66.07451754664831
# Perplexity for test sample 280 : 402.458282839866
# Perplexity for test sample 281 : 968.5103405563622
# Perplexity for test sample 282 : 459.82867096390163
# Perplexity for test sample 283 : 1534.3135409898505
# Perplexity for test sample 284 : 656.2856924252014
# Perplexity for test sample 285 : 1628.7499762219177
# Perplexity for test sample 286 : 913.9348820365676
# Perplexity for test sample 287 : 1290.393832215846
# Perplexity for test sample 288 : 619.8037811245572
# Perplexity for test sample 289 : 186.72204058199395
# Perplexity for test sample 290 : 77.63851857484606
# Perplexity for test sample 291 : 169.05235046010426
# Perplexity for test sample 292 : 852.5715068384701
# Perplexity for test sample 293 : 103.69072794282626
# Perplexity for test sample 294 : 1383.965518616425
# Perplexity for test sample 295 : 1380.7911588051809
# Perplexity for test sample 296 : 2363.701643180896
# Perplexity for test sample 297 : 304.9574663319291
# Perplexity for test sample 298 : 1170.4250024649675
# Perplexity for test sample 299 : 1771.6507643588857
# Perplexity for test sample 300 : 472.2552314750325
# Perplexity for test sample 301 : 389.98990601220584
# Perplexity for test sample 302 : 229.05554638933535
# Perplexity for test sample 303 : 179.6947070502076
# Perplexity for test sample 304 : 66.1938516609894
# Perplexity for test sample 305 : 22.43749364232009
# Perplexity for test sample 306 : 93.06303324946784
# Perplexity for test sample 307 : 633.2825157450752
# Perplexity for test sample 308 : 499.12542260479654
# Perplexity for test sample 309 : 1143.253694493906
# Perplexity for test sample 310 : 422.9950385808893
# Perplexity for test sample 311 : 560.7701347900812
# Perplexity for test sample 312 : 640.095854695786
# Perplexity for test sample 313 : 1931.2593778821188
# Perplexity for test sample 314 : 595.4924972173574
# Perplexity for test sample 315 : 4219.939675625063
# Perplexity for test sample 316 : 646.7971848741764
# Perplexity for test sample 317 : 3325.755392870575
# Perplexity for test sample 318 : 2764.4813257970522
# Perplexity for test sample 319 : 1606.9266137310683
# Perplexity for test sample 320 : 1597.8386656130767
# Perplexity for test sample 321 : 2117.69656097956
# Perplexity for test sample 322 : 1478.864611165388
# Perplexity for test sample 323 : 1075.3058511779675
# Perplexity for test sample 324 : 1136.3198134962286
# Perplexity for test sample 325 : 1846.4402283796196
# Perplexity for test sample 326 : 1737.8882861483928
# Perplexity for test sample 327 : 2608.5554007792744
# Perplexity for test sample 328 : 228.9714693171564
# Perplexity for test sample 329 : 114.23675823410349
# Perplexity for test sample 330 : 735.5479096120757
# Perplexity for test sample 331 : 36.24849931570654
# Perplexity for test sample 332 : 673.0617197355867
# Perplexity for test sample 333 : 47.46100097652404
# Perplexity for test sample 334 : 138.71260268803786
# Perplexity for test sample 335 : 232.3252552864348
# Perplexity for test sample 336 : 35.569096855877504
# Perplexity for test sample 337 : 2059.439099477476
# Perplexity for test sample 338 : 546.2497981439494
# Perplexity for test sample 339 : 416.00322766637834
# Perplexity for test sample 340 : 278.1688943417625
# Perplexity for test sample 341 : 235.82123377574925
# Perplexity for test sample 342 : 1026.8845763030904
# Perplexity for test sample 343 : 878.8450600142382
# Perplexity for test sample 344 : 918.6906893307547
# Perplexity for test sample 345 : 1467.8630843956341
# Perplexity for test sample 346 : 1675.0053172511105
# Perplexity for test sample 347 : 662.9696467557179
# Perplexity for test sample 348 : 1411.7526709938331
# Perplexity for test sample 349 : 334.89895091278686
# Perplexity for test sample 350 : 1694.1949740364216
# Perplexity for test sample 351 : 1854.2922164329395
# Perplexity for test sample 352 : 1119.0271270546598
# Perplexity for test sample 353 : 513.2739019680205
# Perplexity for test sample 354 : 85.56933996813589
# Perplexity for test sample 355 : 953.0707414701826
# Perplexity for test sample 356 : 145.12245018683362
# Perplexity for test sample 357 : 711.3304217816811
# Perplexity for test sample 358 : 2057.315450484
# Perplexity for test sample 359 : 1467.3743858166574
# Perplexity for test sample 360 : 1605.7858019989985
# Perplexity for test sample 361 : 2172.4447284395046
# Perplexity for test sample 362 : 1883.2849105352752
# Perplexity for test sample 363 : 2109.893371220995
# Perplexity for test sample 364 : 1570.6151250070432
# Perplexity for test sample 365 : 1646.4202009303192
# Perplexity for test sample 366 : 1309.211771143349
# Perplexity for test sample 367 : 920.4876846026568
# Perplexity for test sample 368 : 261.7389913419931
# Perplexity for test sample 369 : 1587.5447064362197
# Perplexity for test sample 370 : 506.82360620408645
# Perplexity for test sample 371 : 1651.5922982097293
# Perplexity for test sample 372 : 379.4285156300535
# Perplexity for test sample 373 : 1342.1292581705231
# Perplexity for test sample 374 : 2004.5060128957548
# Perplexity for test sample 375 : 434.1216537825502
# Perplexity for test sample 376 : 1997.6704276401927
# Perplexity for test sample 377 : 2417.55277858527
# Perplexity for test sample 378 : 4426.127317395714
# Perplexity for test sample 379 : 1375.9879136713328
# Perplexity for test sample 380 : 1306.453858486995
# Perplexity for test sample 381 : 979.8556419932391
# Perplexity for test sample 382 : 1361.8903588218086
# Perplexity for test sample 383 : 1122.3310076739874
# Perplexity for test sample 384 : 2062.3402709205416
# Perplexity for test sample 385 : 1199.3782683049199
# Perplexity for test sample 386 : 1741.3221512092161
# Perplexity for test sample 387 : 967.53993751541
# Perplexity for test sample 388 : 2112.9317832744696
# Perplexity for test sample 389 : 1177.529415643371
# Perplexity for test sample 390 : 1004.7281667659246
# Perplexity for test sample 391 : 1602.6098522648797
# Perplexity for test sample 392 : 1849.027680926069
# Perplexity for test sample 393 : 1441.6709495049827
# Perplexity for test sample 394 : 1233.6349022382456
# Perplexity for test sample 395 : 2541.2352908295966
# Perplexity for test sample 396 : 4789.583870003285
# Perplexity for test sample 397 : 4829.79778786494
# Perplexity for test sample 398 : 698.8988194342242
# Perplexity for test sample 399 : 976.4309944391989
# Perplexity for test sample 400 : 1100.235858869824
# Perplexity for test sample 401 : 1802.7389684924947
# Perplexity for test sample 402 : 742.0065082531015
# Perplexity for test sample 403 : 989.673637436874
# Perplexity for test sample 404 : 1317.8792054007417
# Perplexity for test sample 405 : 2030.8151425705414
# Perplexity for test sample 406 : 609.3125290828666
# Perplexity for test sample 407 : 3211.295737435263
# Perplexity for test sample 408 : 1137.6336492692847
# Perplexity for test sample 409 : 1669.798162787097
# Perplexity for test sample 410 : 1713.0584744955518
# Perplexity for test sample 411 : 2715.8199841251703
# Perplexity for test sample 412 : 1117.7379704485693
# Perplexity for test sample 413 : 482.09852626419627
# Perplexity for test sample 414 : 559.0840364585853
# Perplexity for test sample 415 : 1654.140331871742
# Perplexity for test sample 416 : 4455.325723243016
# Perplexity for test sample 417 : 1550.8092314308813
# Perplexity for test sample 418 : 436.62336276678064
# Perplexity for test sample 419 : 433.75078143812846
# Perplexity for test sample 420 : 1991.59302814475
# Perplexity for test sample 421 : 530.794921850357
# Perplexity for test sample 422 : 2419.6034643371413
# Perplexity for test sample 423 : 1576.365517360417
# Perplexity for test sample 424 : 545.6067079897163
# Perplexity for test sample 425 : 1792.6869014417925
# Perplexity for test sample 426 : 515.0682546921106
# Perplexity for test sample 427 : 181.16081833107634
# Perplexity for test sample 428 : 42.27794805120391
# Perplexity for test sample 429 : 76.70541683987852
# Perplexity for test sample 430 : 1896.8041738706684
# Perplexity for test sample 431 : 739.6244996326128
# Perplexity for test sample 432 : 55.927938636125624
# Perplexity for test sample 433 : 27.876750997000187
# Perplexity for test sample 434 : 1980.3431692399663
# Perplexity for test sample 435 : 2102.747445115531
# Perplexity for test sample 436 : 2507.303614084628
# Perplexity for test sample 437 : 711.5534403606764
# Perplexity for test sample 438 : 2627.0928507909475
# Perplexity for test sample 439 : 707.3853730451151
# Perplexity for test sample 440 : 2680.04776374447
# Perplexity for test sample 441 : 1423.1154742491244
# Perplexity for test sample 442 : 556.2558564519584
# Perplexity for test sample 443 : 1054.3801117877915
# Perplexity for test sample 444 : 1035.1437431834534
# Perplexity for test sample 445 : 1235.1194144207648
# Perplexity for test sample 446 : 248.7375496158064
# Perplexity for test sample 447 : 435.27548670143113
# Perplexity for test sample 448 : 815.354032949467
# Perplexity for test sample 449 : 1486.8895269309514
# Perplexity for test sample 450 : 1533.974163346364
# Perplexity for test sample 451 : 445.4754086207121
# Perplexity for test sample 452 : 197.03140120965622
# Perplexity for test sample 453 : 283.77943489828374
# Perplexity for test sample 454 : 442.05427711024504
# Perplexity for test sample 455 : 227.61530687788218
# Perplexity for test sample 456 : 114.59467105262033
# Perplexity for test sample 457 : 315.00751878582804
# Perplexity for test sample 458 : 1013.2766608171565
# Perplexity for test sample 459 : 105.6663661520974
# Perplexity for test sample 460 : 197.21875248941447
# Perplexity for test sample 461 : 120.27737108289467
# Perplexity for test sample 462 : 414.67515537130447
# Perplexity for test sample 463 : 1380.2489553128314
# Perplexity for test sample 464 : 1166.3331551769102
# Perplexity for test sample 465 : 124.07163566522452
# Perplexity for test sample 466 : 418.10625538597765
# Perplexity for test sample 467 : 393.0352116770653
# Perplexity for test sample 468 : 556.8317578405371
# Perplexity for test sample 469 : 47.46546710688659
# Perplexity for test sample 470 : 808.1304802489457
# Perplexity for test sample 471 : 394.4535220020941
# Perplexity for test sample 472 : 381.26509460330254
# Perplexity for test sample 473 : 2147.8017853421725
# Perplexity for test sample 474 : 767.5356735066674
# Perplexity for test sample 475 : 440.23612274171313
# Perplexity for test sample 476 : 1411.7982098584541
# Perplexity for test sample 477 : 1340.228462912635
# Perplexity for test sample 478 : 625.8875601862139
# Perplexity for test sample 479 : 326.7474559438003
# Perplexity for test sample 480 : 2314.711107357359
# Perplexity for test sample 481 : 641.1010297320391
# Perplexity for test sample 482 : 924.7194832409851
# Perplexity for test sample 483 : 216.0777613182024
# Perplexity for test sample 484 : 46.62580188052339
# Perplexity for test sample 485 : 125.4328208334101
# Perplexity for test sample 486 : 77.93621732293839
# Perplexity for test sample 487 : 1115.2150042315734
# Perplexity for test sample 488 : 521.2903409528977
# Perplexity for test sample 489 : 224.99793554099298
# Perplexity for test sample 490 : 23.046753440667732
# Perplexity for test sample 491 : 3565.276825312248
# Perplexity for test sample 492 : 2204.9730010999792
# Perplexity for test sample 493 : 904.9911121240359
# Perplexity for test sample 494 : 2404.934051045733
# Perplexity for test sample 495 : 1624.655194183338
# Perplexity for test sample 496 : 1466.613666267617
# Perplexity for test sample 497 : 1093.1959155471243
# Perplexity for test sample 498 : 1185.1578144645198
# Perplexity for test sample 499 : 1096.7586467676615
# Perplexity for test sample 500 : 2377.569718199431
# Perplexity for test sample 501 : 1551.7332062615874
# Perplexity for test sample 502 : 1345.5309514786677
# Perplexity for test sample 503 : 1617.7358987047912
# Perplexity for test sample 504 : 1719.118249136406
# Perplexity for test sample 505 : 899.9945933972881
# Perplexity for test sample 506 : 1594.7925379320473
# Perplexity for test sample 507 : 888.7633088054858
# Perplexity for test sample 508 : 1460.0117245055435
# Perplexity for test sample 509 : 1114.6897590862018
# Perplexity for test sample 510 : 1215.0589823857588
# Perplexity for test sample 511 : 1139.23049351491
# Perplexity for test sample 512 : 1069.6189816753993
# Perplexity for test sample 513 : 1699.0298907917622
# Perplexity for test sample 514 : 1111.213089703949
# Perplexity for test sample 515 : 929.3090627846371
# Perplexity for test sample 516 : 1020.4562897017961
# Perplexity for test sample 517 : 2844.015877573986
# Perplexity for test sample 518 : 926.0769510280805
# Perplexity for test sample 519 : 825.8404160296516
# Perplexity for test sample 520 : 1853.0132280290825
# Perplexity for test sample 521 : 1440.1543587047095
# Perplexity for test sample 522 : 383.2279527359837
# Perplexity for test sample 523 : 1163.9777024650646
# Perplexity for test sample 524 : 465.934322506438
# Perplexity for test sample 525 : 1334.0055729360536
# Perplexity for test sample 526 : 2180.096615174918
# Perplexity for test sample 527 : 1108.7488559401008
# Perplexity for test sample 528 : 462.42303691332467
# Perplexity for test sample 529 : 1829.5391982113467
# Perplexity for test sample 530 : 680.7873439128163
# Perplexity for test sample 531 : 1075.720921572503
# Perplexity for test sample 532 : 1439.8581346877356
# Perplexity for test sample 533 : 774.3979944399077
# Perplexity for test sample 534 : 703.7149869261153
# Perplexity for test sample 535 : 1840.1099473425838
# Perplexity for test sample 536 : 1048.4176752574454
# Perplexity for test sample 537 : 1971.689039941437
# Perplexity for test sample 538 : 1139.6771184979086
# Perplexity for test sample 539 : 472.15129462701213
# Perplexity for test sample 540 : 269.29719943722847
# Perplexity for test sample 541 : 1455.8988909984773
# Perplexity for test sample 542 : 924.8680005201046
# Perplexity for test sample 543 : 867.9909649269817
# Perplexity for test sample 544 : 1377.0948627841342
# Perplexity for test sample 545 : 990.1150373931112
# Perplexity for test sample 546 : 1175.6991256226781
# Perplexity for test sample 547 : 1153.7826050323285
# Perplexity for test sample 548 : 1786.9075761898748
# Perplexity for test sample 549 : 1776.40332610084
# Perplexity for test sample 550 : 901.5695779254386
# Perplexity for test sample 551 : 1273.598951993856
# Perplexity for test sample 552 : 3234.816147687008
# Perplexity for test sample 553 : 1284.0629397514783
# Perplexity for test sample 554 : 903.899406142975
# Perplexity for test sample 555 : 1222.3261925177926
# Perplexity for test sample 556 : 251.96586944095444
# Perplexity for test sample 557 : 2360.098162545376
# Perplexity for test sample 558 : 3139.444426040386
# Perplexity for test sample 559 : 558.5475756882631
# Perplexity for test sample 560 : 1066.283600751688
# Perplexity for test sample 561 : 907.672002639616
# Perplexity for test sample 562 : 534.2279352849417
# Perplexity for test sample 563 : 619.8588374951904
# Perplexity for test sample 564 : 1026.057903769044
# Perplexity for test sample 565 : 1272.6999129510825
# Perplexity for test sample 566 : 298.8445432339079
# Perplexity for test sample 567 : 1182.944897673217
# Perplexity for test sample 568 : 2565.6916427008705
# Perplexity for test sample 569 : 525.6969321030986
# Perplexity for test sample 570 : 493.0282756204039
# Perplexity for test sample 571 : 926.7660632373199
# Perplexity for test sample 572 : 1896.9920604218557
# Perplexity for test sample 573 : 1362.6881200849073
# Perplexity for test sample 574 : 1591.9059678973667
# Perplexity for test sample 575 : 1146.5589906423154
# Perplexity for test sample 576 : 764.3708403865194
# Perplexity for test sample 577 : 2055.3219112627376
# Perplexity for test sample 578 : 1204.6460864252524
# Perplexity for test sample 579 : 803.2308618571208
# Perplexity for test sample 580 : 873.1776896352814
# Perplexity for test sample 581 : 583.9518894052751
# Perplexity for test sample 582 : 817.6332438781609
# Perplexity for test sample 583 : 1247.6585369316692
# Perplexity for test sample 584 : 1402.1778140285562
# Perplexity for test sample 585 : 2573.157448553893
# Perplexity for test sample 586 : 473.9272433827728
# Perplexity for test sample 587 : 1524.5062371963986
# Perplexity for test sample 588 : 807.6432195290809
# Perplexity for test sample 589 : 2538.234484629882
# Perplexity for test sample 590 : 2139.116425115902
# Perplexity for test sample 591 : 1915.1266532394372
# Perplexity for test sample 592 : 2378.9848279320736
# Perplexity for test sample 593 : 1888.3645952405589
# Perplexity for test sample 594 : 1865.2730380322403
# Perplexity for test sample 595 : 1938.3214698407323
# Perplexity for test sample 596 : 1029.030713372014
# Perplexity for test sample 597 : 5052.042855285605
# Perplexity for test sample 598 : 1218.7309216558338
# Perplexity for test sample 599 : 1148.2901993950677
# Perplexity for test sample 600 : 1418.0582677329069
# Perplexity for test sample 601 : 3830.683441181401
# Perplexity for test sample 602 : 2112.933242295781
# Perplexity for test sample 603 : 2599.3378905678856
# Perplexity for test sample 604 : 975.3805045606539
# Perplexity for test sample 605 : 4017.033016524169
# Perplexity for test sample 606 : 1071.7733826871834
# Perplexity for test sample 607 : 1140.0055073412748
# Perplexity for test sample 608 : 1753.140696280624
# Perplexity for test sample 609 : 2092.125498091382
# Perplexity for test sample 610 : 1842.280429359916
# Perplexity for test sample 611 : 1517.3417411637026
# Perplexity for test sample 612 : 1603.0921980207386
# Perplexity for test sample 613 : 1133.9077022210918
# Perplexity for test sample 614 : 1854.082747387341
# Perplexity for test sample 615 : 2337.8159922725004
# Perplexity for test sample 616 : 1275.8385396332455
# Perplexity for test sample 617 : 1886.6968583911346
# Perplexity for test sample 618 : 1470.766888942585
# Perplexity for test sample 619 : 1031.026192487583
# Perplexity for test sample 620 : 916.7361426744511
# Perplexity for test sample 621 : 1367.0873992915901
# Perplexity for test sample 622 : 1194.6920442328635
# Perplexity for test sample 623 : 2311.121161386016
# Perplexity for test sample 624 : 1563.7458776445264
# Perplexity for test sample 625 : 2483.423785419098
# Perplexity for test sample 626 : 2267.230008984173
# Perplexity for test sample 627 : 1092.6152638248543
# Perplexity for test sample 628 : 913.4419931046757
# Perplexity for test sample 629 : 1463.9693336068935
# Perplexity for test sample 630 : 1051.6700791862704
# Perplexity for test sample 631 : 2520.3238002755875
# Perplexity for test sample 632 : 1711.031701958241
# Perplexity for test sample 633 : 738.7161488136488
# Perplexity for test sample 634 : 850.0407863910309
# Perplexity for test sample 635 : 867.2212128610985
# Perplexity for test sample 636 : 2599.7005312136853
# Perplexity for test sample 637 : 2190.8886116187387
# Perplexity for test sample 638 : 1053.911851636486
# Perplexity for test sample 639 : 755.2063603443977
# Perplexity for test sample 640 : 1150.2010941520048
# Perplexity for test sample 641 : 1825.4304618305393
# Perplexity for test sample 642 : 364.90666244234274
# Perplexity for test sample 643 : 1756.6640814723123
# Perplexity for test sample 644 : 1659.3408858123835
# Perplexity for test sample 645 : 3608.7859752639692
# Perplexity for test sample 646 : 306.8238218197961
# Perplexity for test sample 647 : 459.6734883032913
# Perplexity for test sample 648 : 265.31292350034033
# Perplexity for test sample 649 : 1825.5478070280028
# Perplexity for test sample 650 : 2616.096041507676
# Perplexity for test sample 651 : 866.3417079667701
# Perplexity for test sample 652 : 1317.384396488839
# Perplexity for test sample 653 : 835.7955800229088
# Perplexity for test sample 654 : 1368.869923485612
# Perplexity for test sample 655 : 1660.0791066203396
# Perplexity for test sample 656 : 1178.8023134336347
# Perplexity for test sample 657 : 559.3568752461229
# Perplexity for test sample 658 : 441.59748715237504
# Perplexity for test sample 659 : 249.52894722964731
# Perplexity for test sample 660 : 1198.6873125507132
# Perplexity for test sample 661 : 910.0540151076999
# Perplexity for test sample 662 : 204.10602314186292
# Perplexity for test sample 663 : 465.2434780337224
# Perplexity for test sample 664 : 351.9017267401526
# Perplexity for test sample 665 : 1289.4722582093048
# Perplexity for test sample 666 : 304.5738057103222
# Perplexity for test sample 667 : 912.9103114846835
# Perplexity for test sample 668 : 2374.619537475548
# Perplexity for test sample 669 : 1393.969525057083
# Perplexity for test sample 670 : 637.853968793247
# Perplexity for test sample 671 : 1393.684433580853
# Perplexity for test sample 672 : 2436.761240983701
# Perplexity for test sample 673 : 758.506920654512
# Perplexity for test sample 674 : 2403.4931328210146
# Perplexity for test sample 675 : 1237.1274904605925
# Perplexity for test sample 676 : 1037.0469190766719
# Perplexity for test sample 677 : 1260.6544635292994
# Perplexity for test sample 678 : 1875.5440020254746
# Perplexity for test sample 679 : 1118.6005642707044
# Perplexity for test sample 680 : 248.81417028392696
# Perplexity for test sample 681 : 455.45246230109126
# Perplexity for test sample 682 : 434.23736095625395
# Perplexity for test sample 683 : 1111.7638424149511
# Perplexity for test sample 684 : 1173.4462259177099
# Perplexity for test sample 685 : 494.9494808546869
# Perplexity for test sample 686 : 2413.9114767109454
# Perplexity for test sample 687 : 2701.6025725050217
# Perplexity for test sample 688 : 1974.7208886934768
# Perplexity for test sample 689 : 120.71965904812515
# Perplexity for test sample 690 : 3652.8175956487057
# Perplexity for test sample 691 : 1048.9731112363988
# Perplexity for test sample 692 : 801.1842377718348
# Perplexity for test sample 693 : 1725.2735583397462
# Perplexity for test sample 694 : 1369.1834100372546
# Perplexity for test sample 695 : 546.0447713489644
# Perplexity for test sample 696 : 920.2930003840106
# Perplexity for test sample 697 : 1820.3557462965357
# Perplexity for test sample 698 : 5044.611411969623
# Perplexity for test sample 699 : 257.0281492579625
# Perplexity for test sample 700 : 374.65265752035964
# Perplexity for test sample 701 : 567.8562639298588
# Perplexity for test sample 702 : 2132.128874576007
# Perplexity for test sample 703 : 880.7084306830131
# Perplexity for test sample 704 : 1244.9816273337544
# Perplexity for test sample 705 : 1656.161397174365
# Perplexity for test sample 706 : 500.4876356979196
# Perplexity for test sample 707 : 1355.515389872046
# Perplexity for test sample 708 : 1838.1700573427547
# Perplexity for test sample 709 : 3441.874941350526
# Perplexity for test sample 710 : 1109.709663782446
# Perplexity for test sample 711 : 2765.0403460639423
# Perplexity for test sample 712 : 894.4595300144265
# Perplexity for test sample 713 : 997.0322279409577
# Perplexity for test sample 714 : 1387.8531466287982
# Perplexity for test sample 715 : 859.1054592296214
# Perplexity for test sample 716 : 2910.915997534536
# Perplexity for test sample 717 : 986.7391595053133
# Perplexity for test sample 718 : 1158.1385053149502
# Perplexity for test sample 719 : 963.181862842607
# Perplexity for test sample 720 : 804.043731124773
# Perplexity for test sample 721 : 1172.255983417812
# Perplexity for test sample 722 : 2182.169233554661
# Perplexity for test sample 723 : 2144.445120910462
# Perplexity for test sample 724 : 1192.5335127089572
# Perplexity for test sample 725 : 939.8782270999319
# Perplexity for test sample 726 : 924.6922126512331
# Perplexity for test sample 727 : 4260.772448732626
# Perplexity for test sample 728 : 793.0441960742892
# Perplexity for test sample 729 : 2281.548315392181
# Perplexity for test sample 730 : 1374.3602115477127
# Perplexity for test sample 731 : 1987.2083091818022
# Perplexity for test sample 732 : 2896.1103892994715
# Perplexity for test sample 733 : 2037.8742900488921
# Perplexity for test sample 734 : 2597.5764904088373
# Perplexity for test sample 735 : 1396.4792946521457
# Perplexity for test sample 736 : 1531.0671631143937
# Perplexity for test sample 737 : 1170.0914741113384
# Perplexity for test sample 738 : 327.33292530736855
# Perplexity for test sample 739 : 1562.8059928424461
# Perplexity for test sample 740 : 2961.848750320132
# Perplexity for test sample 741 : 1500.698489547642
# Perplexity for test sample 742 : 427.4880093774432
# Perplexity for test sample 743 : 482.88754062177316
# Perplexity for test sample 744 : 262.10674516663755
# Perplexity for test sample 745 : 1097.1703518746417
# Perplexity for test sample 746 : 2084.4922006527745
# Perplexity for test sample 747 : 749.3413521040982
# Perplexity for test sample 748 : 1476.302072601717
# Perplexity for test sample 749 : 873.656440148492
# Perplexity for test sample 750 : 2363.8051866386068
# Perplexity for test sample 751 : 886.9305727659458
# Perplexity for test sample 752 : 2995.719303806949
# Perplexity for test sample 753 : 1422.0379275274108
# Perplexity for test sample 754 : 1727.792818704998
# Perplexity for test sample 755 : 324.95222708136913
# Perplexity for test sample 756 : 628.8940706498786
# Perplexity for test sample 757 : 911.6896920212267
# Perplexity for test sample 758 : 261.1023982228137
# Perplexity for test sample 759 : 1302.4972549974968
# Perplexity for test sample 760 : 717.3383585595343
# Perplexity for test sample 761 : 365.6227321560482
# Perplexity for test sample 762 : 1973.55689462365
# Perplexity for test sample 763 : 53.76656485226459
# Perplexity for test sample 764 : 51.243689290070286
# Perplexity for test sample 765 : 89.58485593861606
# Perplexity for test sample 766 : 281.66201093754825
# Perplexity for test sample 767 : 548.1665417154691
# Perplexity for test sample 768 : 466.48637638140394
# Perplexity for test sample 769 : 353.18224043576276
# Perplexity for test sample 770 : 467.2091222336525
# Perplexity for test sample 771 : 1182.4586718619178
# Perplexity for test sample 772 : 2040.843901251164
# Perplexity for test sample 773 : 470.0103678600851
# Perplexity for test sample 774 : 64.05581352945339
# Perplexity for test sample 775 : 71.30809492557715
# Perplexity for test sample 776 : 2528.7916065803456
# Perplexity for test sample 777 : 790.7865256359132
# Perplexity for test sample 778 : 1511.9999999553243
# Perplexity for test sample 779 : 1906.3262473414502
# Perplexity for test sample 780 : 756.1465186987996
# Perplexity for test sample 781 : 954.577631571615
# Perplexity for test sample 782 : 569.8083493519379
# Perplexity for test sample 783 : 3126.3981712980203
# Perplexity for test sample 784 : 706.5498585212472
# Perplexity for test sample 785 : 2608.285320534367
# Perplexity for test sample 786 : 1659.539837844288
# Perplexity for test sample 787 : 3756.917503294301
# Perplexity for test sample 788 : 1641.9631739578929
# Perplexity for test sample 789 : 1746.3128178404406
# Perplexity for test sample 790 : 1373.0792257499966
# Perplexity for test sample 791 : 1941.333094163077
# Perplexity for test sample 792 : 1606.4803546180813
# Perplexity for test sample 793 : 1408.17294674307
# Perplexity for test sample 794 : 2710.5272082971505
# Perplexity for test sample 795 : 843.1102230032269
# Perplexity for test sample 796 : 2795.038375709856
# Perplexity for test sample 797 : 1045.166463532194
# Perplexity for test sample 798 : 8.181472320480859
# Perplexity for test sample 799 : 1442.567994983951
# Perplexity for test sample 800 : 2893.4838436979735
# Perplexity for test sample 801 : 2552.2528758743647
# Perplexity for test sample 802 : 1398.1599589242448
# Perplexity for test sample 803 : 1109.512455793627
# Perplexity for test sample 804 : 1045.766016886944
# Perplexity for test sample 805 : 2361.5872928828985
# Perplexity for test sample 806 : 2319.8926883432973
# Perplexity for test sample 807 : 1160.7376713605113
# Perplexity for test sample 808 : 2546.9663097833063
# Perplexity for test sample 809 : 1131.740478016028
# Perplexity for test sample 810 : 979.5287280230908
# Perplexity for test sample 811 : 1674.3832546192896
# Perplexity for test sample 812 : 1352.3799756057401
# Perplexity for test sample 813 : 1157.4960731567103
# Perplexity for test sample 814 : 1001.6163958771388
# Perplexity for test sample 815 : 190.3177197324666
# Perplexity for test sample 816 : 1370.4881754351131
# Perplexity for test sample 817 : 615.988446361166
# Perplexity for test sample 818 : 960.3383292083383
# Perplexity for test sample 819 : 1703.1207910807377
# Perplexity for test sample 820 : 1901.3909258025633
# Perplexity for test sample 821 : 904.559934748942
# Perplexity for test sample 822 : 575.8057876048854
# Perplexity for test sample 823 : 262.6940217768524
# Perplexity for test sample 824 : 799.3273168620826
# Perplexity for test sample 825 : 855.2759430066767
# Perplexity for test sample 826 : 3225.4779324964734
# Perplexity for test sample 827 : 2208.1232233795613
# Perplexity for test sample 828 : 1454.2996983405003
# Perplexity for test sample 829 : 2663.660203746323
# Perplexity for test sample 830 : 593.400652172226
# Perplexity for test sample 831 : 164.86530558563015
# Perplexity for test sample 832 : 974.0747910739447
# Perplexity for test sample 833 : 1326.0820308659688
# Perplexity for test sample 834 : 1494.9209607697148
# Perplexity for test sample 835 : 1258.8880693269246
# Perplexity for test sample 836 : 724.3969769258744
# Perplexity for test sample 837 : 811.1958602485556
# Perplexity for test sample 838 : 1449.8683839662374
# Perplexity for test sample 839 : 1704.7045522582373
# Perplexity for test sample 840 : 489.8364766249318
# Perplexity for test sample 841 : 971.4317444713425
# Perplexity for test sample 842 : 464.54413475590104
# Perplexity for test sample 843 : 1418.292717728814
# Perplexity for test sample 844 : 2035.464886718735
# Perplexity for test sample 845 : 513.8412138240475
# Perplexity for test sample 846 : 917.645276609266
# Perplexity for test sample 847 : 1057.3921316739113
# Perplexity for test sample 848 : 1044.1810526078696
# Perplexity for test sample 849 : 1403.7238124104783
# Perplexity for test sample 850 : 1137.1819708612088
# Perplexity for test sample 851 : 414.7020824016751
# Perplexity for test sample 852 : 1136.322911798998
# Perplexity for test sample 853 : 633.6926952783749
# Perplexity for test sample 854 : 1127.1231159986573
# Perplexity for test sample 855 : 1568.0364323972276
# Perplexity for test sample 856 : 1547.0237839766378
# Perplexity for test sample 857 : 501.5565626705183
# Perplexity for test sample 858 : 2249.590885736426
# Perplexity for test sample 859 : 2767.289237784093
# Perplexity for test sample 860 : 1535.980160092787
# Perplexity for test sample 861 : 1051.4774198189416
# Perplexity for test sample 862 : 1227.485883164797
# Perplexity for test sample 863 : 2675.4705370973197
# Perplexity for test sample 864 : 2233.953173736411
# Perplexity for test sample 865 : 929.9630400717444
# Perplexity for test sample 866 : 1209.3089202527403
# Perplexity for test sample 867 : 2208.9628231788956
# Perplexity for test sample 868 : 1156.450916839128
# Perplexity for test sample 869 : 1731.4756662466789
# Perplexity for test sample 870 : 1489.715791434017
# Perplexity for test sample 871 : 897.8537972751964
# Perplexity for test sample 872 : 697.4309546769869
# Perplexity for test sample 873 : 3243.1799942966263
# Perplexity for test sample 874 : 1514.0085665591307
# Perplexity for test sample 875 : 1315.449402079578
# Perplexity for test sample 876 : 1527.616380880189
# Perplexity for test sample 877 : 1026.6599677834076
# Perplexity for test sample 878 : 1004.055999583099
# Perplexity for test sample 879 : 1679.9178725526008
# Perplexity for test sample 880 : 377.41796604122345
# Perplexity for test sample 881 : 1452.8486201755609
# Perplexity for test sample 882 : 2815.0587269798225
# Perplexity for test sample 883 : 903.6742408923436
# Perplexity for test sample 884 : 1060.7636927078836
# Perplexity for test sample 885 : 1903.1724434145913
# Perplexity for test sample 886 : 1490.4529850161289
# Perplexity for test sample 887 : 1166.8575512609355
# Perplexity for test sample 888 : 1599.6527081045786
# Perplexity for test sample 889 : 1150.1118193312739
# Perplexity for test sample 890 : 1629.5166607595156
# Perplexity for test sample 891 : 1514.2063476150156
# Perplexity for test sample 892 : 518.3655534515356
# Perplexity for test sample 893 : 2492.6395203927627
# Perplexity for test sample 894 : 1192.953745270043
# Perplexity for test sample 895 : 6042.1448858851745
# Perplexity for test sample 896 : 2625.0910575194343
# Perplexity for test sample 897 : 2131.983719329589
# Perplexity for test sample 898 : 837.1234311802341
# Perplexity for test sample 899 : 4223.749763847216
# Perplexity for test sample 900 : 1593.0842268131746
# Perplexity for test sample 901 : 644.8099487538926
# Perplexity for test sample 902 : 1600.63776776288
# Perplexity for test sample 903 : 1167.7737733587312
# Perplexity for test sample 904 : 2581.272721481714
# Perplexity for test sample 905 : 1995.574316598588
# Perplexity for test sample 906 : 1567.2186813775738
# Perplexity for test sample 907 : 896.4171744743294
# Perplexity for test sample 908 : 1716.841686662443
# Perplexity for test sample 909 : 1264.440853134612
# Perplexity for test sample 910 : 696.6582680824341
# Perplexity for test sample 911 : 424.1761373338126
# Perplexity for test sample 912 : 484.60100058576637
# Perplexity for test sample 913 : 787.7007450636225
# Perplexity for test sample 914 : 1110.7463129395367
# Perplexity for test sample 915 : 1698.9919339692733
# Perplexity for test sample 916 : 1024.9721390916054
# Perplexity for test sample 917 : 1068.0578884866413
# Perplexity for test sample 918 : 76.13937400136908
# Perplexity for test sample 919 : 1556.5994359954268
# Perplexity for test sample 920 : 91.07391873307506
# Perplexity for test sample 921 : 775.2997045449988
# Perplexity for test sample 922 : 1483.7719817599184
# Perplexity for test sample 923 : 676.2847858945297
# Perplexity for test sample 924 : 1239.3226082043986
# Perplexity for test sample 925 : 1250.3677081042492
# Perplexity for test sample 926 : 2042.7248260654542
# Perplexity for test sample 927 : 2219.576783006675
# Perplexity for test sample 928 : 541.0285029157761
# Perplexity for test sample 929 : 627.0360202247933
# Perplexity for test sample 930 : 2890.871546285729
# Perplexity for test sample 931 : 1633.8554259129764
# Perplexity for test sample 932 : 332.8046544659314
# Perplexity for test sample 933 : 359.3328297169583
# Perplexity for test sample 934 : 424.38532121552333
# ...
# Perplexity for test sample 3903 : 2022.1939712068056
# Perplexity for test sample 3904 : 933.6712527791274
# Perplexity for test sample 3905 : 1442.6499275900562
# Perplexity for test sample 3906 : 1060.1486521498578
# Perplexity for test sample 3907 : 328.1778181553212
# Perplexity for test sample 3908 : 184.13046527743
# Perplexity for test sample 3909 : 801.1378488012022
# Perplexity for test sample 3910 : 243.08930446016132
# Perplexity for test sample 3911 : 1741.041636464278
# Perplexity for test sample 3912 : 2054.014876017508
# Perplexity for test sample 3913 : 1534.886185026987
# Perplexity for test sample 3914 : 975.536816611033
# Perplexity for test sample 3915 : 1520.97723301682
# Perplexity for test sample 3916 : 1510.7941528935567
# Perplexity for test sample 3917 : 443.4275999598458
# Perplexity for test sample 3918 : 2166.835692610725
# Perplexity for test sample 3919 : 2509.780082927378
# Perplexity for test sample 3920 : 1111.3409123505562
# Perplexity for test sample 3921 : 493.35478313456986
# Perplexity for test sample 3922 : 1101.0611607801068
# Perplexity for test sample 3923 : 1387.3937128675284
# Perplexity for test sample 3924 : 701.3844062845114
# Perplexity for test sample 3925 : 399.7592321090428
# Perplexity for test sample 3926 : 193.94697707094443
# Perplexity for test sample 3927 : 432.392868734902
# Perplexity for test sample 3928 : 393.1424276518544
# Perplexity for test sample 3929 : 1245.074936563409
# Perplexity for test sample 3930 : 1130.0784381168287
# Perplexity for test sample 3931 : 1039.8257795235452
# Perplexity for test sample 3932 : 335.0072721619622
# Perplexity for test sample 3933 : 246.9502847365003
# Perplexity for test sample 3934 : 141.44319434699656
# Perplexity for test sample 3935 : 587.8129229229758
# Perplexity for test sample 3936 : 494.01470310542106
# Perplexity for test sample 3937 : 695.3122879393213
# Perplexity for test sample 3938 : 694.759030892406
# Perplexity for test sample 3939 : 571.0044167899921
# Perplexity for test sample 3940 : 498.731475536633
# Perplexity for test sample 3941 : 712.2083048612891
# Perplexity for test sample 3942 : 810.3249451073426
# Perplexity for test sample 3943 : 577.0639616001156
# Perplexity for test sample 3944 : 1207.8887455859297
# Perplexity for test sample 3945 : 525.504249362169
# Perplexity for test sample 3946 : 833.2139918614666
# Perplexity for test sample 3947 : 744.3667374501832
# Perplexity for test sample 3948 : 245.46263554746656
# Perplexity for test sample 3949 : 443.6440932669732
# Perplexity for test sample 3950 : 278.87806512214553
# Perplexity for test sample 3951 : 2130.51845411503
# Perplexity for test sample 3952 : 899.5149757809593
# Perplexity for test sample 3953 : 1421.0145910906106
# Perplexity for test sample 3954 : 1083.0526509701438
# Perplexity for test sample 3955 : 506.584168541393
# Perplexity for test sample 3956 : 778.6687242588199
# Perplexity for test sample 3957 : 1936.0825976255817
# Perplexity for test sample 3958 : 502.4784591126937
# Perplexity for test sample 3959 : 1043.5403565183105
# Perplexity for test sample 3960 : 1010.6776373127717
# Perplexity for test sample 3961 : 3723.731245900672
# Perplexity for test sample 3962 : 669.3089012763074
# Perplexity for test sample 3963 : 205.19631662609416
# Perplexity for test sample 3964 : 2597.201540957264
# Perplexity for test sample 3965 : 2072.4013133474896
# Perplexity for test sample 3966 : 2577.523497704976
# Perplexity for test sample 3967 : 229.05554638933535
# Perplexity for test sample 3968 : 1231.9663439999983
# Perplexity for test sample 3969 : 1410.6293809977135
# Perplexity for test sample 3970 : 2744.1151445999794
# Perplexity for test sample 3971 : 2738.653518858215
# Perplexity for test sample 3972 : 5794.513911093169
# Perplexity for test sample 3973 : 290.51253012636056
# Perplexity for test sample 3974 : 896.5526771255124
# Perplexity for test sample 3975 : 777.931533602385
# Perplexity for test sample 3976 : 570.4340641197457
# Perplexity for test sample 3977 : 780.2610114631675
# Perplexity for test sample 3978 : 1383.8414476254052
# Perplexity for test sample 3979 : 1167.5393973795162
# Perplexity for test sample 3980 : 1295.042558684882
# Perplexity for test sample 3981 : 3926.874039915513
# Perplexity for test sample 3982 : 1305.6678814200063
# Perplexity for test sample 3983 : 504.1054104861466
# Perplexity for test sample 3984 : 940.0748267572885
# Perplexity for test sample 3985 : 1201.024746805019
# Perplexity for test sample 3986 : 2185.776880522934
# Perplexity for test sample 3987 : 2184.811844867267
# Perplexity for test sample 3988 : 983.2080510218842
# Perplexity for test sample 3989 : 264.4459255387938
# Perplexity for test sample 3990 : 1122.0618612723956
# Perplexity for test sample 3991 : 1621.5444802172196
# Perplexity for test sample 3992 : 887.7272629367416
# Perplexity for test sample 3993 : 741.8791009625567
# Perplexity for test sample 3994 : 369.0739164510721
# Perplexity for test sample 3995 : 1609.5529602551223
# Perplexity for test sample 3996 : 1543.2192314902366
# Perplexity for test sample 3997 : 565.7959357198456
# Perplexity for test sample 3998 : 2768.910448567865
# Perplexity for test sample 3999 : 585.4710605771093
# Perplexity for test sample 4000 : 1710.3318013806843
# Perplexity for test sample 4001 : 1649.2134148553462
# Perplexity for test sample 4002 : 586.2638742448264
# Perplexity for test sample 4003 : 1115.9777079117946
# Perplexity for test sample 4004 : 718.9015104348173
# Perplexity for test sample 4005 : 1203.0681354487367
# Perplexity for test sample 4006 : 2219.210768703732
# Perplexity for test sample 4007 : 764.0304253787758
# Perplexity for test sample 4008 : 1287.3229418705657
# Perplexity for test sample 4009 : 2486.2755808073284
# Perplexity for test sample 4010 : 2237.5603155770937
# Perplexity for test sample 4011 : 718.8948364849693
# Perplexity for test sample 4012 : 1067.598492055765
# Perplexity for test sample 4013 : 1042.4621076256105
# Perplexity for test sample 4014 : 259.45256349167784
# Perplexity for test sample 4015 : 399.6811028933415
# Perplexity for test sample 4016 : 212.71899444152493
# Perplexity for test sample 4017 : 399.6811028933415
# Perplexity for test sample 4018 : 378.5799437928145
# Perplexity for test sample 4019 : 572.3294956516276
# Perplexity for test sample 4020 : 293.5020693356308
# Perplexity for test sample 4021 : 82.65844465400002
# Perplexity for test sample 4022 : 282.59626961095927
# Perplexity for test sample 4023 : 270.44256557604655
# Perplexity for test sample 4024 : 370.74600106092873
# Perplexity for test sample 4025 : 284.59926331014435
# Perplexity for test sample 4026 : 818.6174979486494
# Perplexity for test sample 4027 : 855.6481067946715
# Perplexity for test sample 4028 : 1104.6814809002547
# Perplexity for test sample 4029 : 2221.80807749992
# Perplexity for test sample 4030 : 1088.9258127562407
# Perplexity for test sample 4031 : 2101.7298594087565
# Perplexity for test sample 4032 : 666.4617562975096
# Perplexity for test sample 4033 : 323.15513871994847
# Perplexity for test sample 4034 : 36.08325561884498
# Perplexity for test sample 4035 : 47.01492395478094
# Perplexity for test sample 4036 : 644.1534902951437
# Perplexity for test sample 4037 : 218.29294127090128
# Perplexity for test sample 4038 : 846.3648158499624
# Perplexity for test sample 4039 : 127.3814455523921
# Perplexity for test sample 4040 : 94.40446451772875
# Perplexity for test sample 4041 : 100.07325316820733
# Perplexity for test sample 4042 : 61.746018818935084
# Perplexity for test sample 4043 : 1531.7146553156847
# Perplexity for test sample 4044 : 793.8435022511071
# Perplexity for test sample 4045 : 3109.2580177465206
# Perplexity for test sample 4046 : 2525.7146300167346
# Perplexity for test sample 4047 : 952.6338522953743
# Perplexity for test sample 4048 : 1044.4960460149841
# Perplexity for test sample 4049 : 434.0454327783483
# Perplexity for test sample 4050 : 713.2672783397616
# Perplexity for test sample 4051 : 864.8378490258001
# Perplexity for test sample 4052 : 433.47513028956655
# Perplexity for test sample 4053 : 376.1978781646714
# Perplexity for test sample 4054 : 2342.9361401385963
# Perplexity for test sample 4055 : 960.2461465600649
# Perplexity for test sample 4056 : 329.47912119718785
# Perplexity for test sample 4057 : 1414.797755114474
# Perplexity for test sample 4058 : 1893.2887591438741
# Perplexity for test sample 4059 : 1425.7541937387628
# Perplexity for test sample 4060 : 1460.9625847644525
# Perplexity for test sample 4061 : 1434.419402591353
# Perplexity for test sample 4062 : 778.0015740847407
# Perplexity for test sample 4063 : 1938.9434956744121
# Perplexity for test sample 4064 : 545.8965331218407
# Perplexity for test sample 4065 : 496.9891837068834
# Perplexity for test sample 4066 : 693.1655559871526
# Perplexity for test sample 4067 : 678.0452283631141
# Perplexity for test sample 4068 : 1477.4826373946714
# Perplexity for test sample 4069 : 1603.7706772602078
# Perplexity for test sample 4070 : 2582.8958069499536
# Perplexity for test sample 4071 : 884.2422020560788
# Perplexity for test sample 4072 : 1793.059189187963
# Perplexity for test sample 4073 : 1420.920213745058
# Perplexity for test sample 4074 : 1380.734911993876
# Perplexity for test sample 4075 : 1095.1798010541713
# Perplexity for test sample 4076 : 583.1576032345085
# Perplexity for test sample 4077 : 2001.070725206656
# Perplexity for test sample 4078 : 659.2129842705467
# Perplexity for test sample 4079 : 1956.4501871887037
# Perplexity for test sample 4080 : 1151.78951488489
# Perplexity for test sample 4081 : 2135.93400028341
# Perplexity for test sample 4082 : 973.7690655346437
# Perplexity for test sample 4083 : 469.6466320711362
# Perplexity for test sample 4084 : 2135.829924512364
# Perplexity for test sample 4085 : 229.9840608011572
# Perplexity for test sample 4086 : 1278.4736092795647
# Perplexity for test sample 4087 : 451.036891904344
# Perplexity for test sample 4088 : 1341.53504275834
# Perplexity for test sample 4089 : 2511.6894896325953
# Perplexity for test sample 4090 : 856.0637543302508
# Perplexity for test sample 4091 : 781.1946610282395
# Perplexity for test sample 4092 : 439.7733515412018
# Perplexity for test sample 4093 : 1197.5589130736907
# Perplexity for test sample 4094 : 1119.2867395429812
# Perplexity for test sample 4095 : 1830.9731940189179
# Perplexity for test sample 4096 : 147.57426579397438
# Perplexity for test sample 4097 : 68.40920968057146
# Perplexity for test sample 4098 : 50.73914748990707
# Perplexity for test sample 4099 : 129.57903101934352
# Perplexity for test sample 4100 : 93.76142238812419
# Perplexity for test sample 4101 : 328.773717454244
# Perplexity for test sample 4102 : 2215.1075227103174
# Perplexity for test sample 4103 : 491.83639331428776
# Perplexity for test sample 4104 : 2669.368746857687
# Perplexity for test sample 4105 : 523.9626045718142
# Perplexity for test sample 4106 : 1927.083496531134
# Perplexity for test sample 4107 : 1016.9399611224038
# Perplexity for test sample 4108 : 1731.682235343132
# Perplexity for test sample 4109 : 904.4494236282956
# Perplexity for test sample 4110 : 1246.8329818930688
# Perplexity for test sample 4111 : 283.2976961910886
# Perplexity for test sample 4112 : 258.58637267285127
# Perplexity for test sample 4113 : 1072.5138644268168
# Perplexity for test sample 4114 : 802.3828132987927
# Perplexity for test sample 4115 : 553.3385159103876
# Perplexity for test sample 4116 : 189.19925184052116
# Perplexity for test sample 4117 : 2454.5889958512203
# Perplexity for test sample 4118 : 274.0512039406307
# Perplexity for test sample 4119 : 229.02491582119313
# Perplexity for test sample 4120 : 645.4492886084963
# Perplexity for test sample 4121 : 267.9172186321295
# Perplexity for test sample 4122 : 29.2317417314848
# Perplexity for test sample 4123 : 700.3681917219473
# Perplexity for test sample 4124 : 1578.1889714624338
# Perplexity for test sample 4125 : 184.66362581019735
# Perplexity for test sample 4126 : 357.06270562432337
# Perplexity for test sample 4127 : 1378.2050383851565
# Perplexity for test sample 4128 : 476.19749034458135
# Perplexity for test sample 4129 : 298.68243553540464
# Perplexity for test sample 4130 : 231.18170381141587
# Perplexity for test sample 4131 : 1769.994931908289
# Perplexity for test sample 4132 : 843.7796665784765
# Perplexity for test sample 4133 : 1341.0619157657604
# Perplexity for test sample 4134 : 311.8235082745908
# Perplexity for test sample 4135 : 1684.6886035512923
# Perplexity for test sample 4136 : 2195.214490811103
# Perplexity for test sample 4137 : 1781.6641841614112
# Perplexity for test sample 4138 : 2772.6576566515046
# Perplexity for test sample 4139 : 622.9382924054373
# Perplexity for test sample 4140 : 1229.3805887187082
# Perplexity for test sample 4141 : 782.8946194277669
# Perplexity for test sample 4142 : 559.6379469813506
# Perplexity for test sample 4143 : 500.72065821677705
# Perplexity for test sample 4144 : 1858.625230003411
# Perplexity for test sample 4145 : 2062.694136775294
# Perplexity for test sample 4146 : 442.29385533365536
# Perplexity for test sample 4147 : 1078.712359184109
# Perplexity for test sample 4148 : 437.0565243466907
# Perplexity for test sample 4149 : 751.7232439179686
# Perplexity for test sample 4150 : 677.3734483705947
# Perplexity for test sample 4151 : 916.007448650771
# Perplexity for test sample 4152 : 1582.4754551161052
# Perplexity for test sample 4153 : 1154.84573014304
# Perplexity for test sample 4154 : 172.29029338075205
# Perplexity for test sample 4155 : 495.09741801098045
# Perplexity for test sample 4156 : 1223.0284908550693
# Perplexity for test sample 4157 : 724.7320090540347
# Perplexity for test sample 4158 : 1503.5949658752436
# Perplexity for test sample 4159 : 591.9698657797222
# Perplexity for test sample 4160 : 969.6180164081939
# Perplexity for test sample 4161 : 980.004784624474
# Perplexity for test sample 4162 : 492.91842691357937
# Perplexity for test sample 4163 : 952.1107190923827
# Perplexity for test sample 4164 : 824.0243312945598
# Perplexity for test sample 4165 : 1340.6958067305668
# Perplexity for test sample 4166 : 949.1140418419491
# Perplexity for test sample 4167 : 2228.9644390208155
# Perplexity for test sample 4168 : 2190.116984666732
# Perplexity for test sample 4169 : 465.69931817573126
# Perplexity for test sample 4170 : 332.8046544659314
# Perplexity for test sample 4171 : 359.3328297169583
# Perplexity for test sample 4172 : 501.0339326868506
# Perplexity for test sample 4173 : 555.5845883111765
# Perplexity for test sample 4174 : 651.55590707348
# Perplexity for test sample 4175 : 208.60646307466118
# Perplexity for test sample 4176 : 1033.812715321892
# Perplexity for test sample 4177 : 480.03435684338143
# Perplexity for test sample 4178 : 516.5792948572353
# Perplexity for test sample 4179 : 1130.2637966062912
# Perplexity for test sample 4180 : 966.8837387170494
# Perplexity for test sample 4181 : 1641.0549478501143
# Perplexity for test sample 4182 : 185.042376938243
# Perplexity for test sample 4183 : 819.7307556910305
# Perplexity for test sample 4184 : 527.8028055525697
# Perplexity for test sample 4185 : 640.9907758234867
# Perplexity for test sample 4186 : 460.2262266980347
# Perplexity for test sample 4187 : 867.0280461620526
# Perplexity for test sample 4188 : 566.1271222874384
# Perplexity for test sample 4189 : 545.8124346723762
# Perplexity for test sample 4190 : 740.315544494902
# Perplexity for test sample 4191 : 296.1376628345603
# Perplexity for test sample 4192 : 585.4674622352636
# Perplexity for test sample 4193 : 1183.839743807474
# Perplexity for test sample 4194 : 960.6238612830562
# Perplexity for test sample 4195 : 986.3956664847703
# Perplexity for test sample 4196 : 1499.9139668730556
# Perplexity for test sample 4197 : 2212.466935414285
# Perplexity for test sample 4198 : 359.0045615482157
# Perplexity for test sample 4199 : 794.3451850094468
# Perplexity for test sample 4200 : 260.21166639497085
# Perplexity for test sample 4201 : 1002.9308773988696
# Perplexity for test sample 4202 : 520.0780989178642
# Perplexity for test sample 4203 : 1413.3193391159616
# Perplexity for test sample 4204 : 2493.9810388596993
# Perplexity for test sample 4205 : 887.8034972054771
# Perplexity for test sample 4206 : 889.5087864718247
# The average testing perplexity for count-based LM: 1184.6602509874976

# %% [markdown]
# ### Hyper-parameters for the neural language model

# %%
# FOR THE NEURAL MODEL
embed_size = 128
intermediate_size = 1024
num_epochs = 3
learning_rate = 1e-1

# %% [markdown]
# ### The class for the neural language model:

# %%
class NeuralLM(nn.Module):
    def __init__(self, vocab_size, embed_size, intermediate_size, m_gram):
        super(NeuralLM, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.intermediate = nn.Linear(m_gram * embed_size, intermediate_size)
        self.final = nn.Linear(intermediate_size, vocab_size)
        
    def forward(self, x):
        x = self.embed(x) # Embed word id(s) to vectors
        print(x)
        conc_emb = x.view(x.size(0), x.size(1)*x.size(2))
        intermediate_output = self.intermediate(conc_emb) # one layer of MLP
        intermediate_output = F.relu(intermediate_output) # ReLU non-linear function
        final_out = self.final(intermediate_output) # Map to the vocabulary size output
        return final_out
    
    # x is the context vector and output is the prob distrbution over all the tokens
    # use softmax to make everything into 1
    # choose word with highest probability
    # at each step make the modl take in the context x again that was generated previously
    # apply softmax to create a conditional distribution and take the argmax from that
    # do this iteratively until reaching the end of the sentence

# %%
neural_model = NeuralLM(vocab_size, embed_size, intermediate_size, m_gram).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(neural_model.parameters(), lr=learning_rate, momentum=0.9)

# %% [markdown]
# ### Train the neural model

# %%
# Reduce batch size if you are running out of memory
batch_size = 64
training_data = torch.cat(train_ids, dim=0)
neural_model.train()

for epoch in range(num_epochs):
    total_loss = 0
    for i in tqdm(range(0, len(training_data), batch_size)):
        batch = training_data[i:i + batch_size]
        inputs = batch[:, 0:n_gram-1].to(device)
        targets = batch[:, n_gram-1:].to(device)
        
        # Forward pass
        outputs = neural_model(inputs)
        loss = criterion(outputs, targets.reshape(-1))
        total_loss += loss.item();
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    
    # Calculate the performance (perplexity) of the current trained model on dev set.
    total_ppl = 0
    for i in range(0, len(dev_ids)):
        dev_inputs = dev_ids[i][:, 0:n_gram-1].to(device)
        dev_targets = dev_ids[i][:, n_gram-1:].to(device)
        dev_outputs = neural_model(dev_inputs)
        ce = criterion(dev_outputs, dev_targets.reshape(-1))
        total_ppl += np.exp(ce.item());
    
    print ('Epoch [{}/{}], Training Loss: {:.4f}, Dev Perplexity: {:5.2f}'
        .format(epoch + 1, num_epochs, total_loss/len(train_ids), total_ppl/len(dev_ids)))
# Out:
#   0%|          | 1/10910 [00:00<27:34,  6.59it/s]
# tensor([[[ 0.3366, -0.6849, -0.6231,  ...,  0.4395,  0.2915,  0.8121]],
#
#         [[-2.9914,  1.7914, -0.2272,  ..., -0.8930,  0.2622,  0.6680]],
#
#         [[ 0.2563,  0.6231,  0.0235,  ..., -0.1732,  1.9910,  0.6156]],
#
#         ...,
#
#         [[ 0.9145, -0.7784,  0.3912,  ..., -1.1965,  1.0594,  1.0600]],
#
#         [[-0.4304,  0.2398,  0.0237,  ..., -0.3762,  0.7208, -0.1786]],
#
#         [[ 0.2462,  0.7818, -0.2613,  ...,  0.8993,  0.1481, -0.9627]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 1.7959,  0.6012, -0.4454,  ...,  0.0339, -1.8028,  1.4657]],
#
#         [[-0.8503,  1.5785,  0.5406,  ...,  0.0375, -0.0828, -0.4686]],
#
#         [[-0.2936,  0.5210,  1.4298,  ...,  0.2086, -0.4422,  0.9478]],
#
#         ...,
#
#         [[ 0.3705, -0.4952,  0.4017,  ...,  0.6291,  0.8509, -1.6369]],
#
#         [[ 0.6665, -0.9370,  1.3804,  ..., -1.2028, -0.0238,  1.3010]],
#
#         [[ 0.4892,  0.5927, -0.0739,  ...,  0.6776, -0.3975, -1.1005]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2697,  0.2945, -1.2300,  ..., -1.4507, -0.4651, -0.3070]],
#
#         [[-1.4154, -1.7207, -0.1969,  ...,  0.7618, -0.8368,  0.6616]],
#
#         [[-0.1710, -0.4283,  0.4472,  ...,  0.4744,  0.7216, -1.7967]],
#
#         ...,
#
#         [[-0.0930,  0.1998,  1.2335,  ..., -0.9530, -0.2512,  0.3857]],
#
#         [[-1.4154, -1.7207, -0.1969,  ...,  0.7618, -0.8368,  0.6616]],
#
#         [[-0.1770, -1.5992, -1.7409,  ..., -1.2787, -0.3244,  1.0495]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 3/10910 [00:00<23:57,  7.59it/s]
# tensor([[[-1.7487, -0.1242,  0.7775,  ..., -1.2465, -1.2272,  0.9909]],
#
#         [[-1.1443, -0.5819, -0.2509,  ..., -0.3759, -0.4278,  0.4879]],
#
#         [[-1.4152, -1.7207, -0.1968,  ...,  0.7618, -0.8367,  0.6615]],
#
#         ...,
#
#         [[ 0.3361, -0.6847, -0.6231,  ...,  0.4395,  0.2912,  0.8119]],
#
#         [[-0.1149, -1.3540, -1.8638,  ..., -0.1145,  0.6369, -0.8028]],
#
#         [[-2.1575,  0.1363,  0.5428,  ...,  0.4330, -0.2222,  0.1070]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.3274, -2.0989,  1.3299,  ..., -0.2913,  1.3246,  0.8078]],
#
#         [[ 1.0870, -0.6926, -1.3763,  ..., -0.2518,  0.2096, -1.1757]],
#
#         [[-0.3789,  1.2668,  1.8092,  ...,  0.7507, -0.2402,  1.1666]],
#
#         ...,
#
#         [[-1.3094,  0.0925,  0.8392,  ...,  0.5384, -1.1800,  0.1376]],
#
#         [[-0.1798,  0.7391, -1.0055,  ..., -0.8215, -0.2188,  1.4452]],
#
#         [[-0.8567,  0.5846,  1.2398,  ..., -0.6659,  0.1959, -0.1028]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 7/10910 [00:00<20:02,  9.07it/s]
# tensor([[[-0.5325, -0.6321,  0.1193,  ...,  0.1317,  2.2458, -1.0840]],
#
#         [[-1.2288,  0.2436,  0.1553,  ...,  0.9258, -1.1570,  0.7287]],
#
#         [[ 0.3707, -0.4951,  0.4017,  ...,  0.6291,  0.8508, -1.6369]],
#
#         ...,
#
#         [[-1.1302, -1.1681, -0.5897,  ..., -0.5806, -1.7073,  0.4863]],
#
#         [[ 0.9243, -0.3556,  0.7373,  ...,  1.1951,  1.4302, -1.4401]],
#
#         [[ 0.3357, -0.6847, -0.6230,  ...,  0.4394,  0.2908,  0.8121]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.3097,  0.0927,  0.8392,  ...,  0.5386, -1.1805,  0.1375]],
#
#         [[-1.9502, -0.1188,  0.4771,  ...,  0.6775, -0.0453,  0.1683]],
#
#         [[-0.4307,  0.2399,  0.0236,  ..., -0.3761,  0.7204, -0.1785]],
#
#         ...,
#
#         [[ 1.4644,  0.0978, -2.8943,  ..., -1.3664, -1.6057,  2.5424]],
#
#         [[ 0.8015, -1.5560, -1.5362,  ...,  0.3195,  0.1219,  1.1461]],
#
#         [[ 0.6798,  0.1730, -0.3893,  ..., -0.7821, -1.1608, -1.3413]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.8105, -0.9236,  0.1356,  ..., -0.0756, -0.8766, -0.6263]],
#
#         [[-1.4128,  0.5755,  0.1929,  ..., -0.1363,  0.9334, -0.0753]],
#
#         [[-1.4814,  0.1256,  0.9724,  ...,  2.1989, -1.8752,  2.3682]],
#
#         ...,
#
#         [[-1.3344,  0.4436, -0.9242,  ...,  0.9765,  1.4197, -0.3395]],
#
#         [[-0.5327, -0.6319,  0.1195,  ...,  0.1315,  2.2460, -1.0841]],
#
#         [[-1.9566, -1.1313, -1.1719,  ..., -0.7370,  0.1669,  1.7168]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 9/10910 [00:00<18:58,  9.58it/s]
# tensor([[[ 0.8975,  0.8944,  2.0132,  ...,  0.3943, -1.6518, -0.0351]],
#
#         [[ 0.6607, -1.7268,  1.6045,  ...,  0.9735, -1.0114,  0.3943]],
#
#         [[-1.1306, -1.1679, -0.5893,  ..., -0.5805, -1.7078,  0.4862]],
#
#         ...,
#
#         [[-0.3244,  0.1470,  0.5059,  ...,  0.2186, -0.6072,  0.5297]],
#
#         [[-0.9940, -1.2286, -1.5375,  ..., -0.3707,  0.0296, -1.2057]],
#
#         [[-1.2376,  0.5106,  1.6851,  ...,  0.1223, -0.4911,  0.1709]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.0906,  1.2153,  1.3003,  ..., -1.3120,  0.3127, -1.0449]],
#
#         [[ 1.1525, -0.3100, -1.9362,  ...,  0.4026,  0.6406,  0.4583]],
#
#         [[-1.3081,  0.0928,  0.8386,  ...,  0.5388, -1.1803,  0.1370]],
#
#         ...,
#
#         [[-1.3081,  0.0928,  0.8386,  ...,  0.5388, -1.1803,  0.1370]],
#
#         [[-0.3650, -0.3804,  1.8045,  ..., -0.4678, -0.5419, -0.2934]],
#
#         [[-0.7926,  0.4279,  0.7042,  ...,  0.1936,  0.4994,  0.8285]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-2.4014,  0.0253, -0.4800,  ..., -0.6833,  0.2818,  1.0744]],
#
#         [[-1.7551,  0.4465, -1.4204,  ..., -1.4069,  1.0396, -0.0702]],
#
#         [[ 1.0046,  0.3149, -0.4239,  ..., -0.1479, -1.3809,  0.9395]],
#
#         ...,
#
#         [[ 0.3350, -0.6841, -0.6227,  ...,  0.4391,  0.2899,  0.8130]],
#
#         [[-0.2395,  0.7455,  1.8870,  ...,  0.3258,  1.0225,  0.5315]],
#
#         [[ 0.5386, -0.3484,  0.9828,  ...,  2.8717, -0.8848,  0.2360]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 13/10910 [00:01<17:39, 10.29it/s]
# tensor([[[ 0.3275, -2.0988,  1.3302,  ..., -0.2910,  1.3248,  0.8079]],
#
#         [[-0.4476, -0.3359, -0.5782,  ..., -0.7680,  0.4108,  0.2380]],
#
#         [[-0.3903, -0.3176,  0.1844,  ...,  0.0679,  0.3893,  0.1393]],
#
#         ...,
#
#         [[-0.5063,  0.0202, -1.6998,  ..., -1.5522,  1.2185,  0.4823]],
#
#         [[ 0.6746,  0.7821, -0.1496,  ...,  0.5787,  0.5020, -0.3163]],
#
#         [[-0.9819, -0.2607,  0.3725,  ...,  0.9188,  0.1192,  0.5857]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.3385, -0.1735,  0.0464,  ...,  1.8719,  0.6370, -0.4785]],
#
#         [[-1.4798,  0.1253,  0.9716,  ...,  2.1980, -1.8745,  2.3657]],
#
#         [[-0.0527,  0.5852,  2.3677,  ...,  0.8098, -1.0011,  1.2449]],
#
#         ...,
#
#         [[ 1.0101,  0.5083,  1.6106,  ...,  0.6336,  1.4291, -0.5343]],
#
#         [[-0.9877,  0.4370,  0.4655,  ...,  1.3071,  0.3887, -0.6337]],
#
#         [[ 0.6470,  0.7603,  0.4534,  ..., -0.1140,  1.1576, -0.9588]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 15/10910 [00:01<17:04, 10.63it/s]
# tensor([[[-1.1253, -1.1665, -0.5874,  ..., -0.5787, -1.7043,  0.4806]],
#
#         [[ 1.1521, -0.3098, -1.9368,  ...,  0.4030,  0.6402,  0.4584]],
#
#         [[-0.3847,  0.7212,  0.0925,  ..., -0.2116,  1.3481,  0.7272]],
#
#         ...,
#
#         [[-1.0448,  0.5540, -0.3509,  ..., -0.2210,  0.9196, -2.5127]],
#
#         [[ 1.4649,  0.0982, -2.8951,  ..., -1.3671, -1.6064,  2.5433]],
#
#         [[ 1.0100,  0.5084,  1.6106,  ...,  0.6335,  1.4289, -0.5343]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.9886, -0.4317,  0.1063,  ...,  0.4561,  0.0093,  0.1192]],
#
#         [[ 0.6154,  0.1264,  0.1270,  ..., -0.2527,  0.9260,  0.6128]],
#
#         [[-1.4149, -1.7207, -0.1973,  ...,  0.7615, -0.8370,  0.6597]],
#
#         ...,
#
#         [[ 0.0755, -1.1357, -1.0940,  ..., -2.0204,  0.0240, -1.4677]],
#
#         [[-0.4596, -0.4592, -0.1535,  ...,  0.2921, -0.0686, -1.9050]],
#
#         [[-2.7279, -1.0845, -0.8919,  ..., -1.2057, -2.0289, -0.6976]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.5454,  0.7135, -0.5335,  ...,  0.2648, -1.2976,  0.1959]],
#
#         [[ 0.0145, -1.1108,  3.0209,  ...,  0.6856,  1.5461, -1.5950]],
#
#         [[ 0.5383, -0.3482,  0.9828,  ...,  2.8710, -0.8849,  0.2359]],
#
#         ...,
#
#         [[-0.5329, -0.6315,  0.1198,  ...,  0.1318,  2.2461, -1.0840]],
#
#         [[ 1.4253,  0.1973,  1.6867,  ...,  2.0209, -0.8192, -1.8089]],
#
#         [[ 0.0238, -0.0366,  0.3689,  ...,  0.2151, -1.6335,  0.3031]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 17/10910 [00:01<16:50, 10.78it/s]
# tensor([[[-1.2976,  0.0924,  0.8351,  ...,  0.5388, -1.1773,  0.1365]],
#
#         [[ 0.1326, -0.0871,  2.5296,  ...,  1.0864, -0.4762, -0.6303]],
#
#         [[ 1.0418, -1.0451, -1.1479,  ...,  0.9300, -0.7086,  2.0325]],
#
#         ...,
#
#         [[-1.5734, -0.0648, -1.5663,  ...,  0.3925,  0.2446, -0.8065]],
#
#         [[ 1.3917, -0.8673, -0.1984,  ..., -0.5217, -0.2081,  1.0591]],
#
#         [[-0.9353,  0.4506, -0.7668,  ..., -1.0178,  1.8601, -1.2289]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.4039, -0.1857, -1.1765,  ...,  1.0066,  2.5936, -0.8383]],
#
#         [[-0.4287,  0.2401,  0.0238,  ..., -0.3783,  0.7174, -0.1782]],
#
#         [[-1.2969,  0.0924,  0.8348,  ...,  0.5390, -1.1771,  0.1364]],
#
#         ...,
#
#         [[-0.3838,  0.7198,  0.0917,  ..., -0.2115,  1.3467,  0.7252]],
#
#         [[-1.3312,  0.1562,  0.0621,  ...,  0.4931, -1.3059, -1.0332]],
#
#         [[ 0.3364, -0.6809, -0.6216,  ...,  0.4378,  0.2884,  0.8085]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.8730, -2.1812,  0.0928,  ..., -1.1163,  1.3829,  1.9702]],
#
#         [[ 1.0208, -0.6842, -0.9060,  ...,  0.5714,  0.2060,  0.5591]],
#
#         [[-1.1215, -1.1666, -0.5870,  ..., -0.5766, -1.7013,  0.4754]],
#
#         ...,
#
#         [[ 0.9126,  1.2837,  0.2737,  ...,  1.6643,  1.6313, -1.6267]],
#
#         [[-0.5328, -0.6312,  0.1202,  ...,  0.1317,  2.2458, -1.0838]],
#
#         [[-0.2830,  1.2636, -0.4284,  ..., -0.5801,  1.4984, -0.5589]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 21/10910 [00:01<16:26, 11.04it/s]
# tensor([[[-1.2962,  0.0925,  0.8343,  ...,  0.5395, -1.1769,  0.1363]],
#
#         [[-1.0585, -0.2090,  0.1060,  ..., -0.1784, -0.3843, -0.9810]],
#
#         [[ 1.1519, -0.3095, -1.9372,  ...,  0.4039,  0.6398,  0.4589]],
#
#         ...,
#
#         [[-0.1777,  0.6066, -0.4838,  ..., -0.6211,  0.7047,  0.4590]],
#
#         [[-0.5328, -0.6311,  0.1203,  ...,  0.1317,  2.2457, -1.0837]],
#
#         [[-1.3949, -1.2906, -0.8457,  ...,  1.5127,  0.7468, -0.0253]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.7436, -0.5201, -0.9459,  ...,  0.8549, -0.5941, -1.9359]],
#
#         [[ 1.7037,  0.2484,  0.0684,  ...,  0.7077, -0.4031, -1.2684]],
#
#         [[-0.4281,  0.2402,  0.0232,  ..., -0.3788,  0.7164, -0.1780]],
#
#         ...,
#
#         [[ 0.1223,  0.7648,  0.3236,  ..., -0.7039, -0.4317,  0.1626]],
#
#         [[-0.2912,  0.7668,  1.1776,  ...,  0.0075, -1.2565,  2.1229]],
#
#         [[-0.1778, -1.7999,  1.3179,  ..., -1.4480,  0.1161, -0.9392]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-2.0182,  0.3460,  0.0970,  ..., -1.0143, -0.7660, -0.7583]],
#
#         [[ 0.1223,  0.7649,  0.3236,  ..., -0.7039, -0.4316,  0.1626]],
#
#         [[ 0.3393, -0.6807, -0.6236,  ...,  0.4381,  0.2885,  0.8079]],
#
#         ...,
#
#         [[ 1.1519, -0.3095, -1.9370,  ...,  0.4041,  0.6397,  0.4588]],
#
#         [[ 1.6168, -0.2491, -0.3373,  ...,  1.2598,  0.7541, -0.5219]],
#
#         [[ 0.3393, -0.6807, -0.6236,  ...,  0.4381,  0.2885,  0.8079]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 23/10910 [00:02<16:42, 10.86it/s]
# tensor([[[-0.2786,  0.1763, -1.4993,  ..., -2.0164,  0.0100,  0.7242]],
#
#         [[ 0.3952, -2.2033,  0.5197,  ...,  0.9356,  1.0217, -0.5435]],
#
#         [[-1.1195, -1.1667, -0.5870,  ..., -0.5760, -1.6999,  0.4727]],
#
#         ...,
#
#         [[ 0.0179,  0.8786, -0.1268,  ...,  0.3850, -0.6146,  0.6272]],
#
#         [[ 1.3429, -1.4739,  1.9608,  ...,  1.4718, -0.3162,  1.0439]],
#
#         [[-0.3826,  0.7185,  0.0913,  ..., -0.2113,  1.3462,  0.7242]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.5542,  0.0699, -0.3386,  ...,  1.3398, -0.6031, -0.7083]],
#
#         [[-0.5329, -0.6309,  0.1206,  ...,  0.1316,  2.2444, -1.0831]],
#
#         [[-0.2649, -0.4421, -0.1974,  ..., -0.4103,  0.6432, -1.4499]],
#
#         ...,
#
#         [[ 0.3412, -0.6808, -0.6258,  ...,  0.4388,  0.2887,  0.8082]],
#
#         [[-0.5329, -0.6309,  0.1206,  ...,  0.1316,  2.2444, -1.0831]],
#
#         [[-1.2945,  0.0923,  0.8337,  ...,  0.5402, -1.1764,  0.1364]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.0763, -0.4954, -1.2449,  ...,  1.1131,  0.8463,  1.7990]],
#
#         [[ 0.2352, -0.4225, -0.3804,  ...,  0.1078,  1.9238,  1.0156]],
#
#         [[-1.4137, -1.7208, -0.1992,  ...,  0.7617, -0.8362,  0.6576]],
#
#         ...,
#
#         [[-0.2914,  0.7666,  1.1772,  ...,  0.0079, -1.2569,  2.1234]],
#
#         [[ 3.1673,  0.4593, -0.7769,  ..., -0.2033, -0.0681,  0.3763]],
#
#         [[ 1.3980, -1.1898, -1.1144,  ...,  1.5332, -2.0343,  0.6441]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 25/10910 [00:02<16:26, 11.04it/s]
# tensor([[[ 1.3784, -0.8424,  0.2761,  ..., -0.3649,  1.2024,  0.0050]],
#
#         [[ 0.0265, -0.4193,  1.5628,  ...,  0.7692,  1.6050,  0.5189]],
#
#         [[-0.5335, -0.6307,  0.1205,  ...,  0.1312,  2.2423, -1.0819]],
#
#         ...,
#
#         [[-1.1183, -1.1668, -0.5882,  ..., -0.5767, -1.7002,  0.4719]],
#
#         [[-1.4135, -1.7208, -0.1995,  ...,  0.7616, -0.8363,  0.6576]],
#
#         [[-1.2940,  0.0920,  0.8334,  ...,  0.5405, -1.1760,  0.1358]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.7801, -0.3130,  0.5125,  ..., -0.6557,  0.5081, -2.4534]],
#
#         [[ 0.4682,  1.5845,  0.1472,  ..., -0.9012, -1.4850,  1.8205]],
#
#         [[-1.1180, -1.1670, -0.5891,  ..., -0.5773, -1.7007,  0.4721]],
#
#         ...,
#
#         [[-2.0149,  0.3452,  0.0978,  ..., -1.0143, -0.7678, -0.7577]],
#
#         [[-0.0199, -0.8522, -1.8343,  ..., -1.0013,  0.0782, -2.4833]],
#
#         [[ 1.4610,  0.0952, -2.8919,  ..., -1.3641, -1.6049,  2.5385]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 29/10910 [00:02<15:41, 11.56it/s]
# tensor([[[-0.3821,  0.7173,  0.0914,  ..., -0.2109,  1.3456,  0.7240]],
#
#         [[-1.1178, -1.1673, -0.5903,  ..., -0.5778, -1.7013,  0.4722]],
#
#         [[-0.2457,  1.5274, -0.0118,  ...,  0.0246, -0.7915,  1.1356]],
#
#         ...,
#
#         [[-0.1704, -0.4285,  0.4479,  ...,  0.4740,  0.7203, -1.7959]],
#
#         [[ 1.0750,  1.2956,  1.0157,  ...,  0.0673, -0.5767, -0.9832]],
#
#         [[ 1.4596,  0.0944, -2.8908,  ..., -1.3634, -1.6045,  2.5371]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2801, -0.9153,  2.5773,  ...,  1.4976, -0.8364, -0.1284]],
#
#         [[-0.5339, -0.6307,  0.1202,  ...,  0.1312,  2.2400, -1.0807]],
#
#         [[-1.1174, -1.1673, -0.5913,  ..., -0.5783, -1.7018,  0.4726]],
#
#         ...,
#
#         [[-0.9941, -1.2281, -1.5371,  ..., -0.3697,  0.0293, -1.2054]],
#
#         [[-2.0538, -0.1523,  0.5200,  ..., -0.6917, -0.6974,  1.2826]],
#
#         [[-0.3821,  0.7171,  0.0915,  ..., -0.2108,  1.3454,  0.7242]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.3636,  1.0789, -0.6340,  ..., -0.4908,  1.1386, -0.6691]],
#
#         [[-1.1175, -1.1676, -0.5922,  ..., -0.5791, -1.7025,  0.4730]],
#
#         [[ 1.2684, -1.2875,  1.3762,  ..., -0.1748, -0.4788,  0.4894]],
#
#         ...,
#
#         [[-1.2943,  0.0914,  0.8332,  ...,  0.5415, -1.1754,  0.1343]],
#
#         [[ 0.7589, -0.2880, -1.1210,  ..., -1.0297, -1.3485,  0.0068]],
#
#         [[-0.5341, -0.6308,  0.1200,  ...,  0.1315,  2.2397, -1.0806]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 31/10910 [00:02<15:18, 11.84it/s]
# tensor([[[-2.1486, -0.6268, -0.8674,  ..., -0.1664,  0.2819, -2.3964]],
#
#         [[ 0.0139,  0.2325, -0.9079,  ...,  0.3686,  0.0674,  1.1910]],
#
#         [[ 0.1685,  1.7012, -0.2518,  ..., -0.0978, -0.5045,  0.9856]],
#
#         ...,
#
#         [[-0.3534,  1.2900, -0.3687,  ...,  0.8138, -0.3317, -1.3838]],
#
#         [[-0.3895, -1.4889,  0.0049,  ..., -1.0076, -2.7434,  0.0147]],
#
#         [[-1.4709,  0.1257,  0.9623,  ...,  2.1919, -1.8703,  2.3594]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-2.0129,  0.3454,  0.0986,  ..., -1.0141, -0.7686, -0.7579]],
#
#         [[-1.7116,  1.1476, -0.4428,  ...,  0.1034,  0.5390,  0.5377]],
#
#         [[ 0.3407, -1.4163,  0.7184,  ..., -2.6509,  0.5388, -0.8170]],
#
#         ...,
#
#         [[-0.0183, -2.5890, -0.0039,  ..., -1.6066, -0.5304, -0.3028]],
#
#         [[ 0.5355, -0.3501,  0.9811,  ...,  2.8659, -0.8849,  0.2364]],
#
#         [[-0.8223, -0.4533, -0.9619,  ...,  0.2304, -0.1204,  0.2492]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.6174,  0.9368, -1.8721,  ..., -0.0893,  0.4260,  1.1205]],
#
#         [[ 0.0949,  0.9613, -0.6638,  ..., -0.3901, -0.1113,  1.3677]],
#
#         [[-2.0127,  0.3458,  0.0991,  ..., -1.0141, -0.7687, -0.7583]],
#
#         ...,
#
#         [[-1.2949,  0.0909,  0.8328,  ...,  0.5425, -1.1753,  0.1334]],
#
#         [[-0.2862, -0.7648, -1.2808,  ..., -0.1540, -0.6797, -0.8891]],
#
#         [[ 0.8318,  0.3612,  0.8539,  ...,  0.1029,  1.0338,  0.8636]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 35/10910 [00:03<15:26, 11.74it/s]
# tensor([[[ 0.9214,  0.2364,  0.5447,  ...,  0.1730, -2.2118,  1.0158]],
#
#         [[ 0.0793,  1.0789,  0.3845,  ...,  1.0450, -0.1164,  0.1262]],
#
#         [[-1.2948,  0.0908,  0.8325,  ...,  0.5425, -1.1754,  0.1332]],
#
#         ...,
#
#         [[ 0.5278, -0.4038, -0.9401,  ..., -0.2126, -0.0272, -0.2954]],
#
#         [[ 0.2169,  1.1271, -1.1634,  ...,  0.0164, -1.4045, -0.2381]],
#
#         [[ 1.1820, -0.6793, -0.8764,  ...,  0.6045, -0.4679, -0.4667]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2575, -1.9963, -0.4651,  ..., -1.0807,  1.1406,  0.5239]],
#
#         [[ 0.2170,  1.1271, -1.1633,  ...,  0.0167, -1.4047, -0.2381]],
#
#         [[ 0.5348, -0.3508,  0.9805,  ...,  2.8651, -0.8851,  0.2364]],
#
#         ...,
#
#         [[-1.4680,  0.1259,  0.9601,  ...,  2.1890, -1.8684,  2.3549]],
#
#         [[ 0.7975,  1.7687, -1.2404,  ..., -0.7026, -0.5042,  0.8329]],
#
#         [[-1.7219,  0.2663,  0.3497,  ..., -0.8322, -0.5400,  0.4097]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.9404,  0.9670, -0.8781,  ..., -0.2163, -0.5071, -0.4181]],
#
#         [[-0.1870, -1.8045,  1.3223,  ..., -1.4506,  0.1097, -0.9393]],
#
#         [[-2.0136,  0.3476,  0.1015,  ..., -1.0146, -0.7690, -0.7609]],
#
#         ...,
#
#         [[-0.1870, -1.8045,  1.3223,  ..., -1.4506,  0.1097, -0.9393]],
#
#         [[-2.0136,  0.3476,  0.1015,  ..., -1.0146, -0.7690, -0.7609]],
#
#         [[-1.4674,  0.1259,  0.9597,  ...,  2.1883, -1.8679,  2.3541]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 37/10910 [00:03<15:19, 11.82it/s]
# tensor([[[-2.0141,  0.3478,  0.1020,  ..., -1.0146, -0.7693, -0.7610]],
#
#         [[ 0.3429, -0.6802, -0.6245,  ...,  0.4361,  0.2915,  0.7962]],
#
#         [[ 0.3821,  0.7688, -0.4335,  ...,  2.1023,  0.2948,  0.3241]],
#
#         ...,
#
#         [[ 1.4241,  0.0056, -0.8531,  ..., -0.4702,  0.2219, -0.6607]],
#
#         [[ 0.4800, -0.1770,  0.7895,  ...,  0.3541, -1.7287,  1.0499]],
#
#         [[ 0.3402, -1.4154,  0.7171,  ..., -2.6488,  0.5390, -0.8153]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.5324,  1.0633, -0.7857,  ...,  0.5494, -0.4940, -0.4199]],
#
#         [[ 0.2572, -1.9964, -0.4651,  ..., -1.0800,  1.1407,  0.5240]],
#
#         [[ 0.3822,  0.7688, -0.4336,  ...,  2.1024,  0.2950,  0.3242]],
#
#         ...,
#
#         [[-2.0145,  0.3482,  0.1025,  ..., -1.0146, -0.7699, -0.7611]],
#
#         [[-2.0145,  0.3482,  0.1025,  ..., -1.0146, -0.7699, -0.7611]],
#
#         [[ 0.3428, -0.6801, -0.6240,  ...,  0.4363,  0.2917,  0.7956]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2181,  1.1279, -1.1625,  ...,  0.0173, -1.4057, -0.2391]],
#
#         [[ 0.5338, -0.3516,  0.9792,  ...,  2.8641, -0.8851,  0.2363]],
#
#         [[ 0.0380,  0.8720, -2.6303,  ...,  0.0137,  0.7368,  0.5974]],
#
#         ...,
#
#         [[ 0.7494,  1.2297,  1.4461,  ..., -0.4734, -0.4471, -0.2416]],
#
#         [[ 1.5140,  0.2261,  0.6279,  ...,  0.8591, -0.4976,  0.1786]],
#
#         [[-1.4675,  0.1237,  0.9604,  ...,  2.1874, -1.8675,  2.3516]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 41/10910 [00:03<15:12, 11.91it/s]
# tensor([[[-1.2932,  0.0905,  0.8295,  ...,  0.5418, -1.1750,  0.1322]],
#
#         [[ 0.2664, -1.0219,  0.9134,  ..., -1.2102, -0.2219, -1.1908]],
#
#         [[-1.4115, -1.7177, -0.2026,  ...,  0.7601, -0.8389,  0.6599]],
#
#         ...,
#
#         [[-1.4115, -1.7177, -0.2026,  ...,  0.7601, -0.8389,  0.6599]],
#
#         [[ 0.9151, -0.7785,  0.3361,  ..., -0.0338, -0.4899, -0.8331]],
#
#         [[-0.5966,  0.2371,  1.6299,  ...,  0.3950, -0.3931, -0.4894]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.4357,  0.2374,  0.0308,  ..., -0.3756,  0.7178, -0.1793]],
#
#         [[-1.7478, -0.1234,  0.7768,  ..., -1.2438, -1.2245,  0.9905]],
#
#         [[-0.5240, -0.4805, -0.0283,  ...,  0.4825,  0.8320,  0.3304]],
#
#         ...,
#
#         [[-1.0515,  0.4501,  1.5516,  ..., -0.2796,  0.0650,  0.7009]],
#
#         [[ 1.1088,  0.5582,  0.0172,  ...,  0.0747,  0.3716, -0.6467]],
#
#         [[ 1.1814, -0.6797, -0.8773,  ...,  0.6046, -0.4677, -0.4659]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.5350, -0.6319,  0.1180,  ...,  0.1345,  2.2377, -1.0790]],
#
#         [[-1.1266,  0.2608, -1.4124,  ..., -0.1710,  0.3667,  0.0634]],
#
#         [[ 1.0940,  0.0620,  2.1407,  ..., -0.0897,  0.0243, -1.9476]],
#
#         ...,
#
#         [[-3.3011,  0.0076,  0.5565,  ...,  0.9505, -1.0052, -1.7821]],
#
#         [[ 0.5725, -0.1601, -0.5716,  ..., -0.9294,  0.2263, -1.4955]],
#
#         [[ 0.0149, -0.2167,  1.1347,  ..., -1.7827,  1.2533, -0.0693]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 43/10910 [00:03<15:23, 11.77it/s]
# tensor([[[-0.5353, -0.6321,  0.1178,  ...,  0.1347,  2.2370, -1.0787]],
#
#         [[-1.2923,  0.0901,  0.8278,  ...,  0.5417, -1.1755,  0.1320]],
#
#         [[ 0.2848,  0.9092,  0.4567,  ...,  0.4454, -0.1327, -1.3281]],
#
#         ...,
#
#         [[-0.1689, -0.4277,  0.4485,  ...,  0.4733,  0.7191, -1.7949]],
#
#         [[ 1.0732,  1.2943,  1.0180,  ...,  0.0677, -0.5780, -0.9836]],
#
#         [[-0.7057,  1.7453, -0.6819,  ..., -0.3317,  0.0789,  1.5492]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.1384, -0.3847,  0.0209,  ...,  0.1999, -0.4583,  0.2915]],
#
#         [[-0.2459,  0.3900, -0.3527,  ..., -1.1251, -1.7276, -0.5068]],
#
#         [[-0.4363,  0.2379,  0.0332,  ..., -0.3750,  0.7195, -0.1804]],
#
#         ...,
#
#         [[-2.0135,  0.3496,  0.1021,  ..., -1.0134, -0.7722, -0.7594]],
#
#         [[-0.0144, -0.9683,  0.0722,  ..., -0.0472,  3.4144,  2.0140]],
#
#         [[-1.9448, -0.5700,  1.0743,  ..., -0.5264, -2.3148, -0.4716]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.0147, -0.2169,  1.1344,  ..., -1.7824,  1.2532, -0.0693]],
#
#         [[ 1.4257,  0.7221,  0.5421,  ..., -0.0863,  0.1931,  1.7834]],
#
#         [[ 0.6477,  0.8348,  0.0193,  ...,  0.7187,  0.1687, -2.4828]],
#
#         ...,
#
#         [[-1.1093, -1.1670, -0.5947,  ..., -0.5809, -1.6944,  0.4694]],
#
#         [[ 1.4959,  2.1985, -0.3539,  ..., -0.2551, -0.4814, -0.5591]],
#
#         [[ 0.3916, -0.9994,  0.4842,  ...,  0.4134, -0.7904, -2.8777]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 45/10910 [00:03<15:31, 11.66it/s]
# tensor([[[-0.5360, -0.6327,  0.1177,  ...,  0.1356,  2.2353, -1.0783]],
#
#         [[-0.3776,  1.5962, -0.7180,  ...,  2.7065, -0.9556,  1.2236]],
#
#         [[-0.1216,  1.9673,  0.1818,  ..., -0.0196, -1.2121, -0.6637]],
#
#         ...,
#
#         [[-0.5360, -0.6327,  0.1177,  ...,  0.1356,  2.2353, -1.0783]],
#
#         [[-1.1267,  0.2607, -1.4123,  ..., -0.1711,  0.3668,  0.0634]],
#
#         [[ 0.6556,  0.4193, -0.1408,  ..., -1.1677, -0.3884, -0.8640]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.5544,  0.9279, -0.8634,  ..., -2.2416,  1.0415, -1.5713]],
#
#         [[-0.4365,  0.2376,  0.0341,  ..., -0.3752,  0.7200, -0.1804]],
#
#         [[ 0.6703, -1.1339,  1.3067,  ...,  0.8043,  0.1352, -1.6883]],
#
#         ...,
#
#         [[-0.2406,  0.0430,  0.7074,  ..., -0.4696, -0.1731,  1.9606]],
#
#         [[-1.4114, -1.7144, -0.2029,  ...,  0.7595, -0.8376,  0.6603]],
#
#         [[ 1.4959,  2.1982, -0.3536,  ..., -0.2550, -0.4814, -0.5589]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 47/10910 [00:04<17:04, 10.61it/s]
# tensor([[[-0.9836, -0.4238, -1.5968,  ...,  1.0070,  0.0884,  0.4717]],
#
#         [[-0.5370, -0.6330,  0.1167,  ...,  0.1346,  2.2328, -1.0765]],
#
#         [[ 0.9495,  0.4841, -0.4124,  ...,  0.4645, -0.6300,  1.1749]],
#
#         ...,
#
#         [[-0.3261,  0.9897,  0.0200,  ...,  0.3426, -0.9924,  2.1374]],
#
#         [[-0.4368,  0.2371,  0.0337,  ..., -0.3756,  0.7198, -0.1800]],
#
#         [[ 0.9420,  0.9674, -0.8787,  ..., -0.2158, -0.5076, -0.4179]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.1907, -1.8057,  1.3239,  ..., -1.4507,  0.1067, -0.9387]],
#
#         [[-2.0108,  0.3468,  0.1002,  ..., -1.0119, -0.7710, -0.7535]],
#
#         [[-1.4113, -1.7142, -0.2025,  ...,  0.7595, -0.8374,  0.6600]],
#
#         ...,
#
#         [[-1.7033,  0.3105, -0.3341,  ..., -1.0807,  0.9461, -0.4973]],
#
#         [[-1.5688,  0.3264,  2.0595,  ..., -1.3385,  0.2040, -2.1558]],
#
#         [[-0.3599, -0.3330,  0.2898,  ..., -2.8255,  1.4637, -0.8293]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 49/10910 [00:04<18:03, 10.03it/s]
# tensor([[[-0.7394,  1.1963,  1.6066,  ..., -0.2736, -0.7437,  0.0937]],
#
#         [[-1.1073, -1.1676, -0.5951,  ..., -0.5799, -1.6928,  0.4696]],
#
#         [[-0.4903,  0.9073,  1.5035,  ..., -0.0374, -1.4419,  0.0819]],
#
#         ...,
#
#         [[-0.1684, -0.4274,  0.4476,  ...,  0.4731,  0.7181, -1.7937]],
#
#         [[-1.4111, -1.7141, -0.2023,  ...,  0.7595, -0.8374,  0.6598]],
#
#         [[-0.4455, -2.2356, -1.4101,  ...,  0.7077,  0.8444, -0.1567]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 1.4958,  2.1978, -0.3534,  ..., -0.2549, -0.4817, -0.5584]],
#
#         [[-2.0095,  0.3459,  0.1000,  ..., -1.0118, -0.7704, -0.7520]],
#
#         [[-0.3621, -1.4303,  0.4052,  ...,  0.5295,  0.2181, -0.0519]],
#
#         ...,
#
#         [[ 0.0029, -0.0254, -0.4320,  ..., -2.2688,  0.2658,  1.1635]],
#
#         [[ 1.8880, -0.3027,  1.0860,  ..., -1.5946,  1.3908, -0.0935]],
#
#         [[ 2.0124,  1.7649,  0.5561,  ..., -0.5989,  1.6154, -1.7085]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 52/10910 [00:04<19:57,  9.07it/s]
# tensor([[[ 0.5457,  0.7128, -0.5352,  ...,  0.2656, -1.3014,  0.1993]],
#
#         [[-0.1911, -1.8059,  1.3240,  ..., -1.4507,  0.1064, -0.9387]],
#
#         [[-2.0088,  0.3457,  0.1002,  ..., -1.0116, -0.7704, -0.7521]],
#
#         ...,
#
#         [[ 0.1118,  0.0816, -0.7791,  ...,  0.4821, -1.4997, -1.2364]],
#
#         [[-0.7437,  0.6251, -1.4483,  ...,  0.0138, -1.5243,  1.1959]],
#
#         [[-0.5380, -0.6332,  0.1142,  ...,  0.1319,  2.2283, -1.0730]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.6411, -1.1480,  0.0373,  ..., -0.4259,  1.3181, -0.1491]],
#
#         [[-1.2918,  0.0899,  0.8239,  ...,  0.5413, -1.1752,  0.1308]],
#
#         [[ 1.0428, -1.0439, -1.1472,  ...,  0.9273, -0.7078,  2.0327]],
#
#         ...,
#
#         [[-0.2395,  0.0437,  0.7075,  ..., -0.4708, -0.1723,  1.9615]],
#
#         [[-0.4383,  0.2346,  0.0311,  ..., -0.3771,  0.7174, -0.1774]],
#
#         [[-1.2918,  0.0899,  0.8239,  ...,  0.5413, -1.1752,  0.1308]]],
#        grad_fn=<EmbeddingBackward0>)
#   0%|          | 54/10910 [00:05<21:07,  8.57it/s]
# tensor([[[-0.5796, -0.0049,  1.4896,  ...,  0.9538,  0.4636, -0.9959]],
#
#         [[ 0.5314, -0.3533,  0.9757,  ...,  2.8616, -0.8863,  0.2361]],
#
#         [[ 0.9632,  0.6510,  0.8851,  ..., -0.4336, -1.1024,  0.8171]],
#
#         ...,
#
#         [[-0.0210,  0.0390,  0.2081,  ..., -0.9132, -0.0976, -0.0746]],
#
#         [[-1.7260, -0.8500,  0.3810,  ...,  0.4279,  1.2229, -0.3605]],
#
#         [[ 0.8470, -1.1697, -0.6963,  ..., -0.3969, -0.9894,  2.1150]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.3940, -1.2902, -0.8474,  ...,  1.5131,  0.7448, -0.0250]],
#
#         [[-1.8586, -0.1420,  0.0444,  ...,  0.6427, -1.6349,  0.4560]],
#
#         [[ 0.5461,  0.7127, -0.5353,  ...,  0.2654, -1.3017,  0.1996]],
#
#         ...,
#
#         [[-1.1059, -1.1681, -0.5949,  ..., -0.5791, -1.6926,  0.4700]],
#
#         [[-2.0070,  0.3459,  0.1010,  ..., -1.0106, -0.7713, -0.7553]],
#
#         [[ 0.3216, -1.5437, -0.2363,  ...,  0.4062,  0.8544,  0.1651]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 57/10910 [00:05<19:21,  9.34it/s]
# tensor([[[ 1.1493, -0.3072, -1.9354,  ...,  0.4052,  0.6372,  0.4595]],
#
#         [[ 0.3380, -0.5225,  0.1291,  ...,  0.4554,  0.0113,  0.2923]],
#
#         [[ 0.4299,  0.0815,  1.4583,  ...,  0.3722,  0.5304, -0.3289]],
#
#         ...,
#
#         [[-0.5186, -0.5004,  1.3902,  ...,  0.4788, -1.2979,  1.0007]],
#
#         [[-0.0856, -0.7889,  0.8110,  ..., -0.0424, -2.1383,  0.3478]],
#
#         [[-0.6136,  0.1650, -0.0207,  ..., -0.4954,  0.4856,  0.3444]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.4395,  0.2332,  0.0304,  ..., -0.3776,  0.7162, -0.1759]],
#
#         [[-2.0057,  0.3460,  0.1008,  ..., -1.0103, -0.7716, -0.7563]],
#
#         [[-2.0057,  0.3460,  0.1008,  ..., -1.0103, -0.7716, -0.7563]],
#
#         ...,
#
#         [[-1.1940,  0.1300, -1.4802,  ..., -0.3159, -0.3376,  0.7082]],
#
#         [[-0.4395,  0.2332,  0.0304,  ..., -0.3776,  0.7162, -0.1759]],
#
#         [[-1.2918,  0.0902,  0.8231,  ...,  0.5400, -1.1758,  0.1305]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 59/10910 [00:05<18:02, 10.03it/s]
# tensor([[[ 0.1721,  0.0344, -0.9280,  ...,  0.2671,  0.1187, -1.1835]],
#
#         [[ 0.9584, -0.6543, -1.7383,  ..., -0.2905,  1.0420, -0.2397]],
#
#         [[-0.9939, -1.2273, -1.5368,  ..., -0.3704,  0.0271, -1.2063]],
#
#         ...,
#
#         [[-1.2919,  0.0902,  0.8229,  ...,  0.5396, -1.1758,  0.1305]],
#
#         [[-0.0755,  0.7308,  1.1713,  ...,  1.9010, -0.7419, -0.9252]],
#
#         [[ 0.2539, -1.9953, -0.4652,  ..., -1.0794,  1.1427,  0.5227]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.3410, -0.6770, -0.6168,  ...,  0.4461,  0.3013,  0.7883]],
#
#         [[-1.2919,  0.0903,  0.8229,  ...,  0.5396, -1.1759,  0.1305]],
#
#         [[-0.5789, -0.0050,  1.4894,  ...,  0.9553,  0.4614, -0.9961]],
#
#         ...,
#
#         [[ 0.3815,  0.7691, -0.4342,  ...,  2.1027,  0.2968,  0.3261]],
#
#         [[-0.9130,  0.7394,  0.1719,  ...,  0.1310, -0.0861,  0.2571]],
#
#         [[-0.4791, -0.1032, -0.1943,  ...,  1.0350,  1.0313, -1.0881]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.0751,  1.0760,  0.3823,  ...,  1.0426, -0.1167,  0.1284]],
#
#         [[ 1.4980,  2.2010, -0.3528,  ..., -0.2531, -0.4817, -0.5582]],
#
#         [[ 0.3965, -0.7512,  0.6399,  ...,  0.5011,  3.3730,  0.6085]],
#
#         ...,
#
#         [[-1.3942, -1.2902, -0.8473,  ...,  1.5128,  0.7448, -0.0249]],
#
#         [[ 1.3414, -1.4728,  1.9600,  ...,  1.4710, -0.3173,  1.0449]],
#
#         [[ 0.3973, -0.3686,  0.3396,  ..., -0.9477, -1.5157,  0.8091]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 61/10910 [00:05<17:28, 10.35it/s]
# tensor([[[-1.5470,  0.0650,  0.4074,  ..., -0.6247, -1.3670,  0.1822]],
#
#         [[-1.2921,  0.0907,  0.8228,  ...,  0.5403, -1.1764,  0.1309]],
#
#         [[ 1.9522,  0.1021,  0.3400,  ...,  2.3681, -0.7296,  1.2430]],
#
#         ...,
#
#         [[-1.7038,  0.3103, -0.3346,  ..., -1.0806,  0.9456, -0.4968]],
#
#         [[-1.2921,  0.0907,  0.8228,  ...,  0.5403, -1.1764,  0.1309]],
#
#         [[-1.1036, -1.1688, -0.5935,  ..., -0.5785, -1.6958,  0.4716]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.1645, -0.4248,  0.4489,  ...,  0.4719,  0.7180, -1.7954]],
#
#         [[-1.6749, -0.3171,  0.4527,  ...,  0.1279,  0.1860,  0.3565]],
#
#         [[-1.4099, -1.7154, -0.1988,  ...,  0.7610, -0.8416,  0.6604]],
#
#         ...,
#
#         [[-1.2781,  0.5922, -0.5242,  ..., -2.1245, -1.6811,  1.4560]],
#
#         [[-0.3871,  0.7094,  0.0899,  ..., -0.2098,  1.3338,  0.7303]],
#
#         [[ 1.9521,  0.1020,  0.3400,  ...,  2.3683, -0.7295,  1.2428]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.3859, -0.3201,  0.1810,  ...,  0.0698,  0.3858,  0.1467]],
#
#         [[ 2.6986,  0.8973,  0.7218,  ..., -1.0241, -0.2368, -1.5334]],
#
#         [[-1.5690,  0.3260,  2.0585,  ..., -1.3381,  0.2036, -2.1554]],
#
#         ...,
#
#         [[-0.5907,  1.2475,  0.8338,  ...,  0.4759, -0.8463,  0.2209]],
#
#         [[-0.0515, -0.3227, -0.0893,  ...,  0.0028,  0.6296,  0.4745]],
#
#         [[-1.9174, -0.1383,  0.2543,  ..., -0.6651, -0.9840,  0.5192]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 63/10910 [00:05<17:21, 10.41it/s]
# tensor([[[ 0.3375, -0.6736, -0.6148,  ...,  0.4422,  0.3011,  0.7880]],
#
#         [[ 0.9360,  1.2230,  1.0179,  ...,  0.0944,  2.4099, -0.8758]],
#
#         [[-1.4820,  0.8803,  1.0060,  ...,  0.9108, -1.9256,  1.5964]],
#
#         ...,
#
#         [[ 0.2534, -1.9954, -0.4660,  ..., -1.0801,  1.1438,  0.5229]],
#
#         [[ 0.3375, -0.6736, -0.6148,  ...,  0.4422,  0.3011,  0.7880]],
#
#         [[-0.3895, -0.8776,  1.5658,  ..., -0.7341, -0.6064,  0.6485]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.2343e-01,  3.1290e-01, -1.3677e-03,  ...,  9.1344e-01,
#           -1.3483e+00, -2.9668e-01]],
#
#         [[ 4.7630e-01, -1.5580e+00,  1.4072e-01,  ...,  1.6703e+00,
#            1.3040e+00,  1.0901e+00]],
#
#         [[-1.0532e+00,  4.3574e-01, -2.1075e-01,  ..., -4.7831e-01,
#           -9.2992e-01, -3.1497e-01]],
#
#         ...,
#
#         [[-1.4707e+00,  1.1972e-01,  9.5951e-01,  ...,  2.1872e+00,
#           -1.8586e+00,  2.3457e+00]],
#
#         [[ 1.3791e+00, -2.0631e+00,  8.1548e-01,  ...,  1.1705e-01,
#           -8.6714e-01, -9.9711e-01]],
#
#         [[-1.2922e+00,  9.1468e-02,  8.2265e-01,  ...,  5.4186e-01,
#           -1.1760e+00,  1.3247e-01]]], grad_fn=<EmbeddingBackward0>)
#   1%|          | 67/10910 [00:06<16:26, 10.99it/s]
# tensor([[[ 0.3141,  0.0291, -0.0831,  ..., -0.8426,  2.6301,  1.8605]],
#
#         [[-0.5383, -1.6305,  0.3778,  ...,  0.1910,  0.0686, -0.2343]],
#
#         [[ 1.0838, -0.2095,  1.4054,  ...,  1.3976, -1.1841,  1.0117]],
#
#         ...,
#
#         [[-1.0059,  1.2532,  0.4144,  ...,  0.1537, -0.4651,  0.4950]],
#
#         [[-0.6281, -0.1036, -0.2445,  ...,  0.6216, -1.2304,  0.4099]],
#
#         [[-0.1297,  0.3320, -1.3119,  ...,  2.7852,  0.8900, -0.4015]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 6.6968e-02, -6.1704e-01,  5.7792e-01,  ...,  8.5308e-01,
#            5.5752e-02,  2.0095e+00]],
#
#         [[-5.3660e-01, -6.3354e-01,  1.1054e-01,  ...,  1.2767e-01,
#            2.2214e+00, -1.0680e+00]],
#
#         [[ 2.5232e-01,  6.7322e-01,  9.3514e-01,  ..., -2.5415e-01,
#            1.2630e+00, -1.9777e-01]],
#
#         ...,
#
#         [[-5.6109e-01, -9.3701e-02,  1.0789e+00,  ..., -5.8486e-01,
#            7.8241e-01, -5.5713e-01]],
#
#         [[-9.1278e-01,  7.3862e-01,  1.6827e-01,  ...,  1.3058e-01,
#           -8.4920e-02,  2.5892e-01]],
#
#         [[-3.6945e-03,  2.9106e-02,  1.0986e-03,  ..., -1.6794e+00,
#           -7.3643e-01, -9.8288e-01]]], grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2220, -0.2912,  0.3273,  ..., -0.2845, -1.2711, -0.0362]],
#
#         [[-2.5119, -0.2895,  1.4850,  ..., -0.1594,  0.7187,  0.3937]],
#
#         [[-0.9920,  1.2967, -0.2901,  ..., -1.2761,  0.4966, -0.3358]],
#
#         ...,
#
#         [[ 2.7539,  0.9311,  1.7168,  ...,  0.6715, -0.4233,  0.6567]],
#
#         [[ 0.3593, -0.4954,  0.4032,  ...,  0.6291,  0.8404, -1.6270]],
#
#         [[-1.2923,  0.0911,  0.8228,  ...,  0.5425, -1.1752,  0.1341]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 69/10910 [00:06<16:36, 10.88it/s]
# tensor([[[ 1.8455e+00,  3.7229e-01,  1.1019e-01,  ...,  2.5365e-01,
#            7.0744e-01,  3.5101e-01]],
#
#         [[-9.1209e-01,  7.3906e-01,  1.6711e-01,  ...,  1.3058e-01,
#           -8.4400e-02,  2.5922e-01]],
#
#         [[-4.3591e-03,  2.8674e-02,  1.1123e-03,  ..., -1.6785e+00,
#           -7.3611e-01, -9.8160e-01]],
#
#         ...,
#
#         [[-2.3470e-01,  4.4014e-02,  7.1235e-01,  ..., -4.7072e-01,
#           -1.6701e-01,  1.9594e+00]],
#
#         [[ 1.4446e+00,  8.3813e-02, -2.8741e+00,  ..., -1.3535e+00,
#           -1.5985e+00,  2.5238e+00]],
#
#         [[-1.2924e+00,  9.0814e-02,  8.2288e-01,  ...,  5.4274e-01,
#           -1.1751e+00,  1.3474e-01]]], grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2214, -0.7007, -0.4847,  ...,  0.5186,  0.1085, -0.2407]],
#
#         [[-0.1176,  0.7589, -0.2115,  ...,  0.9176, -0.8732,  1.6356]],
#
#         [[-0.4454,  0.2321,  0.0318,  ..., -0.3785,  0.7141, -0.1733]],
#
#         ...,
#
#         [[ 0.3315, -0.6685, -0.6140,  ...,  0.4375,  0.3002,  0.7883]],
#
#         [[-1.2225,  0.3996, -0.7986,  ...,  0.1297, -0.3223, -0.7736]],
#
#         [[-0.7074,  1.4111,  0.7799,  ..., -0.0329,  1.2741,  0.5374]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.2926,  0.0905,  0.8231,  ...,  0.5432, -1.1753,  0.1350]],
#
#         [[-0.5798,  1.4352, -1.1028,  ..., -0.4667,  1.8345, -0.2231]],
#
#         [[-0.4457,  0.2321,  0.0320,  ..., -0.3786,  0.7141, -0.1733]],
#
#         ...,
#
#         [[-0.5356, -0.6338,  0.1101,  ...,  0.1272,  2.2216, -1.0684]],
#
#         [[-0.8311, -0.1535,  0.4582,  ..., -0.0302, -0.6224,  0.0148]],
#
#         [[-1.5173, -0.1440,  0.3880,  ...,  0.2908, -0.2255,  0.0626]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 73/10910 [00:06<15:40, 11.52it/s]
# tensor([[[-1.1022, -1.1635, -0.5930,  ..., -0.5740, -1.6865,  0.4729]],
#
#         [[-1.9961,  0.3458,  0.0964,  ..., -1.0124, -0.7645, -0.7478]],
#
#         [[-0.1557, -0.0487, -0.4956,  ...,  0.2212, -1.0425,  2.2875]],
#
#         ...,
#
#         [[ 1.1808, -0.6810, -0.8761,  ...,  0.6074, -0.4677, -0.4696]],
#
#         [[-0.5354, -0.6339,  0.1100,  ...,  0.1270,  2.2217, -1.0687]],
#
#         [[-1.1277,  0.2600, -1.4117,  ..., -0.1719,  0.3675,  0.0650]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 1.0941,  0.0617,  2.1384,  ..., -0.0892,  0.0254, -1.9452]],
#
#         [[-0.5497,  0.9282, -0.8640,  ..., -2.2425,  1.0447, -1.5733]],
#
#         [[ 0.3300, -0.6673, -0.6145,  ...,  0.4365,  0.3007,  0.7877]],
#
#         ...,
#
#         [[ 1.1795, -0.6808, -0.8757,  ...,  0.6069, -0.4677, -0.4690]],
#
#         [[-0.4463,  0.2317,  0.0324,  ..., -0.3788,  0.7137, -0.1731]],
#
#         [[-0.5754, -0.1259,  0.7942,  ...,  0.0577, -0.4897, -0.3513]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 1.8935, -0.3003,  1.0842,  ..., -1.5965,  1.3883, -0.0955]],
#
#         [[ 0.3298, -0.6673, -0.6149,  ...,  0.4364,  0.3007,  0.7874]],
#
#         [[ 0.3437, -0.6704, -0.1131,  ...,  0.1965, -0.5268,  1.2732]],
#
#         ...,
#
#         [[-1.9564, -1.1310, -1.1710,  ..., -0.7363,  0.1665,  1.7163]],
#
#         [[ 0.9122, -0.7378,  1.3244,  ..., -0.0605, -0.1362,  0.1770]],
#
#         [[ 0.4613, -0.6643,  0.4500,  ..., -1.8560, -0.9581,  0.7387]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 75/10910 [00:06<15:32, 11.62it/s]
# tensor([[[ 1.2506, -1.1188,  0.5474,  ..., -0.0166,  0.2915, -1.1322]],
#
#         [[-1.2514, -1.2449, -0.2233,  ...,  0.1977,  0.7125, -0.2832]],
#
#         [[-0.1400,  0.8874, -0.0301,  ...,  0.4475,  1.0692, -1.0010]],
#
#         ...,
#
#         [[-2.1687, -0.5204, -1.0711,  ...,  1.6053, -1.0312,  1.3092]],
#
#         [[-0.4474,  0.2305,  0.0326,  ..., -0.3786,  0.7127, -0.1719]],
#
#         [[-1.2931,  0.0900,  0.8228,  ...,  0.5433, -1.1745,  0.1352]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.9938,  0.3473,  0.0948,  ..., -1.0133, -0.7638, -0.7486]],
#
#         [[ 0.9114, -0.7382,  1.3245,  ..., -0.0605, -0.1365,  0.1773]],
#
#         [[-0.3871, -0.3216,  0.1813,  ...,  0.0715,  0.3845,  0.1478]],
#
#         ...,
#
#         [[-1.1009, -1.1662, -0.5923,  ..., -0.5750, -1.6883,  0.4722]],
#
#         [[-1.0586, -0.4059,  0.5027,  ..., -0.5057, -2.1211,  0.2610]],
#
#         [[ 0.7868,  0.9823,  1.2732,  ...,  0.8320, -1.0801,  0.0078]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.3631, -0.3300,  0.2903,  ..., -2.8220,  1.4654, -0.8264]],
#
#         [[ 1.7976, -0.7203, -0.8256,  ..., -0.8253,  0.2983,  0.0059]],
#
#         [[-0.2462,  1.4912,  0.3005,  ...,  0.1985,  1.2452, -0.5550]],
#
#         ...,
#
#         [[ 0.1575,  0.1100,  0.1333,  ..., -0.4905,  0.9154, -1.1865]],
#
#         [[-0.5170,  1.9298,  0.5181,  ..., -1.0398, -0.6413, -0.4163]],
#
#         [[-2.0497, -0.9462, -0.6450,  ...,  0.9956, -0.3685,  0.3995]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 79/10910 [00:07<15:24, 11.71it/s]
# tensor([[[ 0.9227,  0.0318,  1.2826,  ...,  1.1955, -0.3798, -0.3683]],
#
#         [[ 0.2515, -1.9935, -0.4659,  ..., -1.0789,  1.1450,  0.5257]],
#
#         [[ 0.3293, -0.6679, -0.6164,  ...,  0.4360,  0.3003,  0.7861]],
#
#         ...,
#
#         [[-0.9392,  1.5142, -0.7397,  ...,  0.0215,  0.3872, -0.4789]],
#
#         [[-1.3957, -1.2913, -0.8457,  ...,  1.5126,  0.7451, -0.0252]],
#
#         [[-0.1661, -1.3404, -0.0055,  ..., -1.2214,  0.8811,  0.3328]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.4109, -1.7116, -0.1992,  ...,  0.7593, -0.8393,  0.6609]],
#
#         [[-0.6908, -1.6224, -1.8540,  ..., -0.2914, -1.3429, -0.2939]],
#
#         [[-0.3907,  0.7079,  0.0883,  ..., -0.2125,  1.3307,  0.7303]],
#
#         ...,
#
#         [[-0.3786,  1.5952, -0.7174,  ...,  2.7057, -0.9565,  1.2242]],
#
#         [[-0.4494,  0.2283,  0.0323,  ..., -0.3784,  0.7113, -0.1699]],
#
#         [[ 0.6231, -0.0952,  0.8231,  ..., -0.2679, -0.0035, -0.6632]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.0410,  0.0259, -0.4997,  ...,  1.9198, -0.8029, -0.1126]],
#
#         [[-1.4112, -1.7111, -0.1990,  ...,  0.7593, -0.8389,  0.6610]],
#
#         [[-1.2937,  0.0876,  0.8217,  ...,  0.5429, -1.1726,  0.1363]],
#
#         ...,
#
#         [[-0.8925,  0.6361, -0.3857,  ...,  1.5864, -0.9867, -0.5452]],
#
#         [[ 0.2901, -0.4332, -1.2583,  ...,  0.7693, -1.2064, -0.3927]],
#
#         [[-0.5353, -0.6336,  0.1100,  ...,  0.1253,  2.2211, -1.0695]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 81/10910 [00:07<15:29, 11.64it/s]
# tensor([[[ 0.2781, -0.8465,  1.4850,  ...,  0.3383, -0.5511, -0.3946]],
#
#         [[-0.7542, -3.5614, -1.1109,  ...,  1.0455,  0.4903,  0.7087]],
#
#         [[ 0.3293, -0.6682, -0.6168,  ...,  0.4357,  0.3002,  0.7855]],
#
#         ...,
#
#         [[ 0.4103, -2.1086, -1.3262,  ..., -0.8448, -0.1237,  0.1305]],
#
#         [[-1.0512,  0.5124, -0.7421,  ..., -0.5086,  0.2963, -0.4546]],
#
#         [[-1.4711,  0.1184,  0.9568,  ...,  2.1850, -1.8563,  2.3440]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 1.5084,  0.2200,  0.2976,  ...,  0.4836, -0.5845, -0.0131]],
#
#         [[ 0.3294, -0.6683, -0.6170,  ...,  0.4356,  0.3001,  0.7853]],
#
#         [[ 0.9224,  0.0311,  1.2823,  ...,  1.1950, -0.3801, -0.3680]],
#
#         ...,
#
#         [[ 0.2145,  1.0968, -0.5757,  ...,  0.9648,  0.2381,  0.3142]],
#
#         [[ 0.5805,  0.0199, -0.1064,  ..., -3.0345, -1.4489,  1.6280]],
#
#         [[-0.8407,  1.0641, -0.8456,  ...,  0.2745,  1.3762,  0.6335]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.1088, -0.9142,  0.9100,  ...,  0.5035,  0.6884, -1.7607]],
#
#         [[-1.2938,  0.0855,  0.8208,  ...,  0.5421, -1.1710,  0.1373]],
#
#         [[ 0.3423, -0.6557, -0.7108,  ..., -1.6889,  0.8426,  0.5288]],
#
#         ...,
#
#         [[ 0.3296, -0.6686, -0.6171,  ...,  0.4356,  0.3001,  0.7850]],
#
#         [[-1.2938,  0.0855,  0.8208,  ...,  0.5421, -1.1710,  0.1373]],
#
#         [[ 1.4073, -0.3959, -0.0237,  ...,  0.3290,  1.0154,  0.2011]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 85/10910 [00:07<15:12, 11.87it/s]
# tensor([[[-1.6694,  0.6581, -1.3621,  ..., -0.9377,  0.9456,  0.5629]],
#
#         [[-0.0177, -2.5917, -0.0031,  ..., -1.6071, -0.5318, -0.3037]],
#
#         [[-1.3961, -1.2907, -0.8449,  ...,  1.5121,  0.7451, -0.0250]],
#
#         ...,
#
#         [[-0.1711,  0.2038,  1.5019,  ..., -0.6243,  0.6178, -0.7495]],
#
#         [[ 0.3371, -1.4113,  0.7138,  ..., -2.6435,  0.5382, -0.8093]],
#
#         [[ 1.9928, -1.3066, -0.3004,  ...,  0.0386,  0.9894, -0.1582]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.4122, -1.7105, -0.1988,  ...,  0.7582, -0.8376,  0.6610]],
#
#         [[-0.6202,  0.1069, -1.1267,  ...,  0.9994,  0.3057, -0.0542]],
#
#         [[ 0.3582, -0.4958,  0.4057,  ...,  0.6294,  0.8381, -1.6282]],
#
#         ...,
#
#         [[-1.0096, -0.6038,  1.3145,  ..., -0.6009,  0.5783, -1.2710]],
#
#         [[-0.9270,  0.1634,  1.2121,  ...,  1.5192,  0.3759, -0.7350]],
#
#         [[-0.5413, -1.6277,  0.3751,  ...,  0.1918,  0.0677, -0.2296]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.9841, -0.5547, -2.9043,  ...,  0.5451, -1.6917, -0.2669]],
#
#         [[-0.4100, -0.1802,  1.5526,  ...,  1.0041,  0.0765, -0.1664]],
#
#         [[-0.4507,  0.2245,  0.0316,  ..., -0.3766,  0.7089, -0.1705]],
#
#         ...,
#
#         [[ 0.1588,  0.4430,  0.0046,  ...,  0.3473,  0.1346, -1.4252]],
#
#         [[-0.1336,  0.4537, -0.5553,  ...,  0.1674, -0.0492,  0.2033]],
#
#         [[-0.7050,  1.4105,  0.7813,  ..., -0.0318,  1.2719,  0.5398]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 87/10910 [00:07<15:19, 11.77it/s]
# tensor([[[ 0.6227,  0.0680,  1.8933,  ..., -0.5262, -0.5244, -0.0796]],
#
#         [[-0.5359, -0.6325,  0.1118,  ...,  0.1259,  2.2169, -1.0668]],
#
#         [[-1.0996, -1.1658, -0.5916,  ..., -0.5755, -1.6862,  0.4749]],
#
#         ...,
#
#         [[ 0.2458, -0.3946,  1.0235,  ..., -0.5735,  0.4849,  0.3989]],
#
#         [[ 0.7768,  0.0073, -0.1360,  ...,  0.9113, -0.1509, -0.9519]],
#
#         [[ 1.4372,  0.0824, -2.8678,  ..., -1.3473, -1.5964,  2.5229]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.2935,  0.0827,  0.8193,  ...,  0.5412, -1.1699,  0.1376]],
#
#         [[ 0.0142,  2.2723,  0.3958,  ..., -1.6317,  0.1507,  1.7632]],
#
#         [[-0.5361, -0.6323,  0.1121,  ...,  0.1259,  2.2166, -1.0665]],
#
#         ...,
#
#         [[-2.0528, -0.1551,  0.5212,  ..., -0.6929, -0.6981,  1.2814]],
#
#         [[ 1.0282, -0.1423,  0.3160,  ..., -0.1928,  0.8345, -0.4905]],
#
#         [[-1.9906,  0.3499,  0.0927,  ..., -1.0141, -0.7624, -0.7485]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.6623, -1.2612, -0.0318,  ..., -0.0104,  0.4372, -0.9091]],
#
#         [[ 0.3324, -0.6711, -0.6185,  ...,  0.4366,  0.3001,  0.7835]],
#
#         [[-0.2362,  0.7446,  1.8865,  ...,  0.3243,  1.0220,  0.5265]],
#
#         ...,
#
#         [[-1.0990, -1.1659, -0.5926,  ..., -0.5760, -1.6866,  0.4759]],
#
#         [[-0.5361, -0.6322,  0.1122,  ...,  0.1259,  2.2165, -1.0664]],
#
#         [[ 1.4066,  0.2144,  0.3837,  ..., -1.1415, -0.5530,  0.6570]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 91/10910 [00:08<15:55, 11.32it/s]
# tensor([[[-1.0988, -1.1658, -0.5931,  ..., -0.5761, -1.6869,  0.4764]],
#
#         [[-0.5624, -0.0929,  1.0780,  ..., -0.5849,  0.7819, -0.5551]],
#
#         [[-1.0506,  0.5546,  1.6137,  ..., -0.7581,  0.7209,  0.1583]],
#
#         ...,
#
#         [[-0.0787,  0.7282,  1.1690,  ...,  1.8949, -0.7410, -0.9223]],
#
#         [[ 0.2513, -1.9888, -0.4661,  ..., -1.0770,  1.1425,  0.5205]],
#
#         [[ 1.4875,  2.1933, -0.3492,  ..., -0.2475, -0.4817, -0.5539]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.0987, -1.1653, -0.5936,  ..., -0.5761, -1.6868,  0.4769]],
#
#         [[ 0.2072, -0.0149, -1.8029,  ..., -0.9555,  0.8077,  2.2120]],
#
#         [[-0.9524, -0.3525, -1.3266,  ..., -0.3298, -0.0423, -1.2259]],
#
#         ...,
#
#         [[-1.4125, -1.7101, -0.1981,  ...,  0.7564, -0.8361,  0.6609]],
#
#         [[-0.7438,  0.6258, -1.4474,  ...,  0.0156, -1.5256,  1.1940]],
#
#         [[ 1.4870,  2.1931, -0.3490,  ..., -0.2473, -0.4818, -0.5537]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 93/10910 [00:08<15:53, 11.34it/s]
# tensor([[[-0.0573,  0.5803,  2.3662,  ...,  0.8111, -1.0015,  1.2419]],
#
#         [[-1.4125, -1.7100, -0.1979,  ...,  0.7563, -0.8357,  0.6610]],
#
#         [[-1.9903,  0.3496,  0.0932,  ..., -1.0139, -0.7608, -0.7467]],
#
#         ...,
#
#         [[-1.7434, -0.1178,  0.7729,  ..., -1.2326, -1.2236,  0.9924]],
#
#         [[ 0.3410, -0.3583, -0.1256,  ...,  0.2754, -0.3060, -1.9504]],
#
#         [[ 1.7244,  0.4438,  0.6031,  ...,  1.1348, -0.1283,  0.6666]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.0680, -0.6172,  0.5756,  ...,  0.8594,  0.0564,  2.0103]],
#
#         [[-0.5362, -0.6314,  0.1125,  ...,  0.1263,  2.2164, -1.0662]],
#
#         [[ 0.5634, -0.1810, -1.7062,  ..., -1.4699, -0.4653, -0.0218]],
#
#         ...,
#
#         [[-0.3230,  0.1465,  0.5072,  ...,  0.2187, -0.6048,  0.5322]],
#
#         [[-0.6495, -1.6264, -0.7117,  ..., -1.1585, -0.5097,  1.9976]],
#
#         [[-1.4127, -1.7104, -0.1977,  ...,  0.7563, -0.8359,  0.6609]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 95/10910 [00:08<15:44, 11.45it/s]
# tensor([[[ 1.3276, -0.5960,  1.1372,  ...,  0.8422,  0.8780, -1.8005]],
#
#         [[ 0.8179,  1.9800, -1.9201,  ..., -0.2639,  0.2657, -0.8489]],
#
#         [[-0.1804,  0.7389, -1.0047,  ..., -0.8216, -0.2183,  1.4448]],
#
#         ...,
#
#         [[ 0.3632,  1.6329,  1.1072,  ..., -0.6442, -0.1617,  1.2404]],
#
#         [[ 1.1384,  0.4320,  1.3342,  ..., -0.1637,  0.7718, -1.4315]],
#
#         [[ 1.1448, -0.3067, -1.9300,  ...,  0.3983,  0.6356,  0.4584]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.2936,  0.0804,  0.8191,  ...,  0.5450, -1.1704,  0.1379]],
#
#         [[ 0.5162,  1.1143, -0.1550,  ..., -0.7403, -0.6323, -0.5173]],
#
#         [[ 0.5254, -0.3505,  0.9686,  ...,  2.8544, -0.8844,  0.2401]],
#
#         ...,
#
#         [[ 1.1506, -0.6707, -0.8678,  ...,  0.6087, -0.4619, -0.4659]],
#
#         [[-0.7713,  0.1006,  0.3584,  ..., -0.4705, -0.4694,  1.1380]],
#
#         [[-1.3959, -1.2906, -0.8442,  ...,  1.5115,  0.7455, -0.0255]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.1574, -0.2259,  0.5699,  ..., -0.1262, -0.9458, -0.6701]],
#
#         [[ 0.6794, -0.8660, -1.5422,  ..., -0.5326,  1.0838, -0.9055]],
#
#         [[ 0.8927,  3.0286,  2.4672,  ..., -0.4970,  0.7087,  0.8363]],
#
#         ...,
#
#         [[ 0.6794, -0.8660, -1.5422,  ..., -0.5326,  1.0838, -0.9055]],
#
#         [[ 0.8927,  3.0286,  2.4672,  ..., -0.4970,  0.7087,  0.8363]],
#
#         [[ 0.3294, -0.6659, -0.6166,  ...,  0.4339,  0.3018,  0.7846]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 97/10910 [00:08<15:37, 11.54it/s]
# tensor([[[-1.0968, -1.1587, -0.5943,  ..., -0.5747, -1.6810,  0.4759]],
#
#         [[ 0.0213,  0.8797, -0.1269,  ...,  0.3838, -0.6129,  0.6280]],
#
#         [[-0.5748,  1.6079, -1.5353,  ..., -0.7515, -0.3067, -3.0948]],
#
#         ...,
#
#         [[-1.0968, -1.1587, -0.5943,  ..., -0.5747, -1.6810,  0.4759]],
#
#         [[ 0.0736,  1.0752,  0.3856,  ...,  1.0446, -0.1173,  0.1295]],
#
#         [[-0.3947,  0.7118,  0.0890,  ..., -0.2136,  1.3299,  0.7330]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.8506,  0.1514, -0.6592,  ...,  0.1631,  1.1936, -0.4304]],
#
#         [[ 0.4538,  1.4980,  0.9129,  ...,  0.4056,  1.1238, -0.3206]],
#
#         [[ 1.9013,  0.3426, -0.3361,  ...,  1.7319,  1.1289,  1.2356]],
#
#         ...,
#
#         [[-0.1882, -1.8075,  1.3284,  ..., -1.4544,  0.1038, -0.9392]],
#
#         [[-1.9906,  0.3489,  0.0936,  ..., -1.0134, -0.7592, -0.7472]],
#
#         [[-0.2371,  0.0431,  0.7079,  ..., -0.4676, -0.1684,  1.9549]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.4720,  0.1132,  0.9571,  ...,  2.1826, -1.8584,  2.3394]],
#
#         [[-1.9906,  0.3490,  0.0937,  ..., -1.0134, -0.7590, -0.7471]],
#
#         [[-0.3954,  0.7118,  0.0891,  ..., -0.2134,  1.3300,  0.7328]],
#
#         ...,
#
#         [[ 0.2107,  1.0961, -0.5725,  ...,  0.9603,  0.2390,  0.3151]],
#
#         [[ 1.1761,  0.1727,  0.3102,  ...,  0.1009,  1.3160,  0.0371]],
#
#         [[-1.4139, -1.7114, -0.1971,  ...,  0.7567, -0.8367,  0.6620]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 101/10910 [00:09<15:41, 11.49it/s]
# tensor([[[ 0.1295, -0.4721, -0.4598,  ..., -1.5921,  0.4118, -1.0547]],
#
#         [[ 1.6932,  1.2153, -0.0809,  ..., -1.7524,  0.4872,  0.4760]],
#
#         [[-0.5364, -0.6313,  0.1116,  ...,  0.1265,  2.2160, -1.0680]],
#
#         ...,
#
#         [[-1.4719,  0.1132,  0.9571,  ...,  2.1825, -1.8582,  2.3388]],
#
#         [[-1.5534, -0.2927, -0.9262,  ..., -0.0173, -0.1407, -1.5474]],
#
#         [[-0.4508,  0.2269,  0.0307,  ..., -0.3738,  0.7086, -0.1671]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.2912,  0.0811,  0.8183,  ...,  0.5466, -1.1683,  0.1394]],
#
#         [[-0.8891, -0.8233,  0.7832,  ...,  0.1050, -0.1467, -0.3869]],
#
#         [[-2.2781,  1.4609, -0.1848,  ..., -1.5307,  0.7403, -0.0354]],
#
#         ...,
#
#         [[-0.4504,  0.2273,  0.0308,  ..., -0.3733,  0.7087, -0.1665]],
#
#         [[ 0.9734,  0.8317, -0.4412,  ..., -0.5247,  1.1247, -0.4153]],
#
#         [[-0.4180,  0.8064, -1.0305,  ..., -1.3214, -0.6060, -1.1334]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-0.7044,  1.4080,  0.7821,  ..., -0.0309,  1.2711,  0.5401]],
#
#         [[-1.1277,  0.2609, -1.4125,  ..., -0.1729,  0.3689,  0.0660]],
#
#         [[ 1.0988,  0.0615,  2.1389,  ..., -0.0893,  0.0276, -1.9475]],
#
#         ...,
#
#         [[-0.4240, -0.0817,  0.6957,  ..., -0.0687,  1.7676, -1.3131]],
#
#         [[-2.5125, -0.2884,  1.4847,  ..., -0.1577,  0.7192,  0.3968]],
#
#         [[-0.4995,  3.3063,  1.2338,  ...,  0.3692, -0.5295,  1.7393]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 103/10910 [00:09<15:53, 11.34it/s]
# tensor([[[ 0.3691,  0.7627, -0.4301,  ...,  2.0937,  0.2941,  0.3334]],
#
#         [[ 1.4136,  0.7540,  1.2608,  ..., -2.3383,  2.1072,  0.6525]],
#
#         [[ 0.7863,  0.9849,  1.2730,  ...,  0.8301, -1.0789,  0.0075]],
#
#         ...,
#
#         [[-0.2370,  0.0427,  0.7077,  ..., -0.4675, -0.1689,  1.9536]],
#
#         [[-1.2906,  0.0818,  0.8184,  ...,  0.5471, -1.1675,  0.1399]],
#
#         [[ 0.4523,  1.4972,  0.9120,  ...,  0.4059,  1.1235, -0.3198]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[-1.0260, -0.4982,  0.5264,  ...,  0.1421, -1.4814,  0.0974]],
#
#         [[-1.3131,  1.1988, -0.2671,  ..., -0.2855,  1.0091,  0.8064]],
#
#         [[-0.1530,  0.4134, -2.1864,  ..., -0.4470,  0.5353,  0.6312]],
#
#         ...,
#
#         [[ 0.3407, -0.5136,  0.1256,  ...,  0.4515,  0.0081,  0.2883]],
#
#         [[-0.1533,  1.1557, -0.9706,  ..., -0.5088,  0.0134,  0.3478]],
#
#         [[-0.6179, -1.4169,  2.1333,  ...,  2.1228,  1.5674,  0.3188]]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[[ 0.2752,  1.4759, -1.1899,  ..., -2.7769,  0.0474, -0.6054]],
#
#         [[-1.2791, -0.5590,  1.1265,  ...,  0.4288, -0.1128,  1.0209]],
#
#         [[-0.3965,  0.7116,  0.0895,  ..., -0.2131,  1.3304,  0.7328]],
#
#         ...,
#
#         [[-0.3965,  0.7116,  0.0895,  ..., -0.2131,  1.3304,  0.7328]],
#
#         [[ 1.0126,  0.5671,  0.5919,  ..., -0.7137,  1.7041,  0.9584]],
#
#         [[ 1.6895, -1.3496,  0.3831,  ...,  0.0758,  0.6526, -1.2358]]],
#        grad_fn=<EmbeddingBackward0>)
#   1%|          | 104/10910 [00:09<16:19, 11.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-1dd31c9a8fb0> in <module>
#      12
#      13         # Forward pass
# ---> 14         outputs = neural_model(inputs)
#      15         loss = criterion(outputs, targets.reshape(-1))
#      16         total_loss += loss.item();
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-69-c5f0086bfbca> in forward(self, x)
#      12         intermediate_output = self.intermediate(conc_emb) # one layer of MLP
#      13         intermediate_output = F.relu(intermediate_output) # ReLU non-linear function
# ---> 14         final_out = self.final(intermediate_output) # Map to the vocabulary size output
#      15         return final_out
#      16
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the trained model

# %%
torch.save(neural_model, 'model.ckpt')

# %% [markdown]
# ### Neural Model testing

# %%
neural_model = torch.load('model.ckpt')
neural_model.eval()
test_ppl = 0
with torch.no_grad():
    for i in range(0, len(test_ids)):
        inputs = test_ids[i][:, 0:n_gram-1].to(device)
        gold = test_ids[i][:, n_gram-1:].to(device)
        output = neural_model(inputs)
        cross_entropy = criterion(output, gold.reshape(-1)).item()
        print('Perplexity for test sample '+str(i)+' :', np.exp(cross_entropy))
        test_ppl += np.exp(cross_entropy)
    print('The average testing perplexity for neural LM: '+str(test_ppl/len(test_ids)))
# Out:
# Perplexity for test sample 0 : 131.72969878621925
# Perplexity for test sample 1 : 1574.7212829407829
# Perplexity for test sample 2 : 218.10068995888324
# Perplexity for test sample 3 : 120.06119094099284
# Perplexity for test sample 4 : 85.2189484101646
# Perplexity for test sample 5 : 515.2834415076813
# Perplexity for test sample 6 : 371.81643851171054
# Perplexity for test sample 7 : 287.75292782528777
# Perplexity for test sample 8 : 119.88790696081533
# Perplexity for test sample 9 : 356.07168889966863
# Perplexity for test sample 10 : 1160.8481994215201
# Perplexity for test sample 11 : 279.610504443154
# Perplexity for test sample 12 : 206.2456031778053
# Perplexity for test sample 13 : 682.8737300757066
# Perplexity for test sample 14 : 440.3478334698897
# Perplexity for test sample 15 : 452.6268063150043
# Perplexity for test sample 16 : 168.31670265709465
# Perplexity for test sample 17 : 1125.5227618518334
# Perplexity for test sample 18 : 843.6833387365839
# Perplexity for test sample 19 : 551.4993537902428
# Perplexity for test sample 20 : 438.6783516747065
# Perplexity for test sample 21 : 362.66406428714794
# Perplexity for test sample 22 : 262.5236334657493
# Perplexity for test sample 23 : 264.8316682344632
# Perplexity for test sample 24 : 332.2696463045308
# Perplexity for test sample 25 : 486.3387434370903
# Perplexity for test sample 26 : 329.1984959916924
# Perplexity for test sample 27 : 779.2503344716476
# Perplexity for test sample 28 : 921.0649261267083
# Perplexity for test sample 29 : 482.9039036174581
# Perplexity for test sample 30 : 192.6933937378065
# Perplexity for test sample 31 : 32.388879909403386
# Perplexity for test sample 32 : 120.8514206963051
# Perplexity for test sample 33 : 38.56943402976468
# Perplexity for test sample 34 : 126.12808224743989
# Perplexity for test sample 35 : 74.39045215742422
# Perplexity for test sample 36 : 80.69148909695825
# Perplexity for test sample 37 : 6.0398838742971765
# Perplexity for test sample 38 : 64.32212827824308
# Perplexity for test sample 39 : 37.6392977816792
# Perplexity for test sample 40 : 26.184015168846845
# Perplexity for test sample 41 : 92.57361533501555
# Perplexity for test sample 42 : 24.826057244527604
# Perplexity for test sample 43 : 38.811059106237245
# Perplexity for test sample 44 : 48.03758697989022
# Perplexity for test sample 45 : 66.40486113531477
# Perplexity for test sample 46 : 29.380740777069523
# Perplexity for test sample 47 : 54.56963676664766
# Perplexity for test sample 48 : 26.61134156709291
# Perplexity for test sample 49 : 50.80618469350458
# Perplexity for test sample 50 : 20.009053095209733
# Perplexity for test sample 51 : 33.97248194269159
# Perplexity for test sample 52 : 86.59207888167093
# Perplexity for test sample 53 : 111.5438132406815
# Perplexity for test sample 54 : 53.73643601171285
# Perplexity for test sample 55 : 47.72863081450932
# Perplexity for test sample 56 : 58.25460532154846
# Perplexity for test sample 57 : 110.93070164759516
# Perplexity for test sample 58 : 24.89997098436891
# Perplexity for test sample 59 : 44.575142521425676
# Perplexity for test sample 60 : 40.672748575507
# Perplexity for test sample 61 : 51.73390389959477
# Perplexity for test sample 62 : 44.575142521425676
# Perplexity for test sample 63 : 42.84856139595189
# Perplexity for test sample 64 : 95.26968637338005
# Perplexity for test sample 65 : 747.7985454243092
# Perplexity for test sample 66 : 879.3243459272824
# Perplexity for test sample 67 : 1961.8077466747875
# Perplexity for test sample 68 : 1050.629948369179
# Perplexity for test sample 69 : 75.23530008241973
# Perplexity for test sample 70 : 99.09366572096137
# Perplexity for test sample 71 : 812.3727431377918
# Perplexity for test sample 72 : 589.0136981499373
# Perplexity for test sample 73 : 812.1968964148369
# Perplexity for test sample 74 : 412.7845778992403
# Perplexity for test sample 75 : 424.0767105797653
# Perplexity for test sample 76 : 291.30289820567884
# Perplexity for test sample 77 : 283.6454677383913
# Perplexity for test sample 78 : 236.3522904652181
# Perplexity for test sample 79 : 441.8934301106332
# Perplexity for test sample 80 : 837.4287531962269
# Perplexity for test sample 81 : 555.3778776384258
# Perplexity for test sample 82 : 144.43138440329957
# Perplexity for test sample 83 : 282.99078985084657
# Perplexity for test sample 84 : 142.93056481010453
# Perplexity for test sample 85 : 119.25116274319848
# Perplexity for test sample 86 : 180.6397276843496
# Perplexity for test sample 87 : 358.68065807118177
# Perplexity for test sample 88 : 888.9194620790911
# Perplexity for test sample 89 : 344.3260313222791
# Perplexity for test sample 90 : 387.60903006401975
# Perplexity for test sample 91 : 181.60902032413546
# Perplexity for test sample 92 : 202.72242385936718
# Perplexity for test sample 93 : 122.94728142529199
# Perplexity for test sample 94 : 273.7718651833222
# Perplexity for test sample 95 : 20.791479759354644
# Perplexity for test sample 96 : 145.53932698597328
# Perplexity for test sample 97 : 285.25111670523785
# Perplexity for test sample 98 : 228.1250561536021
# Perplexity for test sample 99 : 196.4458704167173
# Perplexity for test sample 100 : 191.8171707425995
# Perplexity for test sample 101 : 317.69784846901956
# Perplexity for test sample 102 : 13.427105945337109
# Perplexity for test sample 103 : 154.46308552671886
# Perplexity for test sample 104 : 75.18455409796309
# Perplexity for test sample 105 : 56.46908462385641
# Perplexity for test sample 106 : 250.25740910410073
# Perplexity for test sample 107 : 106.00391106758565
# Perplexity for test sample 108 : 121.81814708482472
# Perplexity for test sample 109 : 118.3272052046528
# Perplexity for test sample 110 : 237.888651055631
# Perplexity for test sample 111 : 61.667998700079096
# Perplexity for test sample 112 : 368.0872307289706
# Perplexity for test sample 113 : 538.4906852290366
# Perplexity for test sample 114 : 434.04729194912403
# Perplexity for test sample 115 : 536.1240945685538
# Perplexity for test sample 116 : 219.66741209530457
# Perplexity for test sample 117 : 489.41606970492404
# Perplexity for test sample 118 : 46.372998787775494
# Perplexity for test sample 119 : 47.984805969107995
# Perplexity for test sample 120 : 155.65265779482806
# Perplexity for test sample 121 : 180.53243443599092
# Perplexity for test sample 122 : 575.017591800858
# Perplexity for test sample 123 : 335.3627314849203
# Perplexity for test sample 124 : 139.3208433839962
# Perplexity for test sample 125 : 583.9032147560088
# Perplexity for test sample 126 : 918.6227152688383
# Perplexity for test sample 127 : 470.4801445903381
# Perplexity for test sample 128 : 211.49065494135004
# Perplexity for test sample 129 : 178.37404347035
# Perplexity for test sample 130 : 553.2685912950227
# Perplexity for test sample 131 : 417.90554250865193
# Perplexity for test sample 132 : 491.274193530913
# Perplexity for test sample 133 : 283.82162142833914
# Perplexity for test sample 134 : 319.53069222937467
# Perplexity for test sample 135 : 470.62464329110776
# Perplexity for test sample 136 : 1020.8895188835885
# Perplexity for test sample 137 : 235.5695248244627
# Perplexity for test sample 138 : 359.2727468336005
# Perplexity for test sample 139 : 374.7690847892425
# Perplexity for test sample 140 : 1390.6683921602673
# Perplexity for test sample 141 : 504.847556558468
# Perplexity for test sample 142 : 400.69700665823
# Perplexity for test sample 143 : 333.58713263768516
# Perplexity for test sample 144 : 292.5370283687167
# Perplexity for test sample 145 : 325.6478782251216
# Perplexity for test sample 146 : 288.89775756308796
# Perplexity for test sample 147 : 293.5015317829086
# Perplexity for test sample 148 : 1292.2266629105359
# Perplexity for test sample 149 : 560.8430345472781
# Perplexity for test sample 150 : 276.8330221904854
# Perplexity for test sample 151 : 226.38388195840955
# Perplexity for test sample 152 : 372.1710219708251
# Perplexity for test sample 153 : 247.19479230403306
# Perplexity for test sample 154 : 796.5358218046637
# Perplexity for test sample 155 : 271.6148035417593
# Perplexity for test sample 156 : 445.683640902898
# Perplexity for test sample 157 : 165.7437821990403
# Perplexity for test sample 158 : 507.5291645358897
# Perplexity for test sample 159 : 568.8636669589512
# Perplexity for test sample 160 : 97.83211592240369
# Perplexity for test sample 161 : 147.62167457623548
# Perplexity for test sample 162 : 416.17942842338744
# Perplexity for test sample 163 : 288.08956666587756
# Perplexity for test sample 164 : 448.46950370268286
# Perplexity for test sample 165 : 416.197289290073
# Perplexity for test sample 166 : 285.78276311341386
# Perplexity for test sample 167 : 328.0423761317484
# Perplexity for test sample 168 : 169.4372291421121
# Perplexity for test sample 169 : 493.58658938187745
# Perplexity for test sample 170 : 212.08861140087205
# Perplexity for test sample 171 : 279.8876987454986
# Perplexity for test sample 172 : 74.7496917260298
# Perplexity for test sample 173 : 128.8123832980608
# Perplexity for test sample 174 : 128.81490164644052
# Perplexity for test sample 175 : 150.9323009210763
# Perplexity for test sample 176 : 112.74424950904579
# Perplexity for test sample 177 : 345.49670314534063
# Perplexity for test sample 178 : 180.44103576361056
# Perplexity for test sample 179 : 390.15148680103533
# Perplexity for test sample 180 : 257.0361527765083
# Perplexity for test sample 181 : 208.62771096613014
# Perplexity for test sample 182 : 117.51346527575234
# Perplexity for test sample 183 : 173.71215614960136
# Perplexity for test sample 184 : 699.3643507298634
# Perplexity for test sample 185 : 402.58037402664274
# Perplexity for test sample 186 : 292.3491922671582
# Perplexity for test sample 187 : 203.49547878925674
# Perplexity for test sample 188 : 317.8527091221824
# Perplexity for test sample 189 : 292.04447691064973
# Perplexity for test sample 190 : 438.7068008240047
# Perplexity for test sample 191 : 372.5351806726931
# Perplexity for test sample 192 : 379.72485554992653
# Perplexity for test sample 193 : 89.87452370040987
# Perplexity for test sample 194 : 816.3362612784208
# Perplexity for test sample 195 : 75.12929250008855
# Perplexity for test sample 196 : 1583.7841712815425
# Perplexity for test sample 197 : 19.003800158585406
# Perplexity for test sample 198 : 316.9337436279219
# Perplexity for test sample 199 : 416.34834348633314
# Perplexity for test sample 200 : 130.6195244714338
# Perplexity for test sample 201 : 57.93777350795864
# Perplexity for test sample 202 : 321.0091389737959
# Perplexity for test sample 203 : 199.05867003330215
# Perplexity for test sample 204 : 731.0835300420379
# Perplexity for test sample 205 : 337.9582035723793
# Perplexity for test sample 206 : 237.39345994084522
# Perplexity for test sample 207 : 879.9807867586765
# Perplexity for test sample 208 : 302.8984203400239
# Perplexity for test sample 209 : 141.64289400379073
# Perplexity for test sample 210 : 99.65299556357083
# Perplexity for test sample 211 : 237.36584123000426
# Perplexity for test sample 212 : 681.7064059299881
# Perplexity for test sample 213 : 139.49307858199862
# Perplexity for test sample 214 : 58.9633871582612
# Perplexity for test sample 215 : 41.02575416377445
# Perplexity for test sample 216 : 398.213599890741
# Perplexity for test sample 217 : 108.5730511827355
# Perplexity for test sample 218 : 83.94000759003913
# Perplexity for test sample 219 : 111.98914073537352
# Perplexity for test sample 220 : 27.42561478085497
# Perplexity for test sample 221 : 170.567980557568
# Perplexity for test sample 222 : 64.66826039932378
# Perplexity for test sample 223 : 218.10724196362804
# Perplexity for test sample 224 : 98.92148910056451
# Perplexity for test sample 225 : 124.78311952674441
# Perplexity for test sample 226 : 159.1291245475985
# Perplexity for test sample 227 : 189.6252874322753
# Perplexity for test sample 228 : 171.25826537417058
# Perplexity for test sample 229 : 94.66532766631893
# Perplexity for test sample 230 : 519.6582811589018
# Perplexity for test sample 231 : 257.2762459131724
# Perplexity for test sample 232 : 168.98659515335072
# Perplexity for test sample 233 : 124.26131679052453
# Perplexity for test sample 234 : 57.43462007798879
# Perplexity for test sample 235 : 114.56619329868774
# Perplexity for test sample 236 : 52.71122817543126
# Perplexity for test sample 237 : 100.5462795431486
# Perplexity for test sample 238 : 326.2937103857334
# Perplexity for test sample 239 : 171.42240355090303
# Perplexity for test sample 240 : 371.77814457073634
# Perplexity for test sample 241 : 58.02876495725955
# Perplexity for test sample 242 : 37.16497172243124
# Perplexity for test sample 243 : 375.6783589006387
# Perplexity for test sample 244 : 222.20729475105142
# Perplexity for test sample 245 : 10.48390138774116
# Perplexity for test sample 246 : 159.95499923684073
# Perplexity for test sample 247 : 61.326139366769624
# Perplexity for test sample 248 : 20.854510131490454
# Perplexity for test sample 249 : 596.6454731047139
# Perplexity for test sample 250 : 28.586262042932418
# Perplexity for test sample 251 : 319.3399892976093
# Perplexity for test sample 252 : 287.49659416767884
# Perplexity for test sample 253 : 282.43389921171956
# Perplexity for test sample 254 : 93.21118856988028
# Perplexity for test sample 255 : 516.5464429451353
# Perplexity for test sample 256 : 654.1620118492007
# Perplexity for test sample 257 : 244.17163470377633
# Perplexity for test sample 258 : 285.3511077003219
# Perplexity for test sample 259 : 85.37012472424398
# Perplexity for test sample 260 : 860.0388461213638
# Perplexity for test sample 261 : 786.6765051214762
# Perplexity for test sample 262 : 58.22014307023425
# Perplexity for test sample 263 : 47.24754999817671
# Perplexity for test sample 264 : 674.2672700899234
# Perplexity for test sample 265 : 141.5724666778024
# Perplexity for test sample 266 : 55.41113250960995
# Perplexity for test sample 267 : 182.0261212063472
# Perplexity for test sample 268 : 389.5083235177382
# Perplexity for test sample 269 : 352.58192704272886
# Perplexity for test sample 270 : 388.55130952385673
# Perplexity for test sample 271 : 374.8237721494854
# Perplexity for test sample 272 : 186.4558043031833
# Perplexity for test sample 273 : 872.8217697617591
# Perplexity for test sample 274 : 93.89111083926905
# Perplexity for test sample 275 : 800.564448490152
# Perplexity for test sample 276 : 29.632413377656444
# Perplexity for test sample 277 : 105.61924339621456
# Perplexity for test sample 278 : 129.1289749054484
# Perplexity for test sample 279 : 25.759798001838345
# Perplexity for test sample 280 : 180.36817375925614
# Perplexity for test sample 281 : 273.82291287981786
# Perplexity for test sample 282 : 142.13517285226638
# Perplexity for test sample 283 : 568.3981121575665
# Perplexity for test sample 284 : 125.13675948511808
# Perplexity for test sample 285 : 300.5871085857948
# Perplexity for test sample 286 : 350.4082527961821
# Perplexity for test sample 287 : 660.1886170129659
# Perplexity for test sample 288 : 297.0194391512045
# Perplexity for test sample 289 : 56.64959196423578
# Perplexity for test sample 290 : 35.06790281919747
# Perplexity for test sample 291 : 52.68695367318594
# Perplexity for test sample 292 : 262.4093680660957
# Perplexity for test sample 293 : 39.50357304791518
# Perplexity for test sample 294 : 347.541457735179
# Perplexity for test sample 295 : 411.08686814113213
# Perplexity for test sample 296 : 735.3776930933885
# Perplexity for test sample 297 : 67.42084137277739
# Perplexity for test sample 298 : 343.0443127748167
# Perplexity for test sample 299 : 805.0083435790531
# Perplexity for test sample 300 : 193.64119698785444
# Perplexity for test sample 301 : 139.76985767237855
# Perplexity for test sample 302 : 78.52377247060697
# Perplexity for test sample 303 : 60.9040781132214
# Perplexity for test sample 304 : 28.886110723902696
# Perplexity for test sample 305 : 12.914531957333669
# Perplexity for test sample 306 : 23.729046449857226
# Perplexity for test sample 307 : 225.18914400504505
# Perplexity for test sample 308 : 124.82453925428848
# Perplexity for test sample 309 : 331.4148628324718
# Perplexity for test sample 310 : 176.69913608350615
# Perplexity for test sample 311 : 185.24163183048637
# Perplexity for test sample 312 : 202.04708549617493
# Perplexity for test sample 313 : 575.2358882712963
# Perplexity for test sample 314 : 147.23748582889593
# Perplexity for test sample 315 : 1228.276296671485
# Perplexity for test sample 316 : 157.28668869464
# Perplexity for test sample 317 : 1041.9628811358648
# Perplexity for test sample 318 : 1099.2183572539855
# Perplexity for test sample 319 : 348.24814535007977
# Perplexity for test sample 320 : 302.3956327509629
# Perplexity for test sample 321 : 671.5014928824521
# Perplexity for test sample 322 : 329.048619877612
# Perplexity for test sample 323 : 317.8114863922759
# Perplexity for test sample 324 : 446.1703613715469
# Perplexity for test sample 325 : 870.9126984405672
# Perplexity for test sample 326 : 828.7473882105705
# Perplexity for test sample 327 : 571.0781545778302
# Perplexity for test sample 328 : 56.27004507211649
# Perplexity for test sample 329 : 58.017614909255805
# Perplexity for test sample 330 : 210.5468261266485
# Perplexity for test sample 331 : 21.453604996994542
# Perplexity for test sample 332 : 124.07558092043497
# Perplexity for test sample 333 : 20.6686409255104
# Perplexity for test sample 334 : 42.581861052456595
# Perplexity for test sample 335 : 71.37602145037873
# Perplexity for test sample 336 : 20.352638002292387
# Perplexity for test sample 337 : 753.6905556996476
# Perplexity for test sample 338 : 113.08868141932273
# Perplexity for test sample 339 : 185.50061988209612
# Perplexity for test sample 340 : 81.34282093962989
# Perplexity for test sample 341 : 49.35280900001362
# Perplexity for test sample 342 : 393.91917329185213
# Perplexity for test sample 343 : 344.07803344304523
# Perplexity for test sample 344 : 299.98657862785797
# Perplexity for test sample 345 : 516.7430345591669
# Perplexity for test sample 346 : 459.70466007034145
# Perplexity for test sample 347 : 155.76774282418833
# Perplexity for test sample 348 : 416.55883886160694
# Perplexity for test sample 349 : 131.0485562675835
# Perplexity for test sample 350 : 309.52688560125193
# Perplexity for test sample 351 : 808.0927779041558
# Perplexity for test sample 352 : 381.5454885471305
# Perplexity for test sample 353 : 417.8623025283808
# Perplexity for test sample 354 : 42.31317870548912
# Perplexity for test sample 355 : 837.4211662048051
# Perplexity for test sample 356 : 47.72140544733154
# Perplexity for test sample 357 : 295.66585996151775
# Perplexity for test sample 358 : 558.8113077468736
# Perplexity for test sample 359 : 451.13615935025337
# Perplexity for test sample 360 : 348.5721083715625
# Perplexity for test sample 361 : 431.1408609375156
# Perplexity for test sample 362 : 368.61802747261174
# Perplexity for test sample 363 : 374.55077232560467
# Perplexity for test sample 364 : 308.9672731620985
# Perplexity for test sample 365 : 475.26984258781596
# Perplexity for test sample 366 : 204.40038811745214
# Perplexity for test sample 367 : 448.0426546605136
# Perplexity for test sample 368 : 80.8615426676604
# Perplexity for test sample 369 : 541.0049459387565
# Perplexity for test sample 370 : 107.1361439469955
# Perplexity for test sample 371 : 586.9260958902971
# Perplexity for test sample 372 : 75.66977613973393
# Perplexity for test sample 373 : 524.9103377502549
# Perplexity for test sample 374 : 880.0286233181388
# Perplexity for test sample 375 : 116.54282704589349
# Perplexity for test sample 376 : 587.7850795340397
# Perplexity for test sample 377 : 952.9695019594877
# Perplexity for test sample 378 : 2755.941791069403
# Perplexity for test sample 379 : 267.24370413546785
# Perplexity for test sample 380 : 314.57292798792855
# Perplexity for test sample 381 : 302.78982602821713
# Perplexity for test sample 382 : 488.12629283249544
# Perplexity for test sample 383 : 508.3073346526625
# Perplexity for test sample 384 : 735.3657709061139
# Perplexity for test sample 385 : 428.62203154487065
# Perplexity for test sample 386 : 578.555332988118
# Perplexity for test sample 387 : 400.0996031016197
# Perplexity for test sample 388 : 735.7480784497968
# Perplexity for test sample 389 : 898.6814132945841
# Perplexity for test sample 390 : 256.5145584243939
# Perplexity for test sample 391 : 503.23747872218127
# Perplexity for test sample 392 : 554.2379190694048
# Perplexity for test sample 393 : 711.8310373602357
# Perplexity for test sample 394 : 482.6734618267679
# Perplexity for test sample 395 : 555.0787062122746
# Perplexity for test sample 396 : 1471.53826014736
# Perplexity for test sample 397 : 1625.5064612399121
# Perplexity for test sample 398 : 298.9646948649303
# Perplexity for test sample 399 : 517.7661226770626
# Perplexity for test sample 400 : 272.2030538585478
# Perplexity for test sample 401 : 447.86045390895293
# Perplexity for test sample 402 : 205.63734942370638
# Perplexity for test sample 403 : 266.92811479971317
# Perplexity for test sample 404 : 680.853649506387
# Perplexity for test sample 405 : 723.9932894053889
# Perplexity for test sample 406 : 206.36463565020875
# Perplexity for test sample 407 : 802.6250501603773
# Perplexity for test sample 408 : 362.52505384731364
# Perplexity for test sample 409 : 1068.9055000011376
# Perplexity for test sample 410 : 510.24788663108814
# Perplexity for test sample 411 : 588.8061765019211
# Perplexity for test sample 412 : 620.5459713454563
# Perplexity for test sample 413 : 158.9665995905352
# Perplexity for test sample 414 : 192.5431311619956
# Perplexity for test sample 415 : 757.2496830180095
# Perplexity for test sample 416 : 1416.902524054119
# Perplexity for test sample 417 : 472.0603683120044
# Perplexity for test sample 418 : 138.5051800883409
# Perplexity for test sample 419 : 129.4838787586761
# Perplexity for test sample 420 : 908.1170080544223
# Perplexity for test sample 421 : 86.64560767563366
# Perplexity for test sample 422 : 776.3540968674317
# Perplexity for test sample 423 : 434.79385269308705
# Perplexity for test sample 424 : 195.5171534611129
# Perplexity for test sample 425 : 662.6590755036269
# Perplexity for test sample 426 : 146.0463317395585
# Perplexity for test sample 427 : 56.313555987928055
# Perplexity for test sample 428 : 19.635179245174932
# Perplexity for test sample 429 : 33.64823001785644
# Perplexity for test sample 430 : 650.416839635342
# Perplexity for test sample 431 : 224.90015915157653
# Perplexity for test sample 432 : 18.00826814197913
# Perplexity for test sample 433 : 9.469744715857077
# Perplexity for test sample 434 : 1097.3408912933892
# Perplexity for test sample 435 : 483.3851700463994
# Perplexity for test sample 436 : 849.2092400490992
# Perplexity for test sample 437 : 210.34763325948722
# Perplexity for test sample 438 : 586.5816792648599
# Perplexity for test sample 439 : 218.5586595705926
# Perplexity for test sample 440 : 523.300899078088
# Perplexity for test sample 441 : 398.13936254232533
# Perplexity for test sample 442 : 242.65497241735287
# Perplexity for test sample 443 : 287.03360634958364
# Perplexity for test sample 444 : 529.1062237811674
# Perplexity for test sample 445 : 349.69418028971745
# Perplexity for test sample 446 : 102.23358131875982
# Perplexity for test sample 447 : 142.42466460287167
# Perplexity for test sample 448 : 172.39253805589559
# Perplexity for test sample 449 : 463.0131215576398
# Perplexity for test sample 450 : 412.92671436505833
# Perplexity for test sample 451 : 115.5762380345442
# Perplexity for test sample 452 : 46.09990020702202
# Perplexity for test sample 453 : 60.031339606053265
# Perplexity for test sample 454 : 124.80841011124498
# Perplexity for test sample 455 : 70.17307156999586
# Perplexity for test sample 456 : 28.418915390567573
# Perplexity for test sample 457 : 112.2117751719386
# Perplexity for test sample 458 : 233.28046001124733
# Perplexity for test sample 459 : 51.203429531158655
# Perplexity for test sample 460 : 34.5639391301357
# Perplexity for test sample 461 : 38.18729179457278
# Perplexity for test sample 462 : 113.18719114040888
# Perplexity for test sample 463 : 410.57713649893225
# Perplexity for test sample 464 : 516.5612216688216
# Perplexity for test sample 465 : 43.28025900974404
# Perplexity for test sample 466 : 173.88187978647235
# Perplexity for test sample 467 : 130.0717031646925
# Perplexity for test sample 468 : 181.390578628645
# Perplexity for test sample 469 : 16.221888235172067
# Perplexity for test sample 470 : 213.98823149760017
# Perplexity for test sample 471 : 123.9053059851784
# Perplexity for test sample 472 : 120.37481261205085
# Perplexity for test sample 473 : 1410.8072851801362
# Perplexity for test sample 474 : 217.63651923728725
# Perplexity for test sample 475 : 177.7198942470716
# Perplexity for test sample 476 : 490.24898137045665
# Perplexity for test sample 477 : 407.27828097603543
# Perplexity for test sample 478 : 136.39199633555188
# Perplexity for test sample 479 : 144.0917031717548
# Perplexity for test sample 480 : 581.3007299568465
# Perplexity for test sample 481 : 245.96363424856577
# Perplexity for test sample 482 : 328.3760391043779
# Perplexity for test sample 483 : 40.99863957747366
# Perplexity for test sample 484 : 18.816651808429853
# Perplexity for test sample 485 : 49.476678501064725
# Perplexity for test sample 486 : 25.430428179216417
# Perplexity for test sample 487 : 436.1787096618309
# Perplexity for test sample 488 : 393.5517510718252
# Perplexity for test sample 489 : 81.91816087266986
# Perplexity for test sample 490 : 12.317610159454782
# Perplexity for test sample 491 : 1175.6094008494601
# Perplexity for test sample 492 : 725.1410419865709
# Perplexity for test sample 493 : 326.7407122087899
# Perplexity for test sample 494 : 441.2173541337303
# Perplexity for test sample 495 : 352.5886520734286
# Perplexity for test sample 496 : 548.8177600693868
# Perplexity for test sample 497 : 133.49333504251433
# Perplexity for test sample 498 : 178.31655530480828
# Perplexity for test sample 499 : 390.642752032258
# Perplexity for test sample 500 : 535.8575242852795
# Perplexity for test sample 501 : 483.01582611676906
# Perplexity for test sample 502 : 267.85186211973104
# Perplexity for test sample 503 : 883.541206783389
# Perplexity for test sample 504 : 352.5476313813259
# Perplexity for test sample 505 : 347.281704825485
# Perplexity for test sample 506 : 456.9742818824559
# Perplexity for test sample 507 : 518.1988549099124
# Perplexity for test sample 508 : 902.4547593359952
# Perplexity for test sample 509 : 234.34105931101485
# Perplexity for test sample 510 : 607.9692481038168
# Perplexity for test sample 511 : 682.8470297930626
# Perplexity for test sample 512 : 219.69988562656167
# Perplexity for test sample 513 : 739.3627804507234
# Perplexity for test sample 514 : 259.10004470337
# Perplexity for test sample 515 : 270.64542629295744
# Perplexity for test sample 516 : 321.7170976750267
# Perplexity for test sample 517 : 802.2225281645957
# Perplexity for test sample 518 : 242.91464185022613
# Perplexity for test sample 519 : 265.21558968793096
# Perplexity for test sample 520 : 370.4809677913031
# Perplexity for test sample 521 : 487.4680354600938
# Perplexity for test sample 522 : 86.67060736792448
# Perplexity for test sample 523 : 304.623804404759
# Perplexity for test sample 524 : 184.02501108140643
# Perplexity for test sample 525 : 484.1452513573148
# Perplexity for test sample 526 : 1154.8622535266902
# Perplexity for test sample 527 : 358.5727529458172
# Perplexity for test sample 528 : 82.53971185846348
# Perplexity for test sample 529 : 642.8720534390304
# Perplexity for test sample 530 : 144.5892523625556
# Perplexity for test sample 531 : 343.02223068841204
# Perplexity for test sample 532 : 324.46090476586846
# Perplexity for test sample 533 : 304.85223235965503
# Perplexity for test sample 534 : 469.69470512124343
# Perplexity for test sample 535 : 490.5375371186559
# Perplexity for test sample 536 : 370.22242913290853
# Perplexity for test sample 537 : 921.4699556938726
# Perplexity for test sample 538 : 433.06880809113443
# Perplexity for test sample 539 : 210.2048523078828
# Perplexity for test sample 540 : 97.22281307565663
# Perplexity for test sample 541 : 558.9197683035057
# Perplexity for test sample 542 : 540.2663628942262
# Perplexity for test sample 543 : 239.82978610818913
# Perplexity for test sample 544 : 289.0926119063754
# Perplexity for test sample 545 : 301.5946912329337
# Perplexity for test sample 546 : 514.8818682797539
# Perplexity for test sample 547 : 388.95096934002396
# Perplexity for test sample 548 : 497.45238126534565
# Perplexity for test sample 549 : 467.2671410725466
# Perplexity for test sample 550 : 326.5972499672611
# Perplexity for test sample 551 : 236.2553869987733
# Perplexity for test sample 552 : 1010.6503020421352
# Perplexity for test sample 553 : 308.91438726838334
# Perplexity for test sample 554 : 255.89236052086142
# Perplexity for test sample 555 : 203.6582702323006
# Perplexity for test sample 556 : 60.82594901527498
# Perplexity for test sample 557 : 636.3817543441652
# Perplexity for test sample 558 : 735.8740379268612
# Perplexity for test sample 559 : 201.98649448515067
# Perplexity for test sample 560 : 356.70539237842866
# Perplexity for test sample 561 : 173.33989258253064
# Perplexity for test sample 562 : 141.84789283234582
# Perplexity for test sample 563 : 216.49795886814795
# Perplexity for test sample 564 : 285.368660755634
# Perplexity for test sample 565 : 437.8303275185295
# Perplexity for test sample 566 : 111.83641250347885
# Perplexity for test sample 567 : 526.6691093947001
# Perplexity for test sample 568 : 657.7455593603954
# Perplexity for test sample 569 : 160.35983112591416
# Perplexity for test sample 570 : 252.72185712253687
# Perplexity for test sample 571 : 242.01191706007643
# Perplexity for test sample 572 : 1082.735036062756
# Perplexity for test sample 573 : 696.8776647795227
# Perplexity for test sample 574 : 393.91015730067295
# Perplexity for test sample 575 : 430.4781568504311
# Perplexity for test sample 576 : 174.5060080778208
# Perplexity for test sample 577 : 472.170453053014
# Perplexity for test sample 578 : 401.949495054341
# Perplexity for test sample 579 : 512.1089070765197
# Perplexity for test sample 580 : 357.7386542892264
# Perplexity for test sample 581 : 244.47279210280217
# Perplexity for test sample 582 : 192.69762041919404
# Perplexity for test sample 583 : 495.87605572322536
# Perplexity for test sample 584 : 482.4378389552818
# Perplexity for test sample 585 : 1722.0177343750613
# Perplexity for test sample 586 : 342.5756600124425
# Perplexity for test sample 587 : 748.1059789536525
# Perplexity for test sample 588 : 230.1192560561706
# Perplexity for test sample 589 : 749.4606175581753
# Perplexity for test sample 590 : 1092.0432266398789
# Perplexity for test sample 591 : 349.9567388679842
# Perplexity for test sample 592 : 1396.6466540377887
# Perplexity for test sample 593 : 522.142371148089
# Perplexity for test sample 594 : 867.8437742993722
# Perplexity for test sample 595 : 571.5622568006382
# Perplexity for test sample 596 : 211.9129172655292
# Perplexity for test sample 597 : 2287.4059973256217
# Perplexity for test sample 598 : 241.04116031285312
# Perplexity for test sample 599 : 267.8324491217049
# Perplexity for test sample 600 : 316.81905991099643
# Perplexity for test sample 601 : 1214.264017093839
# Perplexity for test sample 602 : 495.4988216867842
# Perplexity for test sample 603 : 975.0746185727935
# Perplexity for test sample 604 : 231.30308893040308
# Perplexity for test sample 605 : 1486.7481457937301
# Perplexity for test sample 606 : 235.62198798296808
# Perplexity for test sample 607 : 365.8176171210044
# Perplexity for test sample 608 : 633.4743811157866
# Perplexity for test sample 609 : 700.9294672987344
# Perplexity for test sample 610 : 595.507694898226
# Perplexity for test sample 611 : 543.6180359834844
# Perplexity for test sample 612 : 790.1087854151995
# Perplexity for test sample 613 : 183.09406517820233
# Perplexity for test sample 614 : 480.5780740935823
# Perplexity for test sample 615 : 773.033908803124
# Perplexity for test sample 616 : 300.94378448619324
# Perplexity for test sample 617 : 394.9396872530529
# Perplexity for test sample 618 : 336.3579070835705
# Perplexity for test sample 619 : 411.9048945714583
# Perplexity for test sample 620 : 290.8237958577836
# Perplexity for test sample 621 : 478.80355460535026
# Perplexity for test sample 622 : 377.3275242886194
# Perplexity for test sample 623 : 1064.9149289953575
# Perplexity for test sample 624 : 1090.3734921894822
# Perplexity for test sample 625 : 779.7710856924506
# Perplexity for test sample 626 : 558.4674111717629
# Perplexity for test sample 627 : 493.6677954084279
# Perplexity for test sample 628 : 244.67338113278288
# Perplexity for test sample 629 : 563.2819424662117
# Perplexity for test sample 630 : 487.61100878961787
# Perplexity for test sample 631 : 809.5321047791286
# Perplexity for test sample 632 : 677.6351707908713
# Perplexity for test sample 633 : 216.10726040540547
# Perplexity for test sample 634 : 310.08189295371
# Perplexity for test sample 635 : 255.03065236470673
# Perplexity for test sample 636 : 1122.7980644609333
# Perplexity for test sample 637 : 626.7295083131165
# Perplexity for test sample 638 : 394.86869627104807
# Perplexity for test sample 639 : 230.18576168828793
# Perplexity for test sample 640 : 315.54357281756796
# Perplexity for test sample 641 : 438.9233676741802
# Perplexity for test sample 642 : 219.11954382109724
# Perplexity for test sample 643 : 425.2631479468103
# Perplexity for test sample 644 : 502.72446097180716
# Perplexity for test sample 645 : 1388.0111502800266
# Perplexity for test sample 646 : 101.92060677017177
# Perplexity for test sample 647 : 33.13782700973555
# Perplexity for test sample 648 : 71.82042944198918
# Perplexity for test sample 649 : 394.9187840733366
# Perplexity for test sample 650 : 507.246576999203
# Perplexity for test sample 651 : 360.9681234631579
# Perplexity for test sample 652 : 503.5939489750902
# Perplexity for test sample 653 : 175.81874754851287
# Perplexity for test sample 654 : 244.11575464695042
# Perplexity for test sample 655 : 630.9586646003667
# Perplexity for test sample 656 : 426.2664747079865
# Perplexity for test sample 657 : 191.25958551621312
# Perplexity for test sample 658 : 169.3828635261699
# Perplexity for test sample 659 : 121.24455248264051
# Perplexity for test sample 660 : 308.13731784674457
# Perplexity for test sample 661 : 405.86594897569023
# Perplexity for test sample 662 : 56.916373628289975
# Perplexity for test sample 663 : 166.708169030506
# Perplexity for test sample 664 : 149.98864014599886
# Perplexity for test sample 665 : 566.5569895926442
# Perplexity for test sample 666 : 115.84913894587257
# Perplexity for test sample 667 : 280.91107450601083
# Perplexity for test sample 668 : 1054.4221762685115
# Perplexity for test sample 669 : 308.18331078297496
# Perplexity for test sample 670 : 288.7085411815176
# Perplexity for test sample 671 : 476.0244267501216
# Perplexity for test sample 672 : 816.1295906692438
# Perplexity for test sample 673 : 228.77451633018677
# Perplexity for test sample 674 : 910.223076708887
# Perplexity for test sample 675 : 307.7988272005231
# Perplexity for test sample 676 : 276.9513232878786
# Perplexity for test sample 677 : 549.2410868161959
# Perplexity for test sample 678 : 404.8303282170591
# Perplexity for test sample 679 : 331.2383892947579
# Perplexity for test sample 680 : 73.37195391165386
# Perplexity for test sample 681 : 86.0901277751469
# Perplexity for test sample 682 : 162.61188550778746
# Perplexity for test sample 683 : 481.96693822259925
# Perplexity for test sample 684 : 510.7924506440719
# Perplexity for test sample 685 : 308.4197022310795
# Perplexity for test sample 686 : 711.199642992457
# Perplexity for test sample 687 : 597.8743662150472
# Perplexity for test sample 688 : 615.3754860173902
# Perplexity for test sample 689 : 49.56850233532684
# Perplexity for test sample 690 : 2068.3702124501406
# Perplexity for test sample 691 : 258.1702845304297
# Perplexity for test sample 692 : 224.47577943003836
# Perplexity for test sample 693 : 549.7931843786565
# Perplexity for test sample 694 : 239.41227939805466
# Perplexity for test sample 695 : 627.3044564201716
# Perplexity for test sample 696 : 171.85814322295647
# Perplexity for test sample 697 : 844.4742278508804
# Perplexity for test sample 698 : 1560.1037294147006
# Perplexity for test sample 699 : 86.47456386063801
# Perplexity for test sample 700 : 102.10209301726555
# Perplexity for test sample 701 : 83.51811964709118
# Perplexity for test sample 702 : 658.4723451052837
# Perplexity for test sample 703 : 642.8858481247681
# Perplexity for test sample 704 : 352.80577133132135
# Perplexity for test sample 705 : 566.3214630317522
# Perplexity for test sample 706 : 157.4461447602632
# Perplexity for test sample 707 : 223.89061530000507
# Perplexity for test sample 708 : 792.0080169142234
# Perplexity for test sample 709 : 1263.6159515224556
# Perplexity for test sample 710 : 303.29457063139927
# Perplexity for test sample 711 : 846.5279561667415
# Perplexity for test sample 712 : 228.14583379392568
# Perplexity for test sample 713 : 549.8293639001237
# Perplexity for test sample 714 : 700.1017364239837
# Perplexity for test sample 715 : 163.5136786665492
# Perplexity for test sample 716 : 1623.370909400842
# Perplexity for test sample 717 : 385.444311492112
# Perplexity for test sample 718 : 700.2743501479986
# Perplexity for test sample 719 : 235.37707276964179
# Perplexity for test sample 720 : 182.9988390454518
# Perplexity for test sample 721 : 424.1240316546032
# Perplexity for test sample 722 : 452.6693266802589
# Perplexity for test sample 723 : 529.1665263217083
# Perplexity for test sample 724 : 370.5820305736949
# Perplexity for test sample 725 : 299.69133660560533
# Perplexity for test sample 726 : 148.42795054160064
# Perplexity for test sample 727 : 1053.584362243903
# Perplexity for test sample 728 : 248.3496772193291
# Perplexity for test sample 729 : 321.55406771006375
# Perplexity for test sample 730 : 423.4289028701776
# Perplexity for test sample 731 : 564.0874934287443
# Perplexity for test sample 732 : 1867.3599519565469
# Perplexity for test sample 733 : 648.4207276779346
# Perplexity for test sample 734 : 383.6123911107782
# Perplexity for test sample 735 : 219.3768307163478
# Perplexity for test sample 736 : 546.6056591466663
# Perplexity for test sample 737 : 363.4408395186297
# Perplexity for test sample 738 : 112.28001701283026
# Perplexity for test sample 739 : 527.9975302508624
# Perplexity for test sample 740 : 1141.9047234171344
# Perplexity for test sample 741 : 393.5339237662468
# Perplexity for test sample 742 : 230.69726720114943
# Perplexity for test sample 743 : 158.94583142352252
# Perplexity for test sample 744 : 120.91188596143519
# Perplexity for test sample 745 : 428.2651232776334
# Perplexity for test sample 746 : 541.1267220773358
# Perplexity for test sample 747 : 169.64014340476356
# Perplexity for test sample 748 : 640.4377995211652
# Perplexity for test sample 749 : 322.85492800898635
# Perplexity for test sample 750 : 531.8446587509324
# Perplexity for test sample 751 : 213.93232223062554
# Perplexity for test sample 752 : 750.1896507079218
# Perplexity for test sample 753 : 304.685689724375
# Perplexity for test sample 754 : 547.3594334599502
# Perplexity for test sample 755 : 355.30541146808844
# Perplexity for test sample 756 : 193.30418967029715
# Perplexity for test sample 757 : 131.21031459814182
# Perplexity for test sample 758 : 84.00567543531812
# Perplexity for test sample 759 : 371.50541437619574
# Perplexity for test sample 760 : 289.06366483481975
# Perplexity for test sample 761 : 71.92777008235032
# Perplexity for test sample 762 : 896.2797476013792
# Perplexity for test sample 763 : 17.710723495728082
# Perplexity for test sample 764 : 14.97993337804149
# Perplexity for test sample 765 : 24.669904248109944
# Perplexity for test sample 766 : 72.06650124499212
# Perplexity for test sample 767 : 281.39638804289325
# Perplexity for test sample 768 : 218.77167841945374
# Perplexity for test sample 769 : 102.00189758963288
# Perplexity for test sample 770 : 88.61068538249273
# Perplexity for test sample 771 : 514.0291656775489
# Perplexity for test sample 772 : 565.1145779496362
# Perplexity for test sample 773 : 131.0970565654249
# Perplexity for test sample 774 : 22.488347664200333
# Perplexity for test sample 775 : 18.589296613615815
# Perplexity for test sample 776 : 1605.904690482694
# Perplexity for test sample 777 : 457.30866631906497
# Perplexity for test sample 778 : 216.00454599489376
# Perplexity for test sample 779 : 777.2352892543531
# Perplexity for test sample 780 : 292.5170816176715
# Perplexity for test sample 781 : 208.20365519292002
# Perplexity for test sample 782 : 230.2123254130334
# Perplexity for test sample 783 : 1401.4632657250834
# Perplexity for test sample 784 : 458.0655301491366
# Perplexity for test sample 785 : 477.9909999159729
# Perplexity for test sample 786 : 496.986494136706
# Perplexity for test sample 787 : 1197.523873018316
# Perplexity for test sample 788 : 386.96913540383815
# Perplexity for test sample 789 : 1166.8445852108464
# Perplexity for test sample 790 : 347.722471842393
# Perplexity for test sample 791 : 607.2009130384769
# Perplexity for test sample 792 : 542.1512931635181
# Perplexity for test sample 793 : 395.5275003213454
# Perplexity for test sample 794 : 1085.0230584666654
# Perplexity for test sample 795 : 269.41152508796534
# Perplexity for test sample 796 : 995.4865581372948
# Perplexity for test sample 797 : 510.6704392435154
# Perplexity for test sample 798 : 13.206860094172548
# Perplexity for test sample 799 : 538.9032195914912
# Perplexity for test sample 800 : 696.6494140150166
# Perplexity for test sample 801 : 699.7906717746478
# Perplexity for test sample 802 : 787.3230965848483
# Perplexity for test sample 803 : 321.5672542682346
# Perplexity for test sample 804 : 368.8497661639466
# Perplexity for test sample 805 : 831.9521357112604
# Perplexity for test sample 806 : 729.3856929936351
# Perplexity for test sample 807 : 595.931798417759
# Perplexity for test sample 808 : 834.0704594455367
# Perplexity for test sample 809 : 413.71289114007874
# Perplexity for test sample 810 : 387.5925808644953
# Perplexity for test sample 811 : 359.6313157819356
# Perplexity for test sample 812 : 706.7001639176472
# Perplexity for test sample 813 : 270.01354337207465
# Perplexity for test sample 814 : 555.9061894305124
# Perplexity for test sample 815 : 75.5228120694161
# Perplexity for test sample 816 : 357.77191953699946
# Perplexity for test sample 817 : 199.0227940469609
# Perplexity for test sample 818 : 328.2922784737706
# Perplexity for test sample 819 : 454.785048443649
# Perplexity for test sample 820 : 378.60100994195966
# Perplexity for test sample 821 : 209.53905558043178
# Perplexity for test sample 822 : 259.46625400088925
# Perplexity for test sample 823 : 85.6501223083616
# Perplexity for test sample 824 : 248.8839807017913
# Perplexity for test sample 825 : 173.00463830524848
# Perplexity for test sample 826 : 1003.049819283141
# Perplexity for test sample 827 : 531.6684336627025
# Perplexity for test sample 828 : 481.23437053497054
# Perplexity for test sample 829 : 698.2657213985807
# Perplexity for test sample 830 : 168.11986064656332
# Perplexity for test sample 831 : 20.711201640680706
# Perplexity for test sample 832 : 316.95187924105903
# Perplexity for test sample 833 : 396.36748222442384
# Perplexity for test sample 834 : 424.004930140928
# Perplexity for test sample 835 : 219.77134429435603
# Perplexity for test sample 836 : 255.09669410788678
# Perplexity for test sample 837 : 173.68026859849576
# Perplexity for test sample 838 : 430.5606824881422
# Perplexity for test sample 839 : 389.2233291459731
# Perplexity for test sample 840 : 78.32471583212828
# Perplexity for test sample 841 : 209.40381296942604
# Perplexity for test sample 842 : 125.06857542151207
# Perplexity for test sample 843 : 377.34983549748415
# Perplexity for test sample 844 : 643.8629575947732
# Perplexity for test sample 845 : 231.5645228311551
# Perplexity for test sample 846 : 218.75811743926644
# Perplexity for test sample 847 : 351.54562251518627
# Perplexity for test sample 848 : 303.42779685712725
# Perplexity for test sample 849 : 553.0670702712513
# Perplexity for test sample 850 : 304.89729880078943
# Perplexity for test sample 851 : 134.76319857418895
# Perplexity for test sample 852 : 335.8264809003096
# Perplexity for test sample 853 : 292.7651875757262
# Perplexity for test sample 854 : 294.843515412373
# Perplexity for test sample 855 : 485.15122184322877
# Perplexity for test sample 856 : 556.4135125626375
# Perplexity for test sample 857 : 171.7098807019989
# Perplexity for test sample 858 : 567.5958780706483
# Perplexity for test sample 859 : 1135.3861022160306
# Perplexity for test sample 860 : 535.613305912951
# Perplexity for test sample 861 : 303.20014708759544
# Perplexity for test sample 862 : 247.95387018814657
# Perplexity for test sample 863 : 1070.806307404984
# Perplexity for test sample 864 : 911.6712775302186
# Perplexity for test sample 865 : 221.75426254220727
# Perplexity for test sample 866 : 477.5465272261062
# Perplexity for test sample 867 : 784.9509883969771
# Perplexity for test sample 868 : 731.769912183874
# Perplexity for test sample 869 : 405.24827835827045
# Perplexity for test sample 870 : 362.6493653903788
# Perplexity for test sample 871 : 249.54184521756707
# Perplexity for test sample 872 : 191.76769425953694
# Perplexity for test sample 873 : 1884.1788240555425
# Perplexity for test sample 874 : 521.0741097108689
# Perplexity for test sample 875 : 450.7501868760019
# Perplexity for test sample 876 : 414.24784838015205
# Perplexity for test sample 877 : 568.2748053644863
# Perplexity for test sample 878 : 305.27437322662064
# Perplexity for test sample 879 : 546.7271317624965
# Perplexity for test sample 880 : 102.81475236966332
# Perplexity for test sample 881 : 662.068771085683
# Perplexity for test sample 882 : 584.7271033625947
# Perplexity for test sample 883 : 192.0497255751086
# Perplexity for test sample 884 : 272.8466958442992
# Perplexity for test sample 885 : 570.5182848860505
# Perplexity for test sample 886 : 426.1175113864327
# Perplexity for test sample 887 : 411.5275644886753
# Perplexity for test sample 888 : 422.47415486553365
# Perplexity for test sample 889 : 219.99089491643764
# Perplexity for test sample 890 : 426.5629303827633
# Perplexity for test sample 891 : 770.8673046235416
# Perplexity for test sample 892 : 184.84219277613317
# Perplexity for test sample 893 : 614.0860231659043
# Perplexity for test sample 894 : 510.8993867924762
# Perplexity for test sample 895 : 2976.996249428898
# Perplexity for test sample 896 : 1084.1676504546144
# Perplexity for test sample 897 : 687.60600008881
# Perplexity for test sample 898 : 267.15375247702696
# Perplexity for test sample 899 : 1473.9399776529983
# Perplexity for test sample 900 : 530.154800693338
# Perplexity for test sample 901 : 211.94070727468957
# Perplexity for test sample 902 : 255.34958643142258
# Perplexity for test sample 903 : 431.9524470799433
# Perplexity for test sample 904 : 581.6248504708386
# Perplexity for test sample 905 : 478.23653696683726
# Perplexity for test sample 906 : 318.05890298942774
# Perplexity for test sample 907 : 267.1011460678621
# Perplexity for test sample 908 : 668.0716878533567
# Perplexity for test sample 909 : 754.7590531281321
# Perplexity for test sample 910 : 223.51162041473498
# Perplexity for test sample 911 : 121.45633613658747
# Perplexity for test sample 912 : 154.77665272547983
# Perplexity for test sample 913 : 286.6133181007075
# Perplexity for test sample 914 : 185.776623297916
# Perplexity for test sample 915 : 525.1692084064425
# Perplexity for test sample 916 : 144.52845519232076
# Perplexity for test sample 917 : 264.54100138351214
# Perplexity for test sample 918 : 30.0122921654538
# Perplexity for test sample 919 : 822.8487207517895
# Perplexity for test sample 920 : 18.609069560348786
# Perplexity for test sample 921 : 225.4506551277398
# Perplexity for test sample 922 : 231.14972097352802
# Perplexity for test sample 923 : 188.83530709397908
# Perplexity for test sample 924 : 385.6485609125655
# Perplexity for test sample 925 : 354.68924728231633
# Perplexity for test sample 926 : 313.817835385421
# Perplexity for test sample 927 : 533.1874051445893
# Perplexity for test sample 928 : 186.90159291476908
# Perplexity for test sample 929 : 102.4552381788134
# Perplexity for test sample 930 : 1185.419796098459
# Perplexity for test sample 931 : 2298.560634498134
# Perplexity for test sample 932 : 131.38022851819943
# Perplexity for test sample 933 : 111.87401489229681
# Perplexity for test sample 934 : 67.18649932014316
# Perplexity for test sample 935 : 89.40690514349207
# Perplexity for test sample 936 : 57.79939021493189
# ...
# Perplexity for test sample 3903 : 578.4094126287006
# Perplexity for test sample 3904 : 204.24859294876183
# Perplexity for test sample 3905 : 499.87203261229735
# Perplexity for test sample 3906 : 392.38548611493405
# Perplexity for test sample 3907 : 104.35693964494483
# Perplexity for test sample 3908 : 101.97942917232623
# Perplexity for test sample 3909 : 366.519345310287
# Perplexity for test sample 3910 : 76.05038665439075
# Perplexity for test sample 3911 : 470.2746918104626
# Perplexity for test sample 3912 : 657.1778069827749
# Perplexity for test sample 3913 : 655.1703180161943
# Perplexity for test sample 3914 : 228.15725686304725
# Perplexity for test sample 3915 : 327.29802371421175
# Perplexity for test sample 3916 : 372.28727968214474
# Perplexity for test sample 3917 : 124.18964204976731
# Perplexity for test sample 3918 : 625.1827901377698
# Perplexity for test sample 3919 : 780.2471654662327
# Perplexity for test sample 3920 : 314.64028522566184
# Perplexity for test sample 3921 : 91.20369201447393
# Perplexity for test sample 3922 : 217.02147238838097
# Perplexity for test sample 3923 : 577.637117178814
# Perplexity for test sample 3924 : 646.9046836475708
# Perplexity for test sample 3925 : 126.56432719271699
# Perplexity for test sample 3926 : 69.15267081801959
# Perplexity for test sample 3927 : 127.54427195008805
# Perplexity for test sample 3928 : 162.75524145235283
# Perplexity for test sample 3929 : 282.7660682102691
# Perplexity for test sample 3930 : 211.71626819935364
# Perplexity for test sample 3931 : 364.3346158128044
# Perplexity for test sample 3932 : 138.2314985981678
# Perplexity for test sample 3933 : 48.671386186782534
# Perplexity for test sample 3934 : 41.698649825700315
# Perplexity for test sample 3935 : 127.8159300825543
# Perplexity for test sample 3936 : 71.13112015912377
# Perplexity for test sample 3937 : 171.37303935458257
# Perplexity for test sample 3938 : 242.26858788357578
# Perplexity for test sample 3939 : 250.90717876833787
# Perplexity for test sample 3940 : 156.45661026804493
# Perplexity for test sample 3941 : 159.218079213998
# Perplexity for test sample 3942 : 609.3757391887406
# Perplexity for test sample 3943 : 129.23825249574193
# Perplexity for test sample 3944 : 353.82014504386063
# Perplexity for test sample 3945 : 134.9482017539889
# Perplexity for test sample 3946 : 295.0333761797733
# Perplexity for test sample 3947 : 151.39072572189576
# Perplexity for test sample 3948 : 48.84482859705798
# Perplexity for test sample 3949 : 110.63604046926572
# Perplexity for test sample 3950 : 80.83085649226966
# Perplexity for test sample 3951 : 693.3787491738024
# Perplexity for test sample 3952 : 252.95032141914848
# Perplexity for test sample 3953 : 531.1965902902167
# Perplexity for test sample 3954 : 489.8872405899352
# Perplexity for test sample 3955 : 143.8103429957771
# Perplexity for test sample 3956 : 398.57587153755344
# Perplexity for test sample 3957 : 302.142534987776
# Perplexity for test sample 3958 : 199.4078966807271
# Perplexity for test sample 3959 : 310.4246705781878
# Perplexity for test sample 3960 : 359.0709949087227
# Perplexity for test sample 3961 : 1980.321303905847
# Perplexity for test sample 3962 : 157.11840347627768
# Perplexity for test sample 3963 : 121.16329337063921
# Perplexity for test sample 3964 : 1167.278097314113
# Perplexity for test sample 3965 : 1020.7585786042308
# Perplexity for test sample 3966 : 964.9939297580987
# Perplexity for test sample 3967 : 78.52377247060697
# Perplexity for test sample 3968 : 534.9308006503104
# Perplexity for test sample 3969 : 681.5013220662825
# Perplexity for test sample 3970 : 851.3577012544789
# Perplexity for test sample 3971 : 651.1553987848374
# Perplexity for test sample 3972 : 2463.3747738238526
# Perplexity for test sample 3973 : 86.48429569953504
# Perplexity for test sample 3974 : 264.1352586078847
# Perplexity for test sample 3975 : 299.61474986782923
# Perplexity for test sample 3976 : 197.72301590248648
# Perplexity for test sample 3977 : 314.95626151627454
# Perplexity for test sample 3978 : 261.030231591846
# Perplexity for test sample 3979 : 441.24996560740925
# Perplexity for test sample 3980 : 566.8447781880213
# Perplexity for test sample 3981 : 1597.8020711053687
# Perplexity for test sample 3982 : 269.5416919996375
# Perplexity for test sample 3983 : 128.99610613848415
# Perplexity for test sample 3984 : 215.915985019946
# Perplexity for test sample 3985 : 331.98283801063064
# Perplexity for test sample 3986 : 289.95020624295574
# Perplexity for test sample 3987 : 685.7317962480623
# Perplexity for test sample 3988 : 256.73800410691297
# Perplexity for test sample 3989 : 64.88224705823541
# Perplexity for test sample 3990 : 173.22817916910623
# Perplexity for test sample 3991 : 349.74003877063967
# Perplexity for test sample 3992 : 151.42393617681628
# Perplexity for test sample 3993 : 173.47285263191736
# Perplexity for test sample 3994 : 129.35662782941924
# Perplexity for test sample 3995 : 463.1014427247726
# Perplexity for test sample 3996 : 515.1448817917337
# Perplexity for test sample 3997 : 133.40749262286482
# Perplexity for test sample 3998 : 1008.9972391119138
# Perplexity for test sample 3999 : 91.35293883772022
# Perplexity for test sample 4000 : 330.53501044927486
# Perplexity for test sample 4001 : 452.9502340753253
# Perplexity for test sample 4002 : 178.71467484294953
# Perplexity for test sample 4003 : 293.8345274358634
# Perplexity for test sample 4004 : 162.12976385783247
# Perplexity for test sample 4005 : 442.73771259208115
# Perplexity for test sample 4006 : 894.3189415911071
# Perplexity for test sample 4007 : 261.2800356871796
# Perplexity for test sample 4008 : 465.69985380339887
# Perplexity for test sample 4009 : 1062.5786101919564
# Perplexity for test sample 4010 : 1128.2266339408702
# Perplexity for test sample 4011 : 325.20004544731506
# Perplexity for test sample 4012 : 316.3061359682099
# Perplexity for test sample 4013 : 356.01260750390435
# Perplexity for test sample 4014 : 81.14849643206595
# Perplexity for test sample 4015 : 85.49200893129796
# Perplexity for test sample 4016 : 70.65074145375783
# Perplexity for test sample 4017 : 85.49200893129796
# Perplexity for test sample 4018 : 102.6385084323994
# Perplexity for test sample 4019 : 149.86539006232192
# Perplexity for test sample 4020 : 92.66295877802114
# Perplexity for test sample 4021 : 19.40759310676467
# Perplexity for test sample 4022 : 78.35146166218644
# Perplexity for test sample 4023 : 88.64559312502986
# Perplexity for test sample 4024 : 106.03383888090961
# Perplexity for test sample 4025 : 83.32638577131351
# Perplexity for test sample 4026 : 207.04946883602184
# Perplexity for test sample 4027 : 254.81780546619893
# Perplexity for test sample 4028 : 216.10612688068716
# Perplexity for test sample 4029 : 436.30580775399835
# Perplexity for test sample 4030 : 294.31943170839764
# Perplexity for test sample 4031 : 375.21074327684437
# Perplexity for test sample 4032 : 344.74808732714695
# Perplexity for test sample 4033 : 142.60876080621398
# Perplexity for test sample 4034 : 12.810572362478402
# Perplexity for test sample 4035 : 27.877038951204856
# Perplexity for test sample 4036 : 161.4115307384759
# Perplexity for test sample 4037 : 99.69876614747567
# Perplexity for test sample 4038 : 164.75511820757816
# Perplexity for test sample 4039 : 36.78082516401604
# Perplexity for test sample 4040 : 33.683683460710064
# Perplexity for test sample 4041 : 35.93380978068096
# Perplexity for test sample 4042 : 31.263640238619114
# Perplexity for test sample 4043 : 466.89742226004154
# Perplexity for test sample 4044 : 183.27767450464606
# Perplexity for test sample 4045 : 1139.8309648033996
# Perplexity for test sample 4046 : 995.8554567025468
# Perplexity for test sample 4047 : 222.4423249527432
# Perplexity for test sample 4048 : 361.53243910686547
# Perplexity for test sample 4049 : 71.37040593931727
# Perplexity for test sample 4050 : 76.56156497866161
# Perplexity for test sample 4051 : 242.9861199233109
# Perplexity for test sample 4052 : 156.61724117824903
# Perplexity for test sample 4053 : 122.1999136921998
# Perplexity for test sample 4054 : 760.9464361195321
# Perplexity for test sample 4055 : 157.412589287511
# Perplexity for test sample 4056 : 110.33321775990406
# Perplexity for test sample 4057 : 720.3997943388133
# Perplexity for test sample 4058 : 339.2681540640942
# Perplexity for test sample 4059 : 398.7800437278092
# Perplexity for test sample 4060 : 451.496842035582
# Perplexity for test sample 4061 : 340.8658800063915
# Perplexity for test sample 4062 : 264.4165275562867
# Perplexity for test sample 4063 : 427.09780341887483
# Perplexity for test sample 4064 : 112.3003637841824
# Perplexity for test sample 4065 : 206.01884470122755
# Perplexity for test sample 4066 : 283.0334342692014
# Perplexity for test sample 4067 : 296.9197484315686
# Perplexity for test sample 4068 : 638.2458443376979
# Perplexity for test sample 4069 : 267.4155373246391
# Perplexity for test sample 4070 : 765.9366415760129
# Perplexity for test sample 4071 : 255.8901641885391
# Perplexity for test sample 4072 : 495.7410599361905
# Perplexity for test sample 4073 : 516.8460409774293
# Perplexity for test sample 4074 : 519.0020460598516
# Perplexity for test sample 4075 : 442.6433547831054
# Perplexity for test sample 4076 : 146.6655593241492
# Perplexity for test sample 4077 : 600.1127863172679
# Perplexity for test sample 4078 : 340.04880952520074
# Perplexity for test sample 4079 : 400.38759727973803
# Perplexity for test sample 4080 : 313.0873960849319
# Perplexity for test sample 4081 : 2039.1714705586105
# Perplexity for test sample 4082 : 236.41496083679445
# Perplexity for test sample 4083 : 376.0050683622351
# Perplexity for test sample 4084 : 564.7334098602229
# Perplexity for test sample 4085 : 90.4208711885344
# Perplexity for test sample 4086 : 313.80092652042737
# Perplexity for test sample 4087 : 114.02359180243876
# Perplexity for test sample 4088 : 451.24459209536184
# Perplexity for test sample 4089 : 720.6973383649944
# Perplexity for test sample 4090 : 224.47449497300022
# Perplexity for test sample 4091 : 283.49429551999555
# Perplexity for test sample 4092 : 174.29228692027937
# Perplexity for test sample 4093 : 389.7491066363054
# Perplexity for test sample 4094 : 1621.6386611569526
# Perplexity for test sample 4095 : 802.3254352027012
# Perplexity for test sample 4096 : 41.53945924774274
# Perplexity for test sample 4097 : 31.67362736357646
# Perplexity for test sample 4098 : 22.215473934123303
# Perplexity for test sample 4099 : 61.84751598049631
# Perplexity for test sample 4100 : 40.09055024096901
# Perplexity for test sample 4101 : 115.94115202222324
# Perplexity for test sample 4102 : 342.07600181771045
# Perplexity for test sample 4103 : 87.19070112619463
# Perplexity for test sample 4104 : 654.1495348180019
# Perplexity for test sample 4105 : 161.21730597215407
# Perplexity for test sample 4106 : 652.1382357429038
# Perplexity for test sample 4107 : 213.60511778514325
# Perplexity for test sample 4108 : 309.3934894500949
# Perplexity for test sample 4109 : 291.1590291526794
# Perplexity for test sample 4110 : 281.22616480733814
# Perplexity for test sample 4111 : 81.70808386257194
# Perplexity for test sample 4112 : 142.81713242873408
# Perplexity for test sample 4113 : 285.51729267336304
# Perplexity for test sample 4114 : 197.62150060104045
# Perplexity for test sample 4115 : 121.58503325319178
# Perplexity for test sample 4116 : 64.5318923954727
# Perplexity for test sample 4117 : 508.689226262845
# Perplexity for test sample 4118 : 95.4068871579686
# Perplexity for test sample 4119 : 47.46131784363054
# Perplexity for test sample 4120 : 199.78002619883685
# Perplexity for test sample 4121 : 74.93787601807989
# Perplexity for test sample 4122 : 11.752772323634925
# Perplexity for test sample 4123 : 254.7890100295439
# Perplexity for test sample 4124 : 680.7195796483549
# Perplexity for test sample 4125 : 44.64408350758424
# Perplexity for test sample 4126 : 127.2153074508149
# Perplexity for test sample 4127 : 498.94472945210254
# Perplexity for test sample 4128 : 150.76168428084026
# Perplexity for test sample 4129 : 84.136804208868
# Perplexity for test sample 4130 : 63.9427753533676
# Perplexity for test sample 4131 : 416.4085025315298
# Perplexity for test sample 4132 : 255.4165633078594
# Perplexity for test sample 4133 : 466.31670885256824
# Perplexity for test sample 4134 : 116.77345625052149
# Perplexity for test sample 4135 : 542.515408558744
# Perplexity for test sample 4136 : 998.4668104889749
# Perplexity for test sample 4137 : 823.1532522107503
# Perplexity for test sample 4138 : 852.9692579527306
# Perplexity for test sample 4139 : 159.58930995572823
# Perplexity for test sample 4140 : 330.5249234751862
# Perplexity for test sample 4141 : 303.96896915030123
# Perplexity for test sample 4142 : 208.97230051225952
# Perplexity for test sample 4143 : 159.52760631768186
# Perplexity for test sample 4144 : 275.3880595601576
# Perplexity for test sample 4145 : 382.2967092622009
# Perplexity for test sample 4146 : 114.12960952489802
# Perplexity for test sample 4147 : 248.77956673577478
# Perplexity for test sample 4148 : 209.55724108294777
# Perplexity for test sample 4149 : 108.57807315039845
# Perplexity for test sample 4150 : 299.52847035577827
# Perplexity for test sample 4151 : 695.7242200502916
# Perplexity for test sample 4152 : 802.1001280598356
# Perplexity for test sample 4153 : 327.475208677587
# Perplexity for test sample 4154 : 49.09327486742117
# Perplexity for test sample 4155 : 88.96636365330289
# Perplexity for test sample 4156 : 472.5206886721009
# Perplexity for test sample 4157 : 193.3340565544161
# Perplexity for test sample 4158 : 361.265157807819
# Perplexity for test sample 4159 : 152.18971806510868
# Perplexity for test sample 4160 : 287.4427232152943
# Perplexity for test sample 4161 : 221.14213028988962
# Perplexity for test sample 4162 : 339.926734067908
# Perplexity for test sample 4163 : 304.6527117101465
# Perplexity for test sample 4164 : 217.1627738951992
# Perplexity for test sample 4165 : 402.70670699987704
# Perplexity for test sample 4166 : 187.91703042173322
# Perplexity for test sample 4167 : 484.9876933516014
# Perplexity for test sample 4168 : 4183.563548589946
# Perplexity for test sample 4169 : 88.29098675906971
# Perplexity for test sample 4170 : 131.38022851819943
# Perplexity for test sample 4171 : 111.87401489229681
# Perplexity for test sample 4172 : 80.05044921333877
# Perplexity for test sample 4173 : 89.40690514349207
# Perplexity for test sample 4174 : 143.7581675611561
# Perplexity for test sample 4175 : 61.03083001483566
# Perplexity for test sample 4176 : 126.34502237507998
# Perplexity for test sample 4177 : 135.74615424463585
# Perplexity for test sample 4178 : 194.30215062394802
# Perplexity for test sample 4179 : 324.88169279962455
# Perplexity for test sample 4180 : 249.6888421641638
# Perplexity for test sample 4181 : 712.1651123785548
# Perplexity for test sample 4182 : 49.591730247927146
# Perplexity for test sample 4183 : 241.46219842662717
# Perplexity for test sample 4184 : 131.53029101138154
# Perplexity for test sample 4185 : 174.01110676861853
# Perplexity for test sample 4186 : 191.58115200283234
# Perplexity for test sample 4187 : 298.81746925537726
# Perplexity for test sample 4188 : 179.00260181848824
# Perplexity for test sample 4189 : 274.3965800427616
# Perplexity for test sample 4190 : 288.27878976422477
# Perplexity for test sample 4191 : 94.60531057160685
# Perplexity for test sample 4192 : 113.95461627343066
# Perplexity for test sample 4193 : 535.9032637407267
# Perplexity for test sample 4194 : 341.76801716411427
# Perplexity for test sample 4195 : 192.7561603000492
# Perplexity for test sample 4196 : 439.49427673596995
# Perplexity for test sample 4197 : 1022.574742767844
# Perplexity for test sample 4198 : 126.92089692057557
# Perplexity for test sample 4199 : 255.39500701439727
# Perplexity for test sample 4200 : 113.25894247304969
# Perplexity for test sample 4201 : 409.75529913537844
# Perplexity for test sample 4202 : 182.05363787738722
# Perplexity for test sample 4203 : 503.0460252113128
# Perplexity for test sample 4204 : 700.7820877112077
# Perplexity for test sample 4205 : 675.5419971765143
# Perplexity for test sample 4206 : 383.5909899926032
# The average testing perplexity for neural LM: 402.7019621491263

# %%
neural_model(the)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-fb2fe859a45b> in <module>
# ----> 1 neural_model(the)
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-69-c5f0086bfbca> in forward(self, x)
#       7
#       8     def forward(self, x):
# ----> 9         x = self.embed(x) # Embed word id(s) to vectors
#      10         print(x)
#      11         conc_emb = x.view(x.size(0), x.size(1)*x.size(2))
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     156
#     157     def forward(self, input: Tensor) -> Tensor:
# --> 158         return F.embedding(
#     159             input, self.weight, self.padding_idx, self.max_norm,
#     160             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2042         # remove once script supports set_grad_enabled
#    2043         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2044     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2045
#    2046
#
# TypeError: embedding(): argument 'indices' (position 2) must be Tensor, not int

# %%
    value = 0
    key
    for pair in x:
    #     print(pair)
        try:
            prob = neural_model.compute_mle(pair)
            if prob > value:
                value = prob
                key = pair

        except TypeError:
            # hit end of dict
            
            break
    prob = count_model.compute_mle(key)
    x = count_model.n_gram_count
    print(prob)
    
    
    for i in range(0, len(test_ids)):
        inputs = test_ids[i][:, 0:n_gram-1].to(device)
        gold = test_ids[i][:, n_gram-1:].to(device)
        output = neural_model(inputs)
        cross_entropy = criterion(output, gold.reshape(-1)).item()
        print('Perplexity for test sample '+str(i)+' :', np.exp(cross_entropy))
        test_ppl += np.exp(cross_entropy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-92c768d1e578> in <module>
# ----> 1 neural_model.forward("the")
#
# <ipython-input-15-8a1901d5535e> in forward(self, x)
#       7
#       8     def forward(self, x):
# ----> 9         x = self.embed(x) # Embed word id(s) to vectors
#      10         conc_emb = x.view(x.size(0), x.size(1)*x.size(2))
#      11         intermediate_output = self.intermediate(conc_emb) # one layer of MLP
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     156
#     157     def forward(self, input: Tensor) -> Tensor:
# --> 158         return F.embedding(
#     159             input, self.weight, self.padding_idx, self.max_norm,
#     160             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# ~\.virtualenvs\swtheart_hw7\lib\site-packages\torch\nn\functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2042         # remove once script supports set_grad_enabled
#    2043         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2044     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2045
#    2046
#
# TypeError: embedding(): argument 'indices' (position 2) must be Tensor, not str
